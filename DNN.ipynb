# %%
import cv2
import numpy as np
import torch
from pathlib import Path

# %%
import os

# 이미지와 바운딩 박스 디렉토리 설정
image_dir = "C:/Users/wjdrl/OneDrive - dgu.ac.kr/DA/BAF/project/2024_2/code/Crawling2-2/train/images"
bbox_dir = "C:/Users/wjdrl/OneDrive - dgu.ac.kr/DA/BAF/project/2024_2/code/Crawling2-2/train/labels"

# 실험 파일 설정
image_file = "image_1_jpg.rf.03dc7caa804ba5ddf4d0464d761ccec6.jpg"
bbox_file = "image_1_jpg.rf.03dc7caa804ba5ddf4d0464d761ccec6.txt"

# 이미지와 바운딩 박스 경로 설정
image_path = os.path.join(image_dir, image_file).replace("\\", "/")
bbox_path = os.path.join(bbox_dir, bbox_file).replace("\\", "/")

# %%
image_path
# Out:
# 'C:/Users/wjdrl/OneDrive - dgu.ac.kr/DA/BAF/project/2024_2/code/Crawling2-2/train/images/image_1_jpg.rf.03dc7caa804ba5ddf4d0464d761ccec6.jpg'

# %%
img_width = 640             # 사진의 너비
img_height = 640            # 사진의 높이

def extract_object(image, bbox, img_width, img_height):
    x_center, y_center, width, height = bbox  # YOLOv5에서 반환된 바운딩 박스 좌표를 픽셀 단위로 변환
    
    # 정규화된 좌표를 이미지 크기에 맞게 변환
    x_center, y_center = int(x_center * img_width), int(y_center * img_height)
    width, height = int(width * img_width), int(height * img_height)
    
    # 좌표를 이미지 크기 안에서 잘라냄
    x1 = max(0, x_center - width // 2)
    y1 = max(0, y_center - height // 2)
    x2 = min(img_width, x_center + width // 2)
    y2 = min(img_height, y_center + height // 2)
    
    # 잘린 좌표가 이미지 크기를 벗어나면 경고 출력
    if x1 >= x2 or y1 >= y2:
        print(f"Warning: Bounding box is out of bounds for image. Using default empty image.")
        return np.zeros((100, 100, 3), dtype=np.uint8)  # 기본값으로 빈 이미지 반환
    
    # 이미지에서 객체 영역을 잘라냄
    cropped_image = image[y1:y2, x1:x2]
    
    return cropped_image
# YOLOv5 모델 추론 후 결과 필터링
def process_detections(image, detections, img_width, img_height):
    top_images = []
    bottom_images = []
    accessory_images = []

    for det in detections:
        # detections의 형식: [class, x_center, y_center, width, height, confidence]
        class_id, bbox = int(det[0]), det[1:5]
        
        if class_id == 0:  # 상의
            top_images.append(extract_object(image, bbox, img_width, img_height))
        elif class_id == 1:  # 하의
            bottom_images.append(extract_object(image, bbox, img_width, img_height))
        elif class_id == 2:  # 악세사리
            accessory_images.append(extract_object(image, bbox, img_width, img_height))
    
    return top_images, bottom_images, accessory_images

# %%
def image_to_rgb_vectors(image):
    if image is None or image.size == 0:
        return None, None, None  # 이미지가 비어 있으면 None 반환

    # 이미지 크기를 100x100으로 고정
    image_resized = cv2.resize(image, (100, 100))
    
    # 각 채널(R, G, B) 분리
    r_channel = image_resized[:, :, 0].flatten()  # R 채널을 1차원 벡터로 변환
    g_channel = image_resized[:, :, 1].flatten()  # G 채널을 1차원 벡터로 변환
    b_channel = image_resized[:, :, 2].flatten()  # B 채널을 1차원 벡터로 변환

    return r_channel, g_channel, b_channel

# %%
# detections => 우리가 라벨링한 파일 = bbox
def load_detections_from_label_file(label_file_path):
    detections = []
    with open(label_file_path, 'r') as f:
        for line in f:
            parts = line.strip().split()
            class_id = int(parts[0])
            x_center = float(parts[1])
            y_center = float(parts[2])
            width = float(parts[3])
            height = float(parts[4])
            detections.append([class_id, x_center, y_center, width, height])
    return detections

# 예시 라벨 파일 경로
label_file_path = bbox_path

# 라벨 파일에서 `detections` 정보를 불러오기
detections = load_detections_from_label_file(label_file_path)


# 감지된 객체들을 벡터화하여 각 세트에 저장
def process_image_sets(image, detections, img_width, img_height):
    # 감지된 객체 분류
    top_images, bottom_images, accessory_images = process_detections(image, detections, img_width, img_height)

    # 벡터 저장을 위한 딕셔너리 초기화
    image_sets = {
        'upper_body': [image_to_rgb_vectors(img) for img in top_images],
        'lower_body': [image_to_rgb_vectors(img) for img in bottom_images],
        'accessory': [image_to_rgb_vectors(img) for img in accessory_images]
    }
    
    return image_sets

# 각 세트의 상의, 하의, 악세사리 벡터를 저장할 딕셔너리
image_sets = {}

# 예시: 여러 세트의 상의, 하의, 악세사리 이미지 파일 경로
sets = [
    {'upper_body': 'upper_body_image_1.jpg', 'lower_body': 'lower_body_image_1.jpg', 'accessory': 'accessory_image_1.jpg'},
    {'upper_body': 'upper_body_image_2.jpg', 'lower_body': 'lower_body_image_2.jpg', 'accessory': 'accessory_image_2.jpg'},
    # 추가 이미지 세트
]

# %%
# 테스트 이미지와 감지 결과로부터 상의, 하의, 악세사리 벡터 생성
image_file = image_path
image = cv2.imread(image_file)
img_height, img_width = image.shape[:2]
image_sets = process_image_sets(image, detections, img_width, img_height)

# 결과 확인
print(image_sets)
# Out:
# {'upper_body': [(array([238, 238, 238, ...,   7,  10,  14], dtype=uint8), array([239, 239, 239, ...,   7,  10,  14], dtype=uint8), array([237, 237, 237, ...,   7,  10,  14], dtype=uint8))], 'lower_body': [(array([209, 214, 200, ..., 127, 127, 118], dtype=uint8), array([202, 207, 193, ..., 115, 117, 112], dtype=uint8), array([199, 205, 191, ..., 101, 106, 102], dtype=uint8))], 'accessory': [(array([ 99, 100, 104, ...,  97, 102, 103], dtype=uint8), array([ 96,  97, 101, ..., 111, 116, 117], dtype=uint8), array([ 92,  93,  97, ..., 111, 115, 116], dtype=uint8)), (array([111, 117, 125, ..., 174, 172, 171], dtype=uint8), array([112, 117, 123, ..., 191, 189, 188], dtype=uint8), array([103, 108, 113, ..., 188, 186, 185], dtype=uint8))]}

# %%
# 예시(원본)
# # 모든 이미지와 라벨 파일을 처리하여 저장할 딕셔너리
# all_image_sets = {}

# # 이미지 파일과 라벨 파일 목록 불러오기
# image_files = os.listdir(image_dir)
# label_files = os.listdir(label_dir)

# # 각 이미지와 해당 라벨 파일을 처리
# for image_file in image_files:
#     # 이미지 경로 및 파일명 설정
#     image_path = os.path.join(image_dir, image_file)
#     label_file = image_file.replace('.jpg', '.txt')  # 이미지 파일명과 라벨 파일명 맞추기
#     label_path = os.path.join(label_dir, label_file)

#     # 이미지와 라벨 파일이 모두 존재할 때만 처리
#     if os.path.exists(label_path):
#         # 이미지 로드 및 크기 확인
#         image = cv2.imread(image_path)
#         if image is None:
#             print(f"Error: Could not load image {image_path}")
#             continue
        
#         img_height, img_width = image.shape[:2]

#         # 라벨 파일에서 바운딩 박스 정보 로드
#         detections = load_detections_from_label_file(label_path)

#         # 각 이미지의 객체를 벡터화하여 저장
#         image_vectors = process_image_sets(image, detections, img_width, img_height)

#         # 고유 키를 파일명으로 설정하여 딕셔너리에 저장  => 가독성이 떨어지긴 하는데
#         all_image_sets[image_file] = image_vectors

# # 전체 결과 확인
# for image_name, vectors in all_image_sets.items():
#     print(f"Image: {image_name}")
#     print("Upper Body Vectors:", vectors['upper_body'])
#     print("Lower Body Vectors:", vectors['lower_body'])
#     print("Accessory Vectors:", vectors['accessory'])
#     print("\n")

# %% [markdown]
# ##### train

# %%
image_dir = "./Crawling2-2/train/images"
label_dir = "./Crawling2-2/train/labels"

# 모든 이미지와 라벨 파일을 처리하여 저장할 딕셔너리
train_image_sets = {}

# 이미지 파일과 라벨 파일 목록 불러오기
image_files = os.listdir(image_dir)
label_files = os.listdir(label_dir)

# 각 이미지와 해당 라벨 파일을 처리
for image_file in image_files:
    # 이미지 경로 및 파일명 설정
    image_path = os.path.join(image_dir, image_file)
    label_file = image_file.replace('.jpg', '.txt')  # 이미지 파일명과 라벨 파일명 맞추기
    label_path = os.path.join(label_dir, label_file)

    # 이미지와 라벨 파일이 모두 존재할 때만 처리
    if os.path.exists(label_path):
        # 이미지 로드 및 크기 확인
        image = cv2.imread(image_path)
        if image is None:
            print(f"Error: Could not load image {image_path}")
            continue
        
        img_height, img_width = image.shape[:2]

        # 라벨 파일에서 바운딩 박스 정보 로드
        detections = load_detections_from_label_file(label_path)

        # 각 이미지의 객체를 벡터화하여 저장
        image_vectors = process_image_sets(image, detections, img_width, img_height)

        # 고유 키를 파일명으로 설정하여 딕셔너리에 저장  => 가독성이 떨어지긴 하는데
        train_image_sets[image_file] = image_vectors

# 전체 결과 확인
for image_name, vectors in train_image_sets.items():
    print(f"Image: {image_name}")
    print("Upper Body Vectors:", vectors['upper_body'])
    print("Lower Body Vectors:", vectors['lower_body'])
    print("Accessory Vectors:", vectors['accessory'])
    print("\n")
# Out:
# Warning: Bounding box is out of bounds for image. Using default empty image.
# Image: image_1001_jpg.rf.7e10c26e11be6c0f91af1cc4b6939314.jpg
# Upper Body Vectors: [(array([169, 168, 171, ..., 152, 148, 149], dtype=uint8), array([197, 197, 198, ..., 176, 175, 175], dtype=uint8), array([202, 202, 195, ..., 196, 194, 197], dtype=uint8))]
# Lower Body Vectors: [(array([168, 167, 160, ..., 124, 135, 137], dtype=uint8), array([153, 153, 144, ..., 107, 119, 126], dtype=uint8), array([137, 135, 127, ...,  83,  99, 111], dtype=uint8))]
# Accessory Vectors: [(array([144, 144, 145, ...,  19,  19,  19], dtype=uint8), array([149, 149, 150, ...,  20,  20,  20], dtype=uint8), array([148, 148, 149, ...,  16,  17,  18], dtype=uint8)), (array([120, 117, 113, ..., 166, 166, 167], dtype=uint8), array([100,  98,  96, ..., 151, 150, 150], dtype=uint8), array([ 75,  73,  70, ..., 132, 131, 131], dtype=uint8))]
#
#
# Image: image_1002_jpg.rf.ce2d9d012308af8427470a4e2da5718a.jpg
# Upper Body Vectors: [(array([69, 52, 42, ..., 32, 35, 37], dtype=uint8), array([72, 55, 45, ..., 35, 39, 42], dtype=uint8), array([79, 60, 50, ..., 39, 42, 45], dtype=uint8))]
# Lower Body Vectors: [(array([202, 203, 198, ..., 110, 185, 231], dtype=uint8), array([206, 207, 202, ..., 115, 195, 245], dtype=uint8), array([207, 208, 203, ..., 120, 201, 247], dtype=uint8))]
# Accessory Vectors: [(array([54, 69, 86, ..., 19, 19, 19], dtype=uint8), array([46, 62, 78, ..., 19, 19, 19], dtype=uint8), array([46, 62, 78, ..., 19, 19, 19], dtype=uint8)), (array([250, 249, 249, ..., 227, 228, 228], dtype=uint8), array([250, 249, 246, ..., 224, 224, 225], dtype=uint8), array([244, 243, 241, ..., 219, 220, 220], dtype=uint8)), (array([ 18,  13,  14, ..., 227, 227, 227], dtype=uint8), array([ 16,  11,  12, ..., 229, 229, 229], dtype=uint8), array([ 15,  10,  11, ..., 229, 229, 229], dtype=uint8))]
#
#
# Image: image_1003_jpg.rf.fe7b5b6ef29fd8f941965bf62fbcd8f2.jpg
# Upper Body Vectors: [(array([252, 245, 221, ...,   1,   2,  12], dtype=uint8), array([249, 242, 215, ...,   1,   2,  12], dtype=uint8), array([245, 237, 211, ...,   1,   2,  12], dtype=uint8))]
# Lower Body Vectors: [(array([248, 217, 199, ..., 219, 219, 219], dtype=uint8), array([246, 213, 195, ..., 222, 222, 222], dtype=uint8), array([248, 218, 199, ..., 220, 220, 220], dtype=uint8))]
# Accessory Vectors: [(array([239, 239, 239, ..., 185, 186, 188], dtype=uint8), array([240, 240, 240, ..., 190, 191, 191], dtype=uint8), array([238, 238, 238, ..., 188, 189, 189], dtype=uint8)), (array([225, 221, 222, ..., 109, 117, 125], dtype=uint8), array([210, 206, 207, ..., 107, 114, 123], dtype=uint8), array([207, 203, 205, ..., 106, 113, 122], dtype=uint8)), (array([  5,   5,   5, ..., 218, 218, 218], dtype=uint8), array([  6,   6,   6, ..., 220, 220, 220], dtype=uint8), array([  2,   2,   2, ..., 220, 220, 220], dtype=uint8))]
#
#
# Image: image_1006_jpg.rf.486bad32dc82587f0ea616bfd672db18.jpg
# Upper Body Vectors: [(array([190, 183, 175, ...,  81,  78,  77], dtype=uint8), array([186, 177, 169, ...,  92,  90,  90], dtype=uint8), array([217, 212, 207, ..., 142, 136, 135], dtype=uint8))]
# Lower Body Vectors: [(array([ 64,  61,  59, ...,  50,  83, 137], dtype=uint8), array([ 74,  71,  69, ...,  63,  95, 146], dtype=uint8), array([108, 106, 104, ...,  77, 108, 159], dtype=uint8))]
# Accessory Vectors: [(array([210, 201, 193, ...,  65,  65,  65], dtype=uint8), array([232, 221, 212, ..., 104, 104, 104], dtype=uint8), array([238, 229, 221, ..., 179, 180, 182], dtype=uint8))]
#
#
# Image: image_1008_jpg.rf.7500fc46489e141ee6c7458c6b01d697.jpg
# Upper Body Vectors: [(array([127, 112,  82, ..., 179, 208, 147], dtype=uint8), array([128, 109,  80, ..., 168, 199, 140], dtype=uint8), array([125, 108,  78, ..., 169, 201, 143], dtype=uint8))]
# Lower Body Vectors: [(array([ 62,  67, 115, ..., 150, 168, 201], dtype=uint8), array([ 44,  50, 100, ..., 149, 167, 201], dtype=uint8), array([ 41,  48,  99, ..., 151, 169, 202], dtype=uint8))]
# Accessory Vectors: [(array([199, 202, 210, ..., 158, 156, 155], dtype=uint8), array([209, 212, 219, ..., 169, 167, 166], dtype=uint8), array([209, 212, 219, ..., 177, 175, 174], dtype=uint8)), (array([114, 124, 118, ..., 103, 103, 103], dtype=uint8), array([121, 131, 123, ..., 113, 113, 113], dtype=uint8), array([124, 134, 126, ..., 123, 123, 123], dtype=uint8))]
#
#
# Image: image_1009_jpg.rf.d1db9ec4f0d81f464424ec188e12768c.jpg
# Upper Body Vectors: [(array([213, 213, 167, ...,  18,  89, 151], dtype=uint8), array([203, 202, 152, ...,  10,  83, 146], dtype=uint8), array([193, 191, 146, ...,  10,  84, 148], dtype=uint8))]
# Lower Body Vectors: [(array([253, 252, 253, ..., 220, 220, 221], dtype=uint8), array([252, 251, 252, ..., 218, 218, 219], dtype=uint8), array([254, 253, 254, ..., 208, 208, 209], dtype=uint8))]
# Accessory Vectors: [(array([50, 66, 74, ..., 41, 39, 38], dtype=uint8), array([64, 77, 83, ..., 75, 74, 73], dtype=uint8), array([ 83,  94,  98, ..., 116, 117, 117], dtype=uint8)), (array([124, 126, 130, ...,  76,  55,  35], dtype=uint8), array([123, 124, 126, ...,  84,  65,  46], dtype=uint8), array([127, 128, 131, ..., 101,  83,  66], dtype=uint8))]
#
#
# Image: image_100_jpg.rf.b98b3bb89110a69c55ebfa5458fcefa4.jpg
# Upper Body Vectors: [(array([168, 149, 134, ..., 133, 133, 133], dtype=uint8), array([196, 178, 163, ..., 162, 163, 163], dtype=uint8), array([201, 182, 167, ..., 167, 168, 168], dtype=uint8))]
# Lower Body Vectors: [(array([12, 18, 27, ..., 25, 24, 22], dtype=uint8), array([15, 21, 29, ..., 25, 24, 24], dtype=uint8), array([19, 21, 30, ..., 25, 24, 25], dtype=uint8))]
# Accessory Vectors: [(array([114, 113, 111, ...,  50,  50,  50], dtype=uint8), array([150, 151, 153, ...,  59,  59,  59], dtype=uint8), array([160, 160, 160, ...,  63,  62,  62], dtype=uint8)), (array([140, 137, 154, ..., 176, 179, 182], dtype=uint8), array([172, 171, 188, ..., 212, 215, 218], dtype=uint8), array([178, 177, 194, ..., 220, 223, 226], dtype=uint8))]
#
#
# Image: image_1010_jpg.rf.d404fcaf27cc5ecaf0befefb7360a4d1.jpg
# Upper Body Vectors: [(array([149, 133, 105, ..., 193, 190, 200], dtype=uint8), array([151, 131,  99, ..., 188, 182, 192], dtype=uint8), array([149, 130,  99, ..., 186, 181, 191], dtype=uint8))]
# Lower Body Vectors: [(array([ 62, 148, 165, ..., 110, 106, 105], dtype=uint8), array([ 65, 148, 163, ..., 116, 112, 111], dtype=uint8), array([ 74, 153, 165, ..., 119, 118, 116], dtype=uint8))]
# Accessory Vectors: [(array([129, 129, 129, ..., 149, 151, 152], dtype=uint8), array([146, 146, 146, ..., 163, 166, 167], dtype=uint8), array([149, 149, 149, ..., 167, 169, 170], dtype=uint8)), (array([169, 174, 183, ..., 132, 135, 137], dtype=uint8), array([164, 168, 174, ..., 139, 140, 141], dtype=uint8), array([161, 165, 171, ..., 142, 144, 146], dtype=uint8)), (array([105, 106, 112, ...,  24,  24,  24], dtype=uint8), array([ 95,  96, 101, ...,  26,  27,  27], dtype=uint8), array([ 95,  96, 102, ...,  24,  25,  25], dtype=uint8)), (array([14, 14, 13, ..., 14, 16, 16], dtype=uint8), array([12, 12, 11, ..., 12, 14, 14], dtype=uint8), array([12, 12, 11, ..., 11, 13, 13], dtype=uint8))]
#
#
# Image: image_1012_jpg.rf.c073e9893edc9f0ba9fa74e750b544dc.jpg
# Upper Body Vectors: [(array([183, 183, 183, ..., 158, 159, 160], dtype=uint8), array([187, 187, 187, ..., 163, 162, 162], dtype=uint8), array([188, 188, 188, ..., 159, 160, 164], dtype=uint8))]
# Lower Body Vectors: [(array([ 42,  49,  53, ..., 234, 230, 223], dtype=uint8), array([ 48,  55,  59, ..., 231, 227, 220], dtype=uint8), array([ 83,  91,  96, ..., 227, 223, 216], dtype=uint8))]
# Accessory Vectors: [(array([185, 185, 185, ..., 176, 176, 176], dtype=uint8), array([187, 187, 187, ..., 179, 179, 179], dtype=uint8), array([187, 187, 187, ..., 177, 177, 177], dtype=uint8)), (array([233, 222, 211, ..., 140, 140, 141], dtype=uint8), array([231, 220, 209, ..., 141, 141, 142], dtype=uint8), array([230, 219, 208, ..., 139, 139, 140], dtype=uint8)), (array([132, 124,  86, ..., 160, 156, 152], dtype=uint8), array([130, 121,  82, ..., 163, 159, 155], dtype=uint8), array([129, 120,  81, ..., 161, 156, 153], dtype=uint8))]
#
#
# Image: image_1013_jpg.rf.ff35916aa2f838a4368d04850f7b9293.jpg
# Upper Body Vectors: [(array([204, 204, 203, ..., 223, 223, 224], dtype=uint8), array([210, 210, 209, ..., 224, 224, 225], dtype=uint8), array([209, 209, 208, ..., 222, 222, 223], dtype=uint8))]
# Lower Body Vectors: [(array([ 91, 119,  95, ...,  43,  32,  27], dtype=uint8), array([102, 129, 102, ...,  39,  28,  22], dtype=uint8), array([125, 153, 125, ...,  38,  26,  19], dtype=uint8))]
# Accessory Vectors: [(array([138, 139, 142, ..., 194, 193, 193], dtype=uint8), array([140, 141, 144, ..., 194, 193, 193], dtype=uint8), array([140, 141, 144, ..., 188, 187, 187], dtype=uint8)), (array([  3,   0,   1, ..., 213, 214, 217], dtype=uint8), array([  3,   1,   2, ..., 210, 211, 214], dtype=uint8), array([  2,   0,   1, ..., 206, 207, 210], dtype=uint8))]
#
#
# Image: image_1014_jpg.rf.271b3dcd399fc1e9780035cbdbc8e421.jpg
# Upper Body Vectors: [(array([196, 195, 192, ...,  87,  58,  32], dtype=uint8), array([225, 224, 221, ...,  88,  58,  32], dtype=uint8), array([246, 245, 244, ...,  80,  51,  26], dtype=uint8))]
# Lower Body Vectors: [(array([178, 175, 176, ..., 194, 188, 185], dtype=uint8), array([164, 161, 163, ..., 191, 185, 182], dtype=uint8), array([145, 142, 142, ..., 187, 181, 178], dtype=uint8))]
# Accessory Vectors: [(array([191, 191, 194, ..., 142, 132, 130], dtype=uint8), array([178, 178, 181, ..., 152, 142, 140], dtype=uint8), array([156, 156, 158, ..., 169, 159, 157], dtype=uint8)), (array([151, 151, 151, ...,  77,  77,  77], dtype=uint8), array([143, 143, 143, ...,  81,  81,  81], dtype=uint8), array([136, 136, 136, ...,  86,  86,  86], dtype=uint8))]
#
#
# Image: image_1015_jpg.rf.f08c1d5e59414bf65e41ad5e3c91ea77.jpg
# Upper Body Vectors: [(array([211, 211, 212, ...,  34,  38,  54], dtype=uint8), array([212, 212, 213, ...,  30,  34,  49], dtype=uint8), array([210, 210, 211, ...,  29,  33,  48], dtype=uint8))]
# Lower Body Vectors: [(array([221, 162,  15, ...,  62,  66, 103], dtype=uint8), array([219, 160,  13, ...,  57,  62, 101], dtype=uint8), array([218, 159,  13, ...,  56,  61, 100], dtype=uint8))]
# Accessory Vectors: []
#
#
# Image: image_1017_jpg.rf.8b333d8daf7a0b65faff6230db323cd3.jpg
# Upper Body Vectors: [(array([167, 171, 174, ...,  48,  58,  61], dtype=uint8), array([158, 162, 166, ...,  50,  59,  63], dtype=uint8), array([149, 152, 159, ...,  52,  67,  76], dtype=uint8))]
# Lower Body Vectors: [(array([107, 109, 106, ..., 138, 143, 142], dtype=uint8), array([113, 114, 112, ..., 148, 154, 155], dtype=uint8), array([112, 115, 114, ..., 155, 158, 157], dtype=uint8))]
# Accessory Vectors: [(array([ 88,  87,  86, ..., 127, 128, 129], dtype=uint8), array([ 91,  90,  89, ..., 142, 143, 144], dtype=uint8), array([ 89,  88,  87, ..., 145, 146, 147], dtype=uint8)), (array([133, 134, 136, ..., 123, 123, 129], dtype=uint8), array([148, 148, 149, ..., 135, 135, 141], dtype=uint8), array([150, 150, 151, ..., 138, 139, 145], dtype=uint8))]
#
#
# Image: image_1018_jpg.rf.81877aaf89ee67951979cd205efaf7d3.jpg
# Upper Body Vectors: [(array([127, 126, 124, ...,  15,  13,  10], dtype=uint8), array([188, 188, 185, ...,  15,  13,  12], dtype=uint8), array([237, 237, 233, ...,  21,  19,  21], dtype=uint8))]
# Lower Body Vectors: [(array([ 67,  35,   9, ..., 111, 101, 101], dtype=uint8), array([103,  58,  15, ..., 136, 127, 128], dtype=uint8), array([123,  77,  29, ..., 153, 148, 149], dtype=uint8))]
# Accessory Vectors: [(array([ 2,  1,  0, ..., 94, 92, 90], dtype=uint8), array([ 10,   9,   7, ..., 117, 115, 113], dtype=uint8), array([ 17,  15,  14, ..., 134, 131, 129], dtype=uint8)), (array([ 59,  53,  74, ..., 121, 122, 112], dtype=uint8), array([ 78,  72,  95, ..., 149, 150, 140], dtype=uint8), array([ 91,  85, 107, ..., 166, 167, 157], dtype=uint8)), (array([ 20,  20,  20, ..., 122, 122, 123], dtype=uint8), array([ 22,  22,  22, ..., 188, 188, 189], dtype=uint8), array([ 32,  32,  32, ..., 237, 237, 238], dtype=uint8)), (array([ 6,  3,  1, ..., 20, 13, 26], dtype=uint8), array([ 9,  6,  4, ..., 14,  9, 26], dtype=uint8), array([13, 10,  9, ..., 21, 20, 39], dtype=uint8))]
#
#
# Image: image_1019_jpg.rf.c02c2af9dcadfd619f38f634f39db390.jpg
# Upper Body Vectors: [(array([214, 226, 223, ..., 170, 172, 162], dtype=uint8), array([217, 229, 225, ..., 170, 172, 162], dtype=uint8), array([215, 225, 221, ..., 165, 166, 156], dtype=uint8))]
# Lower Body Vectors: [(array([ 62,  60,  57, ..., 108, 111, 106], dtype=uint8), array([ 53,  50,  46, ..., 113, 116, 111], dtype=uint8), array([ 46,  42,  37, ..., 112, 115, 110], dtype=uint8))]
# Accessory Vectors: [(array([ 73,  73,  71, ..., 133, 131, 131], dtype=uint8), array([ 50,  50,  49, ..., 114, 112, 112], dtype=uint8), array([ 36,  36,  36, ..., 106, 104, 104], dtype=uint8)), (array([177, 174, 170, ..., 118, 118, 117], dtype=uint8), array([188, 183, 178, ..., 113, 113, 112], dtype=uint8), array([186, 182, 177, ..., 113, 112, 111], dtype=uint8)), (array([ 31,  33,  36, ..., 106, 108, 115], dtype=uint8), array([ 20,  22,  25, ..., 107, 110, 117], dtype=uint8), array([ 16,  18,  21, ..., 108, 111, 118], dtype=uint8))]
#
#
# Image: image_101_jpg.rf.afcd37dc49d4b23a6ad47a566a5de1a0.jpg
# Upper Body Vectors: [(array([142,  92,  78, ...,  20,  18,  74], dtype=uint8), array([180, 134, 124, ...,  58,  64, 128], dtype=uint8), array([188, 139, 124, ...,  66,  72, 135], dtype=uint8))]
# Lower Body Vectors: [(array([ 50,   5,  10, ..., 237, 216, 207], dtype=uint8), array([ 83,  23,   8, ..., 234, 214, 205], dtype=uint8), array([ 83,  21,   4, ..., 230, 212, 204], dtype=uint8))]
# Accessory Vectors: [(array([188, 186, 186, ..., 145, 149, 150], dtype=uint8), array([189, 187, 187, ..., 150, 154, 155], dtype=uint8), array([173, 171, 171, ..., 149, 153, 154], dtype=uint8)), (array([ 52,  52,  53, ..., 226, 227, 228], dtype=uint8), array([ 47,  47,  48, ..., 221, 222, 223], dtype=uint8), array([ 46,  46,  47, ..., 220, 221, 222], dtype=uint8))]
#
#
# Image: image_1021_jpg.rf.205bdd9418941bf46ff23a7ab402c92c.jpg
# Upper Body Vectors: [(array([189, 184, 186, ...,  37,  30,  26], dtype=uint8), array([191, 186, 187, ...,  40,  33,  29], dtype=uint8), array([192, 187, 189, ...,  44,  38,  34], dtype=uint8))]
# Lower Body Vectors: [(array([155, 155, 150, ...,  61,  65,  68], dtype=uint8), array([160, 160, 155, ...,  64,  68,  71], dtype=uint8), array([159, 159, 154, ...,  68,  72,  75], dtype=uint8))]
# Accessory Vectors: [(array([82, 80, 77, ..., 64, 62, 63], dtype=uint8), array([86, 84, 81, ..., 73, 71, 74], dtype=uint8), array([92, 89, 86, ..., 76, 74, 77], dtype=uint8)), (array([83, 84, 84, ..., 63, 67, 70], dtype=uint8), array([86, 87, 87, ..., 68, 72, 75], dtype=uint8), array([90, 91, 91, ..., 71, 75, 78], dtype=uint8)), (array([ 10,   8,   6, ..., 170, 164, 155], dtype=uint8), array([  9,   9,   8, ..., 169, 163, 154], dtype=uint8), array([ 11,  10,  10, ..., 171, 165, 156], dtype=uint8))]
#
#
# Image: image_1024_jpg.rf.348c16b366227867d6f2973a50bebf0a.jpg
# Upper Body Vectors: [(array([156, 156, 156, ..., 163, 163, 163], dtype=uint8), array([160, 160, 160, ..., 163, 163, 163], dtype=uint8), array([161, 161, 161, ..., 163, 163, 163], dtype=uint8))]
# Lower Body Vectors: [(array([176, 182, 176, ...,  85,  84,  84], dtype=uint8), array([174, 180, 174, ...,  89,  88,  88], dtype=uint8), array([174, 180, 174, ...,  90,  89,  89], dtype=uint8))]
# Accessory Vectors: [(array([91, 86, 81, ..., 27, 28, 29], dtype=uint8), array([109, 105, 102, ...,  36,  37,  38], dtype=uint8), array([126, 122, 120, ...,  45,  46,  47], dtype=uint8))]
#
#
# Image: image_1025_jpg.rf.664aa72084f58a2d4f68243b1450cd6b.jpg
# Upper Body Vectors: [(array([240, 220, 169, ...,  64,  71,  84], dtype=uint8), array([236, 216, 165, ...,  62,  69,  82], dtype=uint8), array([241, 220, 169, ...,  62,  69,  82], dtype=uint8))]
# Lower Body Vectors: [(array([ 57,  49,  51, ..., 132, 165, 201], dtype=uint8), array([ 55,  47,  49, ..., 130, 163, 199], dtype=uint8), array([ 55,  47,  49, ..., 130, 163, 199], dtype=uint8))]
# Accessory Vectors: [(array([200, 200, 199, ..., 180, 180, 180], dtype=uint8), array([198, 198, 197, ..., 176, 176, 176], dtype=uint8), array([204, 204, 203, ..., 182, 182, 182], dtype=uint8)), (array([ 10,  10,  10, ..., 197, 201, 203], dtype=uint8), array([  8,   8,   8, ..., 195, 199, 201], dtype=uint8), array([  7,   7,   7, ..., 201, 205, 207], dtype=uint8))]
#
#
# Image: image_1028_jpg.rf.238b1140dd39df3132ee8e0df71b4fbb.jpg
# Upper Body Vectors: [(array([186, 165, 142, ..., 192, 197, 191], dtype=uint8), array([187, 167, 143, ..., 194, 199, 193], dtype=uint8), array([185, 165, 142, ..., 198, 203, 197], dtype=uint8))]
# Lower Body Vectors: [(array([201, 210, 214, ...,  73,  72,  75], dtype=uint8), array([197, 202, 205, ...,  64,  63,  67], dtype=uint8), array([200, 203, 206, ...,  55,  54,  57], dtype=uint8))]
# Accessory Vectors: [(array([ 68,  72,  79, ..., 108,  97,  90], dtype=uint8), array([56, 60, 67, ..., 96, 85, 80], dtype=uint8), array([50, 54, 61, ..., 86, 75, 70], dtype=uint8)), (array([32, 32, 33, ..., 81, 86, 90], dtype=uint8), array([13, 13, 14, ..., 70, 77, 81], dtype=uint8), array([ 8,  8,  9, ..., 56, 63, 67], dtype=uint8)), (array([242, 227, 205, ..., 164, 165, 166], dtype=uint8), array([245, 230, 208, ..., 166, 168, 169], dtype=uint8), array([230, 215, 193, ..., 206, 207, 207], dtype=uint8))]
#
#
# Image: image_1031_jpg.rf.af69796f76acc897a5ce7bde1c1e690e.jpg
# Upper Body Vectors: [(array([190, 201, 179, ...,  12,  12,  14], dtype=uint8), array([200, 210, 186, ...,   7,   7,   9], dtype=uint8), array([207, 215, 190, ...,   5,   4,   6], dtype=uint8))]
# Lower Body Vectors: [(array([133, 111,  80, ...,  34,  94, 118], dtype=uint8), array([134, 111,  80, ...,  31,  91, 116], dtype=uint8), array([138, 113,  81, ...,  28,  87, 112], dtype=uint8))]
# Accessory Vectors: [(array([66, 66, 60, ..., 51, 52, 52], dtype=uint8), array([65, 65, 58, ..., 55, 56, 56], dtype=uint8), array([81, 81, 74, ..., 66, 67, 67], dtype=uint8)), (array([107, 107, 109, ...,  15,  15,  15], dtype=uint8), array([107, 107, 109, ...,  16,  16,  16], dtype=uint8), array([131, 131, 132, ...,  12,  12,  12], dtype=uint8))]
#
#
# Image: image_1032_jpg.rf.72a88e37bda050611c56ed5c335663ed.jpg
# Upper Body Vectors: [(array([ 6,  5,  7, ..., 27, 18, 27], dtype=uint8), array([ 8,  7,  9, ..., 32, 23, 32], dtype=uint8), array([ 8,  7,  9, ..., 33, 24, 33], dtype=uint8))]
# Lower Body Vectors: [(array([113, 125, 120, ..., 228, 242, 216], dtype=uint8), array([119, 131, 128, ..., 223, 238, 213], dtype=uint8), array([124, 137, 135, ..., 220, 237, 212], dtype=uint8))]
# Accessory Vectors: [(array([  3,   2,   1, ..., 109, 107, 106], dtype=uint8), array([  3,   3,   3, ..., 122, 120, 119], dtype=uint8), array([  3,   3,   3, ..., 120, 118, 117], dtype=uint8)), (array([ 87,  97, 112, ...,  44,  49,  53], dtype=uint8), array([ 91, 101, 116, ...,  60,  64,  67], dtype=uint8), array([ 92, 102, 117, ...,  59,  63,  66], dtype=uint8)), (array([14, 14, 10, ..., 92, 90, 90], dtype=uint8), array([ 13,  13,   9, ..., 118, 116, 116], dtype=uint8), array([ 17,  17,  13, ..., 172, 170, 170], dtype=uint8))]
#
#
# Image: image_1033_jpg.rf.6156cf97a01aa645d78fc27f64c9bfd8.jpg
# Upper Body Vectors: [(array([88, 74, 93, ..., 43, 38, 33], dtype=uint8), array([111,  94, 111, ...,  39,  34,  29], dtype=uint8), array([127, 108, 124, ...,  38,  33,  28], dtype=uint8))]
# Lower Body Vectors: [(array([ 4, 10, 30, ..., 17, 17, 17], dtype=uint8), array([11, 17, 38, ..., 18, 18, 18], dtype=uint8), array([31, 38, 59, ..., 16, 16, 16], dtype=uint8))]
# Accessory Vectors: [(array([ 8,  8,  9, ..., 62, 67, 71], dtype=uint8), array([11, 11, 12, ..., 73, 77, 84], dtype=uint8), array([ 9,  9, 10, ..., 81, 87, 93], dtype=uint8))]
#
#
# Image: image_1034_jpg.rf.53925bbf21e09ba918852493ad987aee.jpg
# Upper Body Vectors: [(array([ 63, 103, 154, ...,  72, 119, 107], dtype=uint8), array([ 99, 128, 172, ...,  84, 133, 123], dtype=uint8), array([ 93, 125, 171, ...,  92, 143, 132], dtype=uint8))]
# Lower Body Vectors: [(array([119, 130, 134, ...,  89,  85,  83], dtype=uint8), array([129, 142, 147, ..., 101, 101, 102], dtype=uint8), array([186, 206, 216, ...,  98,  97,  97], dtype=uint8))]
# Accessory Vectors: [(array([46, 50, 56, ..., 82, 75, 71], dtype=uint8), array([ 71,  75,  81, ..., 105,  99,  95], dtype=uint8), array([ 87,  91,  97, ..., 126, 121, 117], dtype=uint8)), (array([121, 122, 124, ..., 246, 246, 247], dtype=uint8), array([139, 140, 142, ..., 254, 254, 255], dtype=uint8), array([150, 151, 153, ..., 253, 253, 254], dtype=uint8))]
#
#
# Image: image_1035_jpg.rf.f30be9a493d658c87f6454c36c1629b4.jpg
# Upper Body Vectors: [(array([19, 13, 51, ..., 30, 55, 83], dtype=uint8), array([18, 11, 48, ..., 18, 43, 71], dtype=uint8), array([17, 10, 44, ..., 14, 39, 67], dtype=uint8))]
# Lower Body Vectors: [(array([30, 35, 34, ..., 52, 44, 41], dtype=uint8), array([22, 27, 25, ..., 39, 31, 28], dtype=uint8), array([22, 27, 25, ..., 37, 29, 26], dtype=uint8))]
# Accessory Vectors: [(array([101, 102, 107, ...,  54,  53,  53], dtype=uint8), array([ 98,  99, 102, ...,  53,  52,  52], dtype=uint8), array([90, 91, 95, ..., 57, 56, 56], dtype=uint8)), (array([240, 240, 240, ..., 173, 175, 175], dtype=uint8), array([225, 225, 225, ..., 168, 170, 170], dtype=uint8), array([216, 216, 216, ..., 170, 172, 172], dtype=uint8))]
#
#
# Image: image_1036_jpg.rf.37507a5c7b1b32e9af58ba448db410f6.jpg
# Upper Body Vectors: [(array([ 20,  19,  17, ..., 132, 125, 115], dtype=uint8), array([ 21,  21,  21, ..., 136, 128, 117], dtype=uint8), array([ 17,  16,  16, ..., 170, 170, 162], dtype=uint8))]
# Lower Body Vectors: [(array([ 86,  85,  82, ..., 134, 138, 139], dtype=uint8), array([ 86,  85,  82, ..., 140, 144, 145], dtype=uint8), array([102, 101, 100, ..., 135, 139, 140], dtype=uint8))]
# Accessory Vectors: [(array([ 86,  43,  71, ..., 102, 101, 100], dtype=uint8), array([ 86,  42,  70, ..., 112, 112, 111], dtype=uint8), array([ 87,  44,  72, ..., 117, 116, 115], dtype=uint8)), (array([  0,  34,  86, ..., 190, 195, 199], dtype=uint8), array([  4,  40,  91, ..., 185, 190, 195], dtype=uint8), array([  3,  40,  93, ..., 184, 189, 193], dtype=uint8)), (array([18,  9, 19, ..., 24, 22, 25], dtype=uint8), array([22, 13, 21, ..., 18, 22, 25], dtype=uint8), array([23, 14, 22, ..., 19, 22, 25], dtype=uint8)), (array([ 62,  60,  57, ..., 190, 190, 191], dtype=uint8), array([ 68,  66,  63, ..., 194, 193, 193], dtype=uint8), array([ 75,  73,  70, ..., 223, 223, 223], dtype=uint8)), (array([94, 94, 92, ..., 85, 83, 83], dtype=uint8), array([98, 98, 96, ..., 87, 85, 85], dtype=uint8), array([127, 127, 125, ..., 111, 109, 109], dtype=uint8))]
#
#
# Image: image_1037_jpg.rf.ea568c561dbc3f979008a269f7be02ae.jpg
# Upper Body Vectors: [(array([102,  93,  89, ..., 107,  86,  78], dtype=uint8), array([106,  97,  93, ...,  99,  78,  70], dtype=uint8), array([107,  98,  93, ...,  92,  71,  61], dtype=uint8))]
# Lower Body Vectors: [(array([42, 41, 39, ..., 27, 32, 36], dtype=uint8), array([51, 50, 48, ..., 24, 30, 35], dtype=uint8), array([55, 54, 52, ..., 33, 40, 44], dtype=uint8))]
# Accessory Vectors: [(array([176, 181, 185, ..., 113, 106,  81], dtype=uint8), array([169, 174, 178, ..., 118, 111,  86], dtype=uint8), array([160, 165, 169, ..., 116, 109,  84], dtype=uint8)), (array([112,  91,  77, ..., 123, 120, 122], dtype=uint8), array([106,  85,  70, ..., 121, 118, 120], dtype=uint8), array([101,  81,  66, ..., 121, 118, 120], dtype=uint8)), (array([82, 82, 82, ..., 36, 39, 39], dtype=uint8), array([78, 78, 78, ..., 40, 42, 42], dtype=uint8), array([77, 77, 77, ..., 43, 46, 46], dtype=uint8))]
#
#
# Image: image_1039_jpg.rf.39ce25ec42c9fe4c95f533a9291983e7.jpg
# Upper Body Vectors: [(array([211, 211, 211, ..., 206, 204, 207], dtype=uint8), array([212, 212, 212, ..., 207, 205, 208], dtype=uint8), array([210, 210, 210, ..., 205, 203, 206], dtype=uint8))]
# Lower Body Vectors: [(array([208, 208, 206, ..., 151, 149, 144], dtype=uint8), array([209, 209, 207, ..., 156, 154, 149], dtype=uint8), array([205, 205, 203, ..., 155, 153, 148], dtype=uint8))]
# Accessory Vectors: [(array([219, 220, 220, ..., 123, 123, 122], dtype=uint8), array([224, 225, 225, ..., 125, 125, 124], dtype=uint8), array([223, 224, 224, ..., 125, 125, 124], dtype=uint8)), (array([165, 154, 159, ..., 124, 125, 125], dtype=uint8), array([167, 156, 160, ..., 129, 130, 130], dtype=uint8), array([167, 156, 160, ..., 128, 129, 129], dtype=uint8)), (array([130, 133, 127, ..., 179, 181, 183], dtype=uint8), array([132, 135, 129, ..., 177, 177, 178], dtype=uint8), array([132, 135, 129, ..., 177, 178, 179], dtype=uint8))]
#
#
# Image: image_1040_jpg.rf.7809595e7a451ba6d2eb48c27526b9e4.jpg
# Upper Body Vectors: [(array([243, 243, 240, ..., 200, 156,  99], dtype=uint8), array([228, 226, 223, ..., 186, 144,  91], dtype=uint8), array([219, 217, 214, ..., 219, 191, 144], dtype=uint8))]
# Lower Body Vectors: [(array([152, 126, 142, ...,  23,  21,  24], dtype=uint8), array([136, 107, 124, ...,  15,  16,  19], dtype=uint8), array([129, 103, 123, ...,  16,  17,  21], dtype=uint8))]
# Accessory Vectors: [(array([235, 237, 236, ...,  96,  95, 101], dtype=uint8), array([205, 204, 203, ...,  88,  88,  91], dtype=uint8), array([178, 178, 177, ..., 128, 131, 133], dtype=uint8))]
#
#
# Image: image_1041_jpg.rf.daf91b2ecf36146b9a8b10145f20e47d.jpg
# Upper Body Vectors: [(array([167, 167, 168, ...,  66,  78,  86], dtype=uint8), array([177, 178, 178, ...,  64,  76,  84], dtype=uint8), array([177, 178, 178, ...,  64,  76,  84], dtype=uint8))]
# Lower Body Vectors: [(array([ 27,  28,  29, ..., 204, 188, 201], dtype=uint8), array([ 21,  23,  23, ..., 214, 197, 210], dtype=uint8), array([ 22,  24,  24, ..., 224, 206, 218], dtype=uint8))]
# Accessory Vectors: [(array([ 57,  75,  77, ..., 102,  94,  94], dtype=uint8), array([ 72,  92,  94, ..., 118, 109, 106], dtype=uint8), array([108, 130, 133, ..., 125, 116, 112], dtype=uint8))]
#
#
# Image: image_1042_jpg.rf.ea3bfe20207244199fc2e1b0432cbb88.jpg
# Upper Body Vectors: [(array([197, 197, 198, ..., 236, 236, 236], dtype=uint8), array([213, 213, 214, ..., 232, 231, 231], dtype=uint8), array([220, 220, 221, ..., 231, 230, 231], dtype=uint8))]
# Lower Body Vectors: [(array([ 81,  80,  90, ..., 216, 218, 223], dtype=uint8), array([ 81,  79,  89, ..., 205, 208, 213], dtype=uint8), array([ 80,  81,  91, ..., 207, 208, 213], dtype=uint8))]
# Accessory Vectors: [(array([104, 105, 107, ..., 160, 160, 160], dtype=uint8), array([121, 122, 124, ..., 168, 169, 169], dtype=uint8), array([134, 135, 137, ..., 177, 178, 178], dtype=uint8)), (array([126, 118, 117, ..., 166, 168, 168], dtype=uint8), array([128, 120, 120, ..., 169, 172, 173], dtype=uint8), array([136, 128, 125, ..., 179, 181, 182], dtype=uint8))]
#
#
# Image: image_1043_jpg.rf.0b408470e8094ce0cc836548dc363882.jpg
# Upper Body Vectors: [(array([ 52,  49,  50, ..., 114, 109, 107], dtype=uint8), array([ 76,  76,  77, ..., 134, 129, 127], dtype=uint8), array([ 87,  86,  87, ..., 143, 140, 139], dtype=uint8))]
# Lower Body Vectors: [(array([90, 92, 95, ..., 76, 70, 74], dtype=uint8), array([34, 36, 42, ..., 85, 81, 85], dtype=uint8), array([208, 203, 196, ..., 103,  98, 103], dtype=uint8))]
# Accessory Vectors: [(array([  1,   1,   1, ..., 254, 254, 254], dtype=uint8), array([ 20,  20,  20, ..., 254, 254, 254], dtype=uint8), array([ 51,  51,  51, ..., 254, 254, 254], dtype=uint8)), (array([134, 136, 139, ..., 161, 160, 160], dtype=uint8), array([106, 108, 111, ..., 180, 179, 179], dtype=uint8), array([ 89,  91,  94, ..., 201, 200, 200], dtype=uint8)), (array([219, 218, 216, ..., 182, 172, 169], dtype=uint8), array([187, 186, 185, ..., 199, 189, 186], dtype=uint8), array([122, 122, 121, ..., 218, 208, 205], dtype=uint8))]
#
#
# Image: image_1045_jpg.rf.ad93c354ab6a8e51fdd504830df1a663.jpg
# Upper Body Vectors: [(array([211, 211, 210, ..., 222, 223, 224], dtype=uint8), array([209, 209, 208, ..., 218, 219, 220], dtype=uint8), array([209, 209, 208, ..., 217, 218, 219], dtype=uint8))]
# Lower Body Vectors: [(array([0, 0, 0, ..., 0, 0, 0], dtype=uint8), array([0, 0, 0, ..., 0, 0, 0], dtype=uint8), array([0, 0, 0, ..., 0, 0, 0], dtype=uint8))]
# Accessory Vectors: [(array([ 23,  32,  36, ..., 128, 173, 217], dtype=uint8), array([ 19,  28,  32, ..., 124, 169, 213], dtype=uint8), array([ 18,  27,  31, ..., 123, 168, 212], dtype=uint8)), (array([128, 128, 129, ..., 239, 236, 235], dtype=uint8), array([135, 135, 136, ..., 235, 233, 231], dtype=uint8), array([144, 144, 145, ..., 234, 232, 230], dtype=uint8)), (array([ 40,  40,  40, ..., 138, 146, 153], dtype=uint8), array([ 36,  36,  36, ..., 134, 142, 149], dtype=uint8), array([ 35,  35,  35, ..., 133, 141, 148], dtype=uint8)), (array([195, 195, 195, ...,  32,  32,  32], dtype=uint8), array([193, 193, 193, ...,  28,  28,  28], dtype=uint8), array([193, 193, 193, ...,  27,  27,  27], dtype=uint8))]
#
#
# Image: image_104_jpg.rf.cb08f6eab25afa6a63582fec4ed5e76a.jpg
# Upper Body Vectors: [(array([87, 71, 63, ..., 70, 86, 68], dtype=uint8), array([101,  88,  85, ..., 105, 133, 116], dtype=uint8), array([112, 104, 102, ..., 131, 163, 152], dtype=uint8))]
# Lower Body Vectors: [(array([ 52,  69, 102, ...,  43,  45,  46], dtype=uint8), array([ 54,  74, 107, ...,  55,  57,  58], dtype=uint8), array([ 67,  85, 116, ...,  67,  67,  69], dtype=uint8))]
# Accessory Vectors: [(array([108, 108, 108, ...,  71,  69,  69], dtype=uint8), array([120, 120, 120, ...,  83,  81,  81], dtype=uint8), array([124, 124, 124, ...,  93,  91,  91], dtype=uint8)), (array([55, 54, 54, ..., 75, 73, 72], dtype=uint8), array([51, 49, 48, ..., 89, 86, 85], dtype=uint8), array([ 46,  44,  43, ..., 102, 100,  99], dtype=uint8)), (array([221, 222, 224, ..., 115, 113, 113], dtype=uint8), array([189, 190, 192, ..., 162, 161, 161], dtype=uint8), array([146, 147, 149, ..., 194, 195, 195], dtype=uint8))]
#
#
# Image: image_1051_jpg.rf.b4f6bf4c66dc93f9359b6b0ff51b459b.jpg
# Upper Body Vectors: [(array([213, 214, 226, ...,   2,  12,   2], dtype=uint8), array([218, 220, 228, ...,   4,  17,   7], dtype=uint8), array([217, 218, 228, ...,   4,  16,   6], dtype=uint8))]
# Lower Body Vectors: [(array([34, 40, 38, ..., 18, 14, 11], dtype=uint8), array([24, 29, 26, ...,  5,  4,  3], dtype=uint8), array([22, 27, 24, ...,  0,  0,  0], dtype=uint8))]
# Accessory Vectors: [(array([197, 195, 193, ..., 147, 143, 136], dtype=uint8), array([203, 201, 199, ..., 141, 137, 132], dtype=uint8), array([202, 200, 198, ..., 136, 132, 127], dtype=uint8)), (array([122, 122, 120, ...,  58,  63,  65], dtype=uint8), array([68, 68, 67, ..., 60, 65, 66], dtype=uint8), array([45, 45, 44, ..., 50, 55, 56], dtype=uint8)), (array([250, 250, 250, ..., 255, 255, 255], dtype=uint8), array([245, 245, 245, ..., 244, 244, 244], dtype=uint8), array([242, 242, 242, ..., 237, 237, 237], dtype=uint8))]
#
#
# Image: image_1052_jpg.rf.e0b2a7595f8060b801b7109c4b0cb97d.jpg
# Upper Body Vectors: [(array([97, 92, 87, ..., 64, 59, 53], dtype=uint8), array([102,  98,  92, ...,  66,  60,  54], dtype=uint8), array([105, 101,  95, ...,  66,  58,  52], dtype=uint8))]
# Lower Body Vectors: [(array([92, 91, 93, ..., 91, 88, 83], dtype=uint8), array([107, 103, 105, ...,  96,  93,  88], dtype=uint8), array([111, 107, 109, ...,  95,  92,  87], dtype=uint8))]
# Accessory Vectors: [(array([190, 184, 184, ..., 165, 173, 178], dtype=uint8), array([209, 203, 202, ..., 185, 193, 197], dtype=uint8), array([217, 211, 210, ..., 196, 203, 205], dtype=uint8)), (array([ 77,  79,  83, ..., 161, 166, 169], dtype=uint8), array([ 81,  83,  87, ..., 177, 182, 185], dtype=uint8), array([ 82,  84,  88, ..., 184, 189, 192], dtype=uint8))]
#
#
# Image: image_1053_jpg.rf.c83b1be6653e5c82b84a5d4f5c7c95ea.jpg
# Upper Body Vectors: [(array([ 68,  93,  56, ..., 196, 184, 191], dtype=uint8), array([ 71,  93,  55, ..., 220, 208, 213], dtype=uint8), array([ 76,  99,  57, ..., 222, 214, 224], dtype=uint8))]
# Lower Body Vectors: [(array([195, 195, 194, ...,  33,  32,  32], dtype=uint8), array([199, 199, 198, ...,  33,  32,  32], dtype=uint8), array([200, 200, 199, ...,  33,  32,  32], dtype=uint8))]
# Accessory Vectors: []
#
#
# Image: image_1054_jpg.rf.d60322151c124dc984922eaf18447406.jpg
# Upper Body Vectors: [(array([163, 222, 228, ...,  49,  48,  48], dtype=uint8), array([162, 223, 236, ...,  39,  39,  39], dtype=uint8), array([148, 208, 219, ...,   5,   6,   8], dtype=uint8))]
# Lower Body Vectors: [(array([53, 55, 39, ..., 45, 43, 34], dtype=uint8), array([50, 51, 35, ..., 34, 34, 25], dtype=uint8), array([56, 60, 46, ..., 30, 30, 21], dtype=uint8))]
# Accessory Vectors: [(array([107, 106, 100, ..., 176, 176, 175], dtype=uint8), array([123, 122, 119, ..., 185, 185, 186], dtype=uint8), array([130, 128, 124, ..., 188, 188, 189], dtype=uint8)), (array([198, 143, 105, ..., 199, 201, 201], dtype=uint8), array([201, 147, 110, ..., 211, 213, 213], dtype=uint8), array([205, 149, 110, ..., 215, 217, 217], dtype=uint8))]
#
#
# Image: image_1055_jpg.rf.7a0bbc670ead2a85613061a87bebbe4c.jpg
# Upper Body Vectors: [(array([ 30,  14,  14, ..., 203, 203, 203], dtype=uint8), array([ 39,  22,  22, ..., 203, 203, 203], dtype=uint8), array([ 44,  27,  28, ..., 203, 203, 203], dtype=uint8))]
# Lower Body Vectors: [(array([ 48,  38,  33, ..., 208, 214, 217], dtype=uint8), array([ 60,  53,  49, ..., 214, 215, 215], dtype=uint8), array([ 85,  74,  69, ..., 211, 213, 214], dtype=uint8))]
# Accessory Vectors: []
#
#
# Image: image_1056_jpg.rf.04cdd796f1a23d8898afbbb247cebc4f.jpg
# Upper Body Vectors: [(array([ 29,  38,  61, ..., 151, 146, 149], dtype=uint8), array([ 54,  61,  80, ..., 171, 166, 169], dtype=uint8), array([ 56,  63,  85, ..., 182, 177, 180], dtype=uint8))]
# Lower Body Vectors: [(array([161, 161, 172, ...,  26,  27,  26], dtype=uint8), array([188, 186, 193, ...,  40,  40,  40], dtype=uint8), array([194, 192, 199, ...,  36,  36,  36], dtype=uint8))]
# Accessory Vectors: [(array([204, 201, 201, ..., 143, 140, 141], dtype=uint8), array([225, 222, 222, ..., 148, 145, 145], dtype=uint8), array([233, 230, 229, ..., 149, 146, 146], dtype=uint8)), (array([198, 197, 197, ..., 196, 194, 194], dtype=uint8), array([219, 218, 218, ..., 217, 215, 215], dtype=uint8), array([227, 226, 227, ..., 225, 223, 223], dtype=uint8))]
#
#
# Image: image_1058_jpg.rf.bfcb976b0ef311a1fc44659ca401c2db.jpg
# Upper Body Vectors: [(array([136, 130, 151, ..., 119, 131, 102], dtype=uint8), array([148, 140, 159, ...,  90, 102,  71], dtype=uint8), array([144, 133, 152, ...,  52,  65,  38], dtype=uint8))]
# Lower Body Vectors: [(array([128,  50,  35, ...,  93,  96,  96], dtype=uint8), array([144,  53,  27, ...,  94,  94,  94], dtype=uint8), array([163,  67,  34, ...,  85,  86,  85], dtype=uint8))]
# Accessory Vectors: []
#
#
# Image: image_105_jpg.rf.6718f1e45f67752996f4f5c216707493.jpg
# Upper Body Vectors: [(array([148, 159, 158, ...,   2,  39, 102], dtype=uint8), array([178, 187, 187, ...,   6,  52, 125], dtype=uint8), array([185, 194, 193, ...,  16,  71, 147], dtype=uint8))]
# Lower Body Vectors: [(array([40, 44, 30, ..., 54, 46, 59], dtype=uint8), array([43, 46, 31, ..., 53, 46, 59], dtype=uint8), array([50, 54, 41, ..., 69, 60, 73], dtype=uint8))]
# Accessory Vectors: [(array([142, 141, 139, ...,  43,  42,  42], dtype=uint8), array([142, 141, 139, ...,  54,  54,  53], dtype=uint8), array([142, 141, 139, ...,  62,  61,  61], dtype=uint8)), (array([112, 116, 122, ...,  46,  45,  46], dtype=uint8), array([112, 117, 124, ...,  58,  56,  56], dtype=uint8), array([112, 117, 124, ...,  70,  67,  66], dtype=uint8))]
#
#
# Image: image_1060_jpg.rf.a2fb345019f676b8a2b94263482680ed.jpg
# Upper Body Vectors: [(array([ 95,  95,  96, ..., 149, 149, 149], dtype=uint8), array([ 97,  97,  98, ..., 152, 152, 152], dtype=uint8), array([ 97,  97,  98, ..., 156, 156, 156], dtype=uint8))]
# Lower Body Vectors: [(array([80, 46, 31, ..., 11, 14, 13], dtype=uint8), array([74, 38, 22, ...,  8, 11, 10], dtype=uint8), array([73, 38, 21, ...,  4,  7,  6], dtype=uint8))]
# Accessory Vectors: [(array([23, 23, 24, ..., 44, 43, 42], dtype=uint8), array([14, 14, 15, ..., 40, 39, 38], dtype=uint8), array([11, 11, 12, ..., 39, 38, 37], dtype=uint8)), (array([ 6,  6,  6, ..., 53, 52, 52], dtype=uint8), array([ 2,  2,  2, ..., 48, 47, 47], dtype=uint8), array([ 1,  1,  1, ..., 49, 48, 48], dtype=uint8))]
#
#
# Image: image_1061_jpg.rf.81f47c6513276752885ea04421d8f7fa.jpg
# Upper Body Vectors: [(array([197, 194, 191, ..., 182, 181, 181], dtype=uint8), array([204, 204, 204, ..., 183, 182, 182], dtype=uint8), array([201, 201, 200, ..., 178, 178, 178], dtype=uint8))]
# Lower Body Vectors: [(array([212, 220, 185, ..., 178, 166, 157], dtype=uint8), array([203, 209, 172, ..., 170, 159, 151], dtype=uint8), array([183, 189, 153, ..., 167, 156, 152], dtype=uint8))]
# Accessory Vectors: [(array([118, 118, 124, ..., 171, 172, 174], dtype=uint8), array([105, 105, 111, ..., 166, 166, 167], dtype=uint8), array([ 91,  91,  97, ..., 163, 163, 164], dtype=uint8)), (array([ 43,  44,  45, ..., 154, 155, 156], dtype=uint8), array([ 24,  25,  26, ..., 155, 156, 157], dtype=uint8), array([  9,  10,  11, ..., 151, 152, 153], dtype=uint8))]
#
#
# Image: image_1064_jpg.rf.f19275615b9d1f3d70c3e2f5986668f2.jpg
# Upper Body Vectors: [(array([ 95,  95,  91, ..., 101, 103, 103], dtype=uint8), array([157, 157, 156, ..., 159, 163, 158], dtype=uint8), array([181, 181, 177, ..., 198, 198, 194], dtype=uint8))]
# Lower Body Vectors: [(array([210, 218, 215, ..., 180, 147,  94], dtype=uint8), array([208, 215, 213, ..., 182, 149,  96], dtype=uint8), array([203, 207, 203, ..., 182, 149,  98], dtype=uint8))]
# Accessory Vectors: [(array([60, 59, 58, ..., 46, 44, 43], dtype=uint8), array([71, 70, 69, ..., 51, 49, 48], dtype=uint8), array([74, 74, 73, ..., 54, 52, 51], dtype=uint8))]
#
#
# Image: image_1067_jpg.rf.288b6374cf77d7bf44b87d921606ae99.jpg
# Upper Body Vectors: [(array([205, 202, 204, ...,  22,  24,  38], dtype=uint8), array([213, 209, 209, ...,  27,  30,  44], dtype=uint8), array([213, 209, 210, ...,  25,  28,  42], dtype=uint8))]
# Lower Body Vectors: [(array([79, 82, 85, ..., 96, 93, 89], dtype=uint8), array([ 84,  87,  91, ..., 127, 122, 121], dtype=uint8), array([ 85,  88,  96, ..., 148, 143, 141], dtype=uint8))]
# Accessory Vectors: [(array([96, 96, 96, ..., 88, 88, 84], dtype=uint8), array([101, 101, 101, ...,  93,  93,  89], dtype=uint8), array([102, 102, 102, ...,  96,  96,  92], dtype=uint8)), (array([ 76,  77,  78, ..., 130, 127, 126], dtype=uint8), array([ 82,  83,  84, ..., 142, 139, 138], dtype=uint8), array([ 81,  82,  83, ..., 146, 143, 142], dtype=uint8)), (array([15, 12,  8, ..., 10, 11, 11], dtype=uint8), array([16, 13,  9, ...,  4,  4,  4], dtype=uint8), array([14, 11,  7, ...,  5,  6,  7], dtype=uint8))]
#
#
# Image: image_1068_jpg.rf.7bbd741bd6968a2b8086581b35ae39d5.jpg
# Upper Body Vectors: [(array([148, 148, 148, ...,  31,  72, 141], dtype=uint8), array([153, 153, 153, ...,  29,  73, 144], dtype=uint8), array([152, 152, 152, ...,  28,  72, 142], dtype=uint8))]
# Lower Body Vectors: [(array([ 6,  7,  7, ..., 90, 93, 98], dtype=uint8), array([ 1,  1,  2, ..., 85, 88, 93], dtype=uint8), array([ 2,  2,  3, ..., 85, 87, 92], dtype=uint8))]
# Accessory Vectors: [(array([ 94,  94,  92, ..., 122, 120, 121], dtype=uint8), array([100, 100,  98, ..., 124, 122, 123], dtype=uint8), array([ 99,  99,  97, ..., 124, 122, 123], dtype=uint8)), (array([113, 112, 111, ..., 252, 253, 253], dtype=uint8), array([117, 116, 114, ..., 254, 255, 255], dtype=uint8), array([118, 118, 117, ..., 254, 255, 255], dtype=uint8)), (array([235, 235, 235, ..., 239, 240, 240], dtype=uint8), array([228, 228, 229, ..., 229, 230, 230], dtype=uint8), array([235, 235, 235, ..., 229, 230, 230], dtype=uint8))]
#
#
# Image: image_1069_jpg.rf.9354fd1eee31e006f305737e0435f1ca.jpg
# Upper Body Vectors: [(array([233, 245, 236, ...,  37,  37,  60], dtype=uint8), array([233, 245, 236, ...,  37,  38,  62], dtype=uint8), array([233, 245, 236, ...,  39,  42,  67], dtype=uint8))]
# Lower Body Vectors: [(array([  4,   4,   3, ..., 224, 226, 209], dtype=uint8), array([  6,   5,   5, ..., 220, 222, 204], dtype=uint8), array([ 20,  17,  14, ..., 219, 221, 203], dtype=uint8))]
# Accessory Vectors: [(array([145, 145, 144, ..., 156, 163, 165], dtype=uint8), array([153, 152, 151, ..., 161, 167, 169], dtype=uint8), array([160, 159, 158, ..., 164, 172, 174], dtype=uint8)), (array([  5,   0,   5, ..., 199, 184, 170], dtype=uint8), array([ 10,   3,  10, ..., 206, 192, 182], dtype=uint8), array([  9,   2,   9, ..., 209, 195, 184], dtype=uint8)), (array([248, 247, 242, ...,  22,  22,  23], dtype=uint8), array([248, 247, 242, ...,  21,  21,  22], dtype=uint8), array([248, 247, 242, ...,  23,  24,  24], dtype=uint8))]
#
#
# Image: image_1071_jpg.rf.a0bc9855d0fb7a17b288acd1a6c7a9ed.jpg
# Upper Body Vectors: [(array([173, 171, 166, ...,  51,  67,  60], dtype=uint8), array([179, 176, 172, ...,  59,  73,  67], dtype=uint8), array([178, 175, 171, ...,  62,  78,  72], dtype=uint8))]
# Lower Body Vectors: [(array([123, 124, 126, ..., 140, 138, 138], dtype=uint8), array([114, 115, 117, ..., 135, 133, 133], dtype=uint8), array([111, 112, 114, ..., 134, 132, 132], dtype=uint8))]
# Accessory Vectors: [(array([171, 171, 173, ..., 153, 149, 149], dtype=uint8), array([179, 179, 181, ..., 166, 162, 161], dtype=uint8), array([186, 186, 188, ..., 166, 162, 161], dtype=uint8)), (array([0, 0, 1, ..., 5, 5, 5], dtype=uint8), array([2, 2, 2, ..., 3, 3, 3], dtype=uint8), array([2, 2, 2, ..., 3, 3, 3], dtype=uint8)), (array([149, 149, 150, ...,  21,  25,  27], dtype=uint8), array([161, 161, 162, ...,  33,  37,  39], dtype=uint8), array([165, 165, 166, ...,  37,  41,  43], dtype=uint8)), (array([107, 108, 110, ...,  19,  20,  21], dtype=uint8), array([114, 115, 119, ...,  24,  25,  26], dtype=uint8), array([117, 118, 120, ...,  25,  26,  27], dtype=uint8))]
#
#
# Image: image_1072_jpg.rf.19dddb829beee2480f046922d7a26b08.jpg
# Upper Body Vectors: [(array([132,  93, 120, ...,  34,  37,  32], dtype=uint8), array([138,  99, 126, ...,  65,  71,  65], dtype=uint8), array([137,  98, 125, ...,  98, 104,  98], dtype=uint8))]
# Lower Body Vectors: [(array([103, 119, 206, ..., 134, 133, 114], dtype=uint8), array([109, 122, 208, ..., 143, 143, 126], dtype=uint8), array([109, 126, 213, ..., 152, 150, 130], dtype=uint8))]
# Accessory Vectors: []
#
#
# Image: image_1073_jpg.rf.4c91cce84f08d6b674bd8baf05884684.jpg
# Upper Body Vectors: [(array([150, 152, 166, ..., 164, 172, 170], dtype=uint8), array([152, 154, 168, ..., 171, 178, 173], dtype=uint8), array([152, 154, 168, ..., 165, 173, 172], dtype=uint8))]
# Lower Body Vectors: [(array([65, 65, 67, ..., 20, 20, 20], dtype=uint8), array([68, 68, 70, ..., 25, 25, 25], dtype=uint8), array([82, 82, 84, ..., 28, 28, 28], dtype=uint8))]
# Accessory Vectors: [(array([94, 38, 11, ..., 12,  8,  6], dtype=uint8), array([96, 40, 12, ..., 10,  6,  4], dtype=uint8), array([97, 41, 12, ..., 10,  6,  4], dtype=uint8)), (array([ 80,  83,  80, ..., 112, 111, 114], dtype=uint8), array([ 76,  79,  76, ..., 112, 111, 114], dtype=uint8), array([ 75,  78,  75, ..., 112, 111, 114], dtype=uint8)), (array([158, 159, 162, ..., 136, 149, 155], dtype=uint8), array([156, 157, 160, ..., 139, 154, 160], dtype=uint8), array([155, 156, 159, ..., 139, 153, 159], dtype=uint8)), (array([123, 124, 126, ...,  79,  81,  82], dtype=uint8), array([113, 114, 116, ...,  79,  81,  82], dtype=uint8), array([113, 114, 116, ...,  79,  81,  82], dtype=uint8))]
#
#
# Image: image_1075_jpg.rf.a241d48ddf8ef6cba76b041e8b21abb6.jpg
# Upper Body Vectors: [(array([ 13,   7,   2, ..., 194, 193, 193], dtype=uint8), array([ 11,   7,   5, ..., 182, 183, 183], dtype=uint8), array([ 12,  10,  13, ..., 182, 183, 183], dtype=uint8))]
# Lower Body Vectors: [(array([50, 47, 42, ..., 38, 54, 54], dtype=uint8), array([45, 42, 36, ..., 30, 46, 46], dtype=uint8), array([46, 43, 37, ..., 31, 47, 47], dtype=uint8))]
# Accessory Vectors: [(array([115, 113, 112, ..., 111, 111, 112], dtype=uint8), array([113, 111, 109, ..., 106, 106, 107], dtype=uint8), array([113, 111, 109, ..., 107, 107, 108], dtype=uint8)), (array([33, 33, 34, ..., 38, 39, 39], dtype=uint8), array([25, 25, 26, ..., 33, 34, 34], dtype=uint8), array([26, 26, 27, ..., 32, 33, 33], dtype=uint8))]
#
#
# Image: image_1076_jpg.rf.b92cb204a7182834783ebcbbeb975e3b.jpg
# Upper Body Vectors: [(array([191, 202, 184, ..., 134, 167, 173], dtype=uint8), array([225, 235, 216, ..., 149, 182, 188], dtype=uint8), array([241, 251, 234, ..., 168, 201, 207], dtype=uint8))]
# Lower Body Vectors: [(array([117, 119, 123, ...,  75, 113, 109], dtype=uint8), array([131, 132, 133, ...,  85, 125, 120], dtype=uint8), array([142, 143, 143, ...,  88, 127, 124], dtype=uint8))]
# Accessory Vectors: [(array([106, 106, 105, ..., 207, 208, 208], dtype=uint8), array([118, 118, 117, ..., 221, 222, 222], dtype=uint8), array([128, 128, 127, ..., 232, 234, 234], dtype=uint8)), (array([  7,   7,   7, ..., 143, 144, 145], dtype=uint8), array([  3,   3,   3, ..., 157, 159, 161], dtype=uint8), array([  2,   2,   2, ..., 163, 165, 167], dtype=uint8)), (array([169, 169, 168, ..., 215, 208, 205], dtype=uint8), array([194, 193, 192, ..., 226, 217, 214], dtype=uint8), array([210, 210, 209, ..., 235, 227, 223], dtype=uint8))]
#
#
# Image: image_1078_jpg.rf.ed923fbb785eee22abea64630643a36d.jpg
# Upper Body Vectors: [(array([121, 133, 147, ..., 194, 145, 139], dtype=uint8), array([132, 144, 158, ..., 200, 151, 144], dtype=uint8), array([140, 152, 166, ..., 205, 156, 150], dtype=uint8))]
# Lower Body Vectors: [(array([ 76,  57,  10, ...,  53,  42, 109], dtype=uint8), array([ 80,  57,  10, ...,  47,  37, 108], dtype=uint8), array([ 81,  57,  10, ...,  48,  38, 109], dtype=uint8))]
# Accessory Vectors: [(array([ 80,  81,  82, ..., 112, 111, 110], dtype=uint8), array([ 82,  83,  84, ..., 115, 114, 113], dtype=uint8), array([ 83,  84,  85, ..., 120, 119, 118], dtype=uint8)), (array([ 66,  66,  66, ..., 161, 161, 160], dtype=uint8), array([ 71,  71,  71, ..., 168, 168, 167], dtype=uint8), array([ 69,  69,  69, ..., 171, 171, 170], dtype=uint8))]
#
#
# Image: image_1079_jpg.rf.cbc8135aaf269814832000aa67c5bb48.jpg
# Upper Body Vectors: [(array([143, 144, 145, ...,  40,  42,  39], dtype=uint8), array([140, 139, 138, ...,  41,  45,  43], dtype=uint8), array([161, 165, 169, ...,  47,  51,  51], dtype=uint8))]
# Lower Body Vectors: [(array([46, 43, 44, ..., 34, 34, 37], dtype=uint8), array([31, 27, 28, ..., 33, 32, 35], dtype=uint8), array([34, 28, 27, ..., 42, 41, 42], dtype=uint8))]
# Accessory Vectors: [(array([23, 19, 17, ..., 41, 40, 39], dtype=uint8), array([20, 15, 12, ..., 30, 28, 27], dtype=uint8), array([16, 12,  9, ..., 30, 28, 27], dtype=uint8)), (array([ 13,  14,   6, ...,  91, 108, 115], dtype=uint8), array([ 24,  25,  17, ..., 102, 119, 126], dtype=uint8), array([ 56,  54,  44, ..., 160, 178, 186], dtype=uint8)), (array([23, 23, 23, ..., 24, 24, 24], dtype=uint8), array([18, 18, 18, ..., 14, 14, 14], dtype=uint8), array([20, 20, 20, ..., 14, 14, 14], dtype=uint8))]
#
#
# Image: image_107_jpg.rf.70afa03aed9a1b845261d7d153cec441.jpg
# Upper Body Vectors: [(array([205, 202, 197, ...,  63,  70,  59], dtype=uint8), array([193, 192, 193, ...,  81,  88,  75], dtype=uint8), array([193, 194, 197, ...,  99, 105,  91], dtype=uint8))]
# Lower Body Vectors: [(array([36, 45, 47, ..., 90, 93, 94], dtype=uint8), array([31, 40, 39, ..., 82, 85, 86], dtype=uint8), array([29, 35, 32, ..., 73, 79, 82], dtype=uint8))]
# Accessory Vectors: [(array([44, 45, 46, ..., 97, 93, 92], dtype=uint8), array([37, 37, 37, ..., 85, 81, 80], dtype=uint8), array([34, 33, 33, ..., 79, 75, 74], dtype=uint8)), (array([108,  96,  75, ...,  99, 100, 101], dtype=uint8), array([105,  93,  74, ..., 112, 112, 112], dtype=uint8), array([101,  89,  70, ..., 164, 164, 164], dtype=uint8))]
#
#
# Image: image_1080_jpg.rf.5e0d217ff83aed870f6d5c4acfc3fa3b.jpg
# Upper Body Vectors: [(array([ 41,  35,  33, ..., 156, 156, 156], dtype=uint8), array([ 37,  31,  28, ..., 159, 159, 159], dtype=uint8), array([ 29,  23,  22, ..., 156, 157, 157], dtype=uint8))]
# Lower Body Vectors: [(array([76, 78, 79, ..., 30, 30, 27], dtype=uint8), array([76, 77, 77, ..., 30, 30, 27], dtype=uint8), array([76, 77, 77, ..., 30, 30, 27], dtype=uint8))]
# ...
#
#
# Image: image_976_jpg.rf.9b8dcf1c7657d5d50a82bd6b6ddf0ecd.jpg
# Upper Body Vectors: [(array([240, 239, 219, ..., 169, 168, 207], dtype=uint8), array([233, 227, 204, ..., 147, 152, 195], dtype=uint8), array([234, 227, 201, ..., 141, 145, 189], dtype=uint8))]
# Lower Body Vectors: [(array([231, 228, 224, ..., 221, 224, 231], dtype=uint8), array([236, 234, 233, ..., 219, 222, 229], dtype=uint8), array([235, 233, 231, ..., 218, 221, 228], dtype=uint8))]
# Accessory Vectors: [(array([238, 238, 238, ..., 171, 171, 171], dtype=uint8), array([238, 238, 238, ..., 161, 161, 161], dtype=uint8), array([238, 238, 238, ..., 161, 161, 161], dtype=uint8)), (array([137, 154, 173, ..., 148, 148, 148], dtype=uint8), array([115, 133, 153, ..., 143, 143, 143], dtype=uint8), array([110, 128, 148, ..., 142, 142, 142], dtype=uint8))]
#
#
# Image: image_977_jpg.rf.f4c253fcdbdef838607926d7fb72294c.jpg
# Upper Body Vectors: [(array([145, 142, 162, ...,  12,  11,  14], dtype=uint8), array([161, 158, 178, ...,  34,  33,  36], dtype=uint8), array([168, 165, 184, ...,  62,  67,  71], dtype=uint8))]
# Lower Body Vectors: [(array([ 82,  90, 104, ...,  64,  64,  63], dtype=uint8), array([ 81,  88, 100, ...,  75,  75,  74], dtype=uint8), array([ 90,  95, 107, ...,  79,  79,  79], dtype=uint8))]
# Accessory Vectors: [(array([16, 14, 18, ..., 68, 64, 62], dtype=uint8), array([14, 12, 16, ..., 69, 65, 63], dtype=uint8), array([13, 11, 15, ..., 67, 63, 61], dtype=uint8))]
#
#
# Image: image_978_jpg.rf.bfead4dd053818e95c2ada16e6433af2.jpg
# Upper Body Vectors: [(array([220, 226, 212, ...,  90, 106,  77], dtype=uint8), array([220, 226, 212, ...,  93, 109,  82], dtype=uint8), array([220, 226, 212, ...,  99, 116,  88], dtype=uint8))]
# Lower Body Vectors: [(array([93, 85, 76, ..., 52, 52, 51], dtype=uint8), array([95, 87, 78, ..., 52, 52, 51], dtype=uint8), array([95, 87, 78, ..., 52, 52, 51], dtype=uint8))]
# Accessory Vectors: [(array([225, 226, 228, ..., 165, 156, 151], dtype=uint8), array([227, 228, 230, ..., 167, 158, 153], dtype=uint8), array([228, 229, 231, ..., 168, 159, 154], dtype=uint8)), (array([74, 74, 73, ...,  9, 18, 23], dtype=uint8), array([73, 74, 75, ..., 13, 21, 27], dtype=uint8), array([75, 75, 76, ..., 14, 23, 28], dtype=uint8))]
#
#
# Image: image_979_jpg.rf.2a0f1c9e8787534697296d0d7afb20ab.jpg
# Upper Body Vectors: [(array([183, 181, 178, ...,  31,  31,  31], dtype=uint8), array([179, 175, 173, ...,  28,  28,  27], dtype=uint8), array([174, 173, 170, ...,  20,  23,  26], dtype=uint8))]
# Lower Body Vectors: [(array([151, 152, 152, ..., 226, 226, 227], dtype=uint8), array([155, 156, 157, ..., 219, 219, 220], dtype=uint8), array([156, 157, 157, ..., 210, 210, 211], dtype=uint8))]
# Accessory Vectors: [(array([159, 162, 163, ..., 109, 116, 109], dtype=uint8), array([159, 162, 163, ..., 115, 122, 114], dtype=uint8), array([159, 162, 163, ..., 120, 126, 117], dtype=uint8)), (array([ 84,  84,  84, ..., 102, 101, 100], dtype=uint8), array([ 88,  88,  88, ..., 106, 105, 104], dtype=uint8), array([ 93,  93,  93, ..., 107, 106, 105], dtype=uint8)), (array([155, 157, 152, ..., 185, 185, 185], dtype=uint8), array([147, 151, 147, ..., 181, 181, 181], dtype=uint8), array([147, 150, 146, ..., 176, 176, 176], dtype=uint8)), (array([ 34,  37,  43, ..., 138, 142, 144], dtype=uint8), array([ 25,  28,  34, ..., 137, 141, 142], dtype=uint8), array([ 22,  25,  31, ..., 149, 152, 153], dtype=uint8))]
#
#
# Image: image_981_jpg.rf.67360f950ad5c6d60c44fd237d37393d.jpg
# Upper Body Vectors: [(array([182, 177, 180, ...,  46,  42,  41], dtype=uint8), array([190, 185, 186, ...,  48,  45,  43], dtype=uint8), array([189, 184, 185, ...,  49,  45,  44], dtype=uint8))]
# Lower Body Vectors: [(array([131, 119, 102, ..., 119, 133, 145], dtype=uint8), array([132, 120, 103, ..., 118, 132, 146], dtype=uint8), array([128, 116,  99, ..., 114, 128, 141], dtype=uint8))]
# Accessory Vectors: [(array([140, 140, 139, ..., 187, 188, 189], dtype=uint8), array([140, 140, 139, ..., 188, 189, 190], dtype=uint8), array([140, 140, 139, ..., 186, 187, 188], dtype=uint8)), (array([160, 157, 151, ..., 191, 196, 197], dtype=uint8), array([162, 159, 153, ..., 194, 198, 199], dtype=uint8), array([162, 159, 153, ..., 195, 198, 199], dtype=uint8))]
#
#
# Image: image_982_jpg.rf.24b5f60934607fc7d4b36eb06e6b5cd3.jpg
# Upper Body Vectors: [(array([159, 156, 156, ..., 159, 158, 160], dtype=uint8), array([160, 158, 158, ..., 158, 159, 161], dtype=uint8), array([158, 158, 158, ..., 154, 157, 159], dtype=uint8))]
# Lower Body Vectors: [(array([ 72,  81,  80, ..., 226, 235, 234], dtype=uint8), array([ 75,  84,  83, ..., 223, 232, 233], dtype=uint8), array([ 73,  82,  81, ..., 218, 227, 228], dtype=uint8))]
# Accessory Vectors: [(array([169, 167, 165, ..., 130, 142, 155], dtype=uint8), array([165, 163, 162, ..., 128, 141, 154], dtype=uint8), array([160, 158, 156, ..., 127, 139, 150], dtype=uint8)), (array([158, 158, 159, ..., 175, 174, 174], dtype=uint8), array([155, 155, 156, ..., 174, 173, 173], dtype=uint8), array([151, 151, 152, ..., 170, 169, 169], dtype=uint8))]
#
#
# Image: image_983_jpg.rf.abbb3dad9fd6c7abf88162bd55cb9d17.jpg
# Upper Body Vectors: [(array([200, 193, 187, ..., 230, 254, 194], dtype=uint8), array([204, 197, 192, ..., 223, 249, 191], dtype=uint8), array([199, 192, 189, ..., 214, 238, 178], dtype=uint8))]
# Lower Body Vectors: [(array([106,  93,  77, ..., 124, 124, 125], dtype=uint8), array([108,  93,  77, ..., 140, 140, 141], dtype=uint8), array([108,  93,  77, ..., 149, 149, 150], dtype=uint8))]
# Accessory Vectors: [(array([92, 87, 80, ..., 86, 87, 88], dtype=uint8), array([114, 110, 104, ...,  98,  98,  99], dtype=uint8), array([126, 124, 121, ..., 105, 106, 107], dtype=uint8)), (array([ 35,  35,  37, ..., 106, 107, 107], dtype=uint8), array([ 32,  32,  33, ..., 123, 126, 126], dtype=uint8), array([ 27,  27,  27, ..., 129, 131, 131], dtype=uint8))]
#
#
# Image: image_984_jpg.rf.6f3c162eeede6ddf0b25bc8aa26c21a7.jpg
# Upper Body Vectors: [(array([171, 174, 149, ..., 131, 128, 129], dtype=uint8), array([178, 181, 155, ..., 134, 130, 131], dtype=uint8), array([180, 184, 158, ..., 134, 130, 131], dtype=uint8))]
# Lower Body Vectors: [(array([171, 216, 207, ...,  79,  87,  96], dtype=uint8), array([174, 218, 208, ...,  83,  87,  97], dtype=uint8), array([182, 228, 218, ...,  72,  74,  78], dtype=uint8))]
# Accessory Vectors: [(array([13, 13, 14, ..., 12,  7,  1], dtype=uint8), array([ 9,  9,  9, ..., 19, 13,  7], dtype=uint8), array([ 4,  4,  3, ..., 18, 12,  6], dtype=uint8)), (array([158, 156, 149, ..., 196, 195, 195], dtype=uint8), array([147, 147, 141, ..., 200, 199, 199], dtype=uint8), array([125, 122, 112, ..., 205, 204, 204], dtype=uint8))]
#
#
# Image: image_987_jpg.rf.a6484c58a5814f2018c71685e9febe03.jpg
# Upper Body Vectors: [(array([15, 15, 22, ..., 93, 93, 98], dtype=uint8), array([ 22,  21,  28, ..., 115, 116, 119], dtype=uint8), array([ 17,  17,  27, ..., 156, 154, 158], dtype=uint8))]
# Lower Body Vectors: [(array([ 9, 10, 11, ..., 13, 13, 11], dtype=uint8), array([ 9, 10, 11, ..., 14, 14, 15], dtype=uint8), array([ 9, 10, 11, ..., 12, 12, 11], dtype=uint8))]
# Accessory Vectors: [(array([14, 15, 19, ..., 13, 11, 11], dtype=uint8), array([13, 14, 19, ..., 15, 13, 13], dtype=uint8), array([ 9, 10, 15, ..., 15, 13, 13], dtype=uint8))]
#
#
# Image: image_988_jpg.rf.1853d583287d2045f7c2158c5e13ee37.jpg
# Upper Body Vectors: [(array([217, 217, 217, ..., 229, 229, 229], dtype=uint8), array([212, 212, 212, ..., 224, 224, 224], dtype=uint8), array([213, 213, 213, ..., 223, 223, 223], dtype=uint8))]
# Lower Body Vectors: [(array([230, 232, 222, ...,  29,  28, 196], dtype=uint8), array([225, 227, 216, ...,  28,  26, 191], dtype=uint8), array([224, 226, 218, ...,  28,  26, 190], dtype=uint8))]
# Accessory Vectors: [(array([234, 233, 231, ..., 226, 226, 226], dtype=uint8), array([230, 229, 227, ..., 221, 221, 221], dtype=uint8), array([229, 228, 226, ..., 220, 220, 220], dtype=uint8)), (array([235, 235, 235, ..., 247, 246, 253], dtype=uint8), array([230, 230, 230, ..., 242, 241, 248], dtype=uint8), array([229, 229, 229, ..., 243, 242, 249], dtype=uint8))]
#
#
# Image: image_989_jpg.rf.633ea59947dac84e921b8e9c26ca8cd3.jpg
# Upper Body Vectors: [(array([187, 188, 187, ...,  40,  44,  47], dtype=uint8), array([181, 181, 180, ...,  45,  48,  51], dtype=uint8), array([183, 183, 181, ...,  54,  59,  62], dtype=uint8))]
# Lower Body Vectors: [(array([131, 116,  93, ...,   9,   8,  41], dtype=uint8), array([139, 123,  99, ...,   4,   3,  36], dtype=uint8), array([136, 120,  96, ...,   3,   2,  35], dtype=uint8))]
# Accessory Vectors: [(array([106, 106, 105, ...,  53,  54,  55], dtype=uint8), array([103, 103, 102, ...,  45,  46,  47], dtype=uint8), array([99, 99, 98, ..., 46, 48, 48], dtype=uint8)), (array([ 6,  6,  5, ..., 38, 36, 36], dtype=uint8), array([ 2,  2,  2, ..., 30, 29, 29], dtype=uint8), array([ 1,  1,  0, ..., 27, 26, 26], dtype=uint8)), (array([67, 67, 66, ..., 79, 82, 80], dtype=uint8), array([ 69,  69,  68, ..., 100, 104, 104], dtype=uint8), array([ 77,  77,  77, ..., 101, 105, 104], dtype=uint8))]
#
#
# Image: image_98_jpg.rf.4a401c4683d3ad95254bbc2a30664043.jpg
# Upper Body Vectors: [(array([ 2,  4,  5, ..., 66, 71, 72], dtype=uint8), array([ 1,  1,  1, ..., 46, 50, 53], dtype=uint8), array([ 40,  42,  43, ..., 142, 143, 140], dtype=uint8))]
# Lower Body Vectors: [(array([ 2,  0,  1, ..., 97, 93, 98], dtype=uint8), array([  7,   2,   0, ..., 123, 120, 123], dtype=uint8), array([ 18,  13,  12, ..., 144, 141, 143], dtype=uint8))]
# Accessory Vectors: [(array([33, 32, 31, ..., 52, 53, 53], dtype=uint8), array([40, 40, 38, ..., 57, 58, 58], dtype=uint8), array([43, 42, 41, ..., 56, 57, 57], dtype=uint8)), (array([86, 88, 95, ..., 36, 28, 26], dtype=uint8), array([105, 107, 114, ...,  33,  25,  23], dtype=uint8), array([118, 120, 127, ...,  35,  27,  25], dtype=uint8))]
#
#
# Image: image_991_jpg.rf.b53cf95e5989897f20b8841e98224a71.jpg
# Upper Body Vectors: [(array([52, 56, 64, ..., 49, 68, 76], dtype=uint8), array([57, 59, 65, ..., 58, 77, 85], dtype=uint8), array([57, 58, 61, ..., 72, 91, 99], dtype=uint8))]
# Lower Body Vectors: [(array([109, 109, 110, ...,   8,  16,  11], dtype=uint8), array([118, 118, 119, ...,   9,  18,  12], dtype=uint8), array([128, 128, 129, ...,  13,  22,  16], dtype=uint8))]
# Accessory Vectors: [(array([145, 144, 136, ...,  35,  38,  39], dtype=uint8), array([151, 150, 142, ...,  30,  33,  34], dtype=uint8), array([146, 144, 137, ...,  29,  32,  33], dtype=uint8)), (array([112, 114, 117, ..., 180, 176, 174], dtype=uint8), array([115, 117, 120, ..., 194, 191, 189], dtype=uint8), array([119, 121, 124, ..., 191, 187, 185], dtype=uint8)), (array([157, 158, 159, ..., 127, 125, 124], dtype=uint8), array([166, 166, 168, ..., 150, 148, 147], dtype=uint8), array([176, 176, 178, ..., 195, 193, 192], dtype=uint8))]
#
#
# Image: image_992_jpg.rf.f9e07295c7df8c42ba57078458d75d50.jpg
# Upper Body Vectors: [(array([199, 194, 152, ...,  92, 106, 119], dtype=uint8), array([199, 194, 151, ...,  93, 107, 117], dtype=uint8), array([199, 194, 153, ...,  97, 111, 123], dtype=uint8))]
# Lower Body Vectors: [(array([175, 129,  96, ..., 123, 123, 122], dtype=uint8), array([171, 125,  92, ..., 121, 121, 120], dtype=uint8), array([170, 124,  91, ..., 121, 121, 120], dtype=uint8))]
# Accessory Vectors: [(array([  6,   6,   7, ..., 121, 121, 121], dtype=uint8), array([  6,   6,   7, ..., 121, 121, 121], dtype=uint8), array([  6,   6,   7, ..., 121, 121, 121], dtype=uint8)), (array([104, 107, 108, ...,  93,  92,  94], dtype=uint8), array([105, 104, 104, ...,  92,  92,  92], dtype=uint8), array([103, 103, 102, ...,  92,  92,  92], dtype=uint8))]
#
#
# Image: image_994_jpg.rf.433dee290f270933a4500aa661820686.jpg
# Upper Body Vectors: [(array([231, 235, 236, ..., 227, 226, 219], dtype=uint8), array([231, 230, 228, ..., 225, 225, 218], dtype=uint8), array([219, 219, 221, ..., 217, 214, 204], dtype=uint8))]
# Lower Body Vectors: [(array([ 21,  19,  29, ..., 195, 195, 194], dtype=uint8), array([ 19,  13,  20, ..., 209, 209, 206], dtype=uint8), array([  3,   2,  12, ..., 207, 209, 209], dtype=uint8))]
# Accessory Vectors: []
#
#
# Image: image_995_jpg.rf.90a65a08f141e14c5b00790d2a0fa8da.jpg
# Upper Body Vectors: [(array([113, 188, 195, ...,  91, 105,  97], dtype=uint8), array([122, 198, 203, ..., 104, 120, 112], dtype=uint8), array([140, 213, 217, ..., 112, 129, 121], dtype=uint8))]
# Lower Body Vectors: [(array([ 82,  83,  90, ..., 168, 172, 160], dtype=uint8), array([ 94,  89,  95, ..., 180, 184, 170], dtype=uint8), array([103,  98, 104, ..., 184, 188, 178], dtype=uint8))]
# Accessory Vectors: [(array([231, 131,  86, ..., 140, 148, 156], dtype=uint8), array([237, 138,  93, ..., 150, 158, 166], dtype=uint8), array([236, 135,  90, ..., 150, 158, 166], dtype=uint8))]
#
#
# Image: image_996_jpg.rf.cb8506e03da6f7c8e5d68bc0db1f2cad.jpg
# Upper Body Vectors: [(array([54, 52, 52, ..., 32, 29, 30], dtype=uint8), array([53, 51, 50, ..., 30, 27, 28], dtype=uint8), array([55, 53, 50, ..., 29, 26, 26], dtype=uint8))]
# Lower Body Vectors: [(array([ 45,  50,  56, ..., 113, 112, 109], dtype=uint8), array([ 46,  51,  57, ..., 104, 103, 100], dtype=uint8), array([ 44,  49,  55, ..., 101, 100,  97], dtype=uint8))]
# Accessory Vectors: []
#
#
# Image: image_998_jpg.rf.77b6cccf6a534f5d9ec2865381b66e08.jpg
# Upper Body Vectors: [(array([ 52,  43,  50, ..., 199, 172, 187], dtype=uint8), array([ 46,  39,  47, ..., 103,  77,  91], dtype=uint8), array([39, 34, 44, ..., 14,  0, 10], dtype=uint8))]
# Lower Body Vectors: [(array([11,  9, 10, ..., 34, 38, 37], dtype=uint8), array([ 6,  5,  6, ..., 29, 33, 32], dtype=uint8), array([ 7,  4,  4, ..., 28, 32, 31], dtype=uint8))]
# Accessory Vectors: [(array([ 13,  12,  10, ..., 149, 150, 150], dtype=uint8), array([ 10,  10,   9, ..., 155, 155, 155], dtype=uint8), array([ 12,  12,  11, ..., 221, 219, 218], dtype=uint8)), (array([117, 116, 113, ...,  13,   5,   4], dtype=uint8), array([118, 116, 114, ...,  15,   6,   4], dtype=uint8), array([132, 130, 127, ...,  22,  13,  10], dtype=uint8))]
#
#
# Image: image_99_jpg.rf.34d48f2b78c95bfc0f7acf5a5e03c9fd.jpg
# Upper Body Vectors: [(array([52, 45, 51, ..., 81, 74, 78], dtype=uint8), array([72, 65, 72, ..., 96, 89, 93], dtype=uint8), array([ 68,  62,  69, ..., 112, 105, 109], dtype=uint8))]
# Lower Body Vectors: [(array([ 66,  76,  56, ...,  90,  92, 108], dtype=uint8), array([ 69,  80,  63, ...,  89,  93, 108], dtype=uint8), array([ 73,  84,  63, ...,  91,  96, 114], dtype=uint8))]
# Accessory Vectors: [(array([121, 121, 120, ..., 128, 127, 126], dtype=uint8), array([134, 134, 133, ..., 141, 140, 139], dtype=uint8), array([136, 136, 135, ..., 149, 148, 147], dtype=uint8)), (array([ 32,  32,  32, ..., 184, 187, 188], dtype=uint8), array([ 36,  36,  36, ..., 195, 198, 200], dtype=uint8), array([ 37,  37,  37, ..., 203, 205, 206], dtype=uint8))]
#
#
# Image: image_9_jpg.rf.e201d4c5774f967908f7af920b1ca543.jpg
# Upper Body Vectors: [(array([212, 208, 199, ..., 132, 116, 106], dtype=uint8), array([216, 211, 200, ..., 152, 136, 126], dtype=uint8), array([222, 215, 203, ..., 209, 193, 183], dtype=uint8))]
# Lower Body Vectors: [(array([112,  98,  81, ...,  85,  82,  86], dtype=uint8), array([106,  93,  76, ...,  74,  75,  81], dtype=uint8), array([105,  91,  74, ...,  71,  71,  76], dtype=uint8))]
# Accessory Vectors: [(array([175, 175, 175, ..., 152, 155, 155], dtype=uint8), array([179, 179, 179, ..., 161, 163, 163], dtype=uint8), array([208, 208, 208, ..., 168, 170, 170], dtype=uint8)), (array([ 79, 101,  72, ...,  38,  38,  38], dtype=uint8), array([74, 96, 67, ..., 40, 40, 40], dtype=uint8), array([73, 95, 66, ..., 40, 40, 40], dtype=uint8)), (array([ 37,  39,  41, ..., 144, 144, 144], dtype=uint8), array([ 40,  40,  41, ..., 164, 164, 164], dtype=uint8), array([ 48,  48,  50, ..., 222, 222, 222], dtype=uint8))]

# %%
len(train_image_sets.items()) # 길이같음
# Out:
# 755

# %%
# 데이터 준비
upper_body_data_train = []  # 상의 벡터 (고정 크기 30000)
lower_body_label_train = []  # 하의 벡터 (고정 크기 30000)
accessory_data_train = []  # 가변 길이 악세사리 시퀀스
accessory_labels_train = []  # 가변 길이 악세사리 레이블 시퀀스

for image_name, vectors in train_image_sets.items():
    # 상의 벡터 처리 (R, G, B 결합)
    if len(vectors['upper_body']) > 0:
        r_vector, g_vector, b_vector = vectors['upper_body'][0]
        upper_body_vector = np.concatenate([r_vector, g_vector, b_vector])  # 크기: 30000
    else:
        upper_body_vector = np.zeros(30000)  # 기본값

    upper_body_data_train.append(upper_body_vector)

    # 하의 벡터 처리 (R, G, B 결합)
    if len(vectors['lower_body']) > 0:
        r_vector, g_vector, b_vector = vectors['lower_body'][0]
        lower_body_vector = np.concatenate([r_vector, g_vector, b_vector])  # 크기: 30000
    else:
        lower_body_vector = np.zeros(30000)  # 기본값

    lower_body_label_train.append(lower_body_vector)

    # 악세사리 벡터 처리 (R, G, B 결합 및 시퀀스 형태로 저장)
    accessory_sequence = []
    accessory_label_sequence = []
    for accessory in vectors['accessory']:
        r_vector, g_vector, b_vector = accessory
        accessory_vector = np.concatenate([r_vector, g_vector, b_vector])  # 크기: 30000
        accessory_sequence.append(accessory_vector)
        accessory_label_sequence.append(accessory_vector)  # 동일한 벡터를 레이블로 사용

    accessory_data_train.append(accessory_sequence)
    accessory_labels_train.append(accessory_label_sequence)

# numpy 배열로 변환
upper_body_data_train = np.array(upper_body_data_train)
lower_body_label_train = np.array(lower_body_label_train)
accessory_data_train = np.array([np.array(seq) for seq in accessory_data_train], dtype=object)  # 가변 길이 시퀀스
accessory_labels_train = np.array([np.array(seq) for seq in accessory_labels_train], dtype=object)  # 가변 길이 시퀀스

# %%
# 데이터 개수
print("Length of upper_body_data_train:", len(upper_body_data_train))
print("Length of lower_body_label_train:", len(lower_body_label_train))
print("Length of accessory_data_train:", len(accessory_data_train))
print("Length of accessory_labels_train:", len(accessory_labels_train))
# Out:
# Length of upper_body_data_train: 755
# Length of lower_body_label_train: 755
# Length of accessory_data_train: 755
# Length of accessory_labels_train: 755

# %% [markdown]
# ##### valid

# %%
image_dir = "./Crawling2-2/valid/images"
label_dir = "./Crawling2-2/valid/labels"

# 모든 이미지와 라벨 파일을 처리하여 저장할 딕셔너리
valid_image_sets = {}

# 이미지 파일과 라벨 파일 목록 불러오기
image_files = os.listdir(image_dir)
label_files = os.listdir(label_dir)

# 각 이미지와 해당 라벨 파일을 처리
for image_file in image_files:
    # 이미지 경로 및 파일명 설정
    image_path = os.path.join(image_dir, image_file)
    label_file = image_file.replace('.jpg', '.txt')  # 이미지 파일명과 라벨 파일명 맞추기
    label_path = os.path.join(label_dir, label_file)

    # 이미지와 라벨 파일이 모두 존재할 때만 처리
    if os.path.exists(label_path):
        # 이미지 로드 및 크기 확인
        image = cv2.imread(image_path)
        if image is None:
            print(f"Error: Could not load image {image_path}")
            continue
        
        img_height, img_width = image.shape[:2]

        # 라벨 파일에서 바운딩 박스 정보 로드
        detections = load_detections_from_label_file(label_path)

        # 각 이미지의 객체를 벡터화하여 저장
        image_vectors = process_image_sets(image, detections, img_width, img_height)

        # 고유 키를 파일명으로 설정하여 딕셔너리에 저장  => 가독성이 떨어지긴 하는데
        valid_image_sets[image_file] = image_vectors

# 전체 결과 확인
for image_name, vectors in valid_image_sets.items():
    print(f"Image: {image_name}")
    print("Upper Body Vectors:", vectors['upper_body'])
    print("Lower Body Vectors:", vectors['lower_body'])
    print("Accessory Vectors:", vectors['accessory'])
    print("\n")
# Out:
# Image: image_0_jpg.rf.fc1f0218d9d8669adc1b06b5d3921abc.jpg
# Upper Body Vectors: [(array([182, 182, 182, ..., 182, 187, 184], dtype=uint8), array([187, 187, 187, ..., 184, 189, 186], dtype=uint8), array([188, 188, 188, ..., 185, 190, 187], dtype=uint8))]
# Lower Body Vectors: [(array([127,  25,  20, ..., 175, 175, 175], dtype=uint8), array([131,  29,  25, ..., 177, 177, 177], dtype=uint8), array([128,  27,  23, ..., 177, 177, 177], dtype=uint8))]
# Accessory Vectors: [(array([157, 157, 157, ..., 197, 197, 196], dtype=uint8), array([159, 159, 159, ..., 192, 192, 191], dtype=uint8), array([159, 159, 159, ..., 193, 193, 192], dtype=uint8)), (array([ 24,  30,  32, ..., 188, 188, 188], dtype=uint8), array([ 22,  29,  30, ..., 188, 188, 188], dtype=uint8), array([ 22,  29,  30, ..., 188, 188, 188], dtype=uint8))]
#
#
# Image: image_1007_jpg.rf.05b685c76d824be326e6d2a8c3eab956.jpg
# Upper Body Vectors: [(array([102, 102, 100, ..., 101,  89,  89], dtype=uint8), array([114, 114, 112, ..., 110,  97,  97], dtype=uint8), array([116, 116, 114, ..., 112,  97,  97], dtype=uint8))]
# Lower Body Vectors: [(array([ 5,  3,  5, ..., 33, 35, 36], dtype=uint8), array([ 5,  2,  6, ..., 33, 33, 35], dtype=uint8), array([12, 11, 16, ..., 39, 38, 39], dtype=uint8))]
# Accessory Vectors: [(array([152, 154, 151, ...,  58,  57,  57], dtype=uint8), array([149, 148, 144, ...,  58,  57,  57], dtype=uint8), array([141, 141, 136, ...,  58,  57,  57], dtype=uint8)), (array([168, 171, 182, ..., 100, 102, 102], dtype=uint8), array([164, 167, 175, ..., 124, 126, 126], dtype=uint8), array([146, 149, 158, ..., 146, 148, 148], dtype=uint8))]
#
#
# Image: image_1011_jpg.rf.beabe3cf1c0d733eb26b077732063d5a.jpg
# Upper Body Vectors: [(array([222, 220, 223, ..., 213, 222, 217], dtype=uint8), array([218, 217, 220, ..., 213, 218, 214], dtype=uint8), array([214, 212, 215, ..., 211, 213, 206], dtype=uint8))]
# Lower Body Vectors: [(array([114, 107, 104, ..., 126, 123, 125], dtype=uint8), array([124, 121, 123, ..., 131, 129, 130], dtype=uint8), array([167, 167, 173, ..., 132, 129, 131], dtype=uint8))]
# Accessory Vectors: [(array([155, 154, 153, ..., 136, 136, 137], dtype=uint8), array([153, 154, 154, ..., 141, 141, 142], dtype=uint8), array([152, 153, 152, ..., 142, 142, 143], dtype=uint8)), (array([167, 168, 170, ..., 131, 132, 133], dtype=uint8), array([181, 182, 184, ..., 136, 137, 138], dtype=uint8), array([187, 188, 189, ..., 135, 136, 137], dtype=uint8))]
#
#
# Image: image_1020_jpg.rf.f1e161cb211e5a0646609765c121b53f.jpg
# Upper Body Vectors: [(array([165,  90,  82, ..., 227, 226, 225], dtype=uint8), array([162,  88,  79, ..., 224, 223, 222], dtype=uint8), array([162,  88,  79, ..., 226, 225, 224], dtype=uint8))]
# Lower Body Vectors: [(array([129, 129, 128, ...,  43,  43,  43], dtype=uint8), array([143, 143, 142, ...,  55,  55,  55], dtype=uint8), array([171, 171, 171, ...,  63,  64,  65], dtype=uint8))]
# Accessory Vectors: [(array([ 22,  26,  29, ..., 105, 107, 107], dtype=uint8), array([ 22,  26,  29, ..., 106, 108, 108], dtype=uint8), array([ 22,  26,  29, ..., 104, 106, 106], dtype=uint8)), (array([159, 159, 159, ...,  31,  34,  63], dtype=uint8), array([159, 159, 158, ...,  31,  34,  63], dtype=uint8), array([159, 159, 158, ...,  31,  34,  63], dtype=uint8))]
#
#
# Image: image_1029_jpg.rf.608d83b82e946d5f8ae9cf28cddf38df.jpg
# Upper Body Vectors: [(array([25, 24, 22, ..., 43, 48, 48], dtype=uint8), array([17, 18, 17, ..., 40, 44, 43], dtype=uint8), array([10, 13, 14, ..., 43, 42, 40], dtype=uint8))]
# Lower Body Vectors: [(array([185, 151, 169, ..., 254, 237, 208], dtype=uint8), array([187, 153, 171, ..., 253, 235, 209], dtype=uint8), array([188, 154, 172, ..., 252, 234, 207], dtype=uint8))]
# Accessory Vectors: [(array([205, 204, 204, ...,  23,  21,  23], dtype=uint8), array([210, 209, 209, ...,  20,  19,  18], dtype=uint8), array([209, 207, 207, ...,  19,  18,  17], dtype=uint8))]
#
#
# Image: image_102_jpg.rf.980549538b78a8d4914232c98c38239b.jpg
# Upper Body Vectors: [(array([197, 201, 192, ..., 188, 190, 189], dtype=uint8), array([202, 206, 197, ..., 194, 195, 193], dtype=uint8), array([201, 205, 196, ..., 194, 198, 194], dtype=uint8))]
# Lower Body Vectors: [(array([ 96, 101, 102, ...,  43,  42,  42], dtype=uint8), array([123, 127, 131, ...,  37,  37,  36], dtype=uint8), array([161, 168, 174, ...,  34,  34,  33], dtype=uint8))]
# Accessory Vectors: [(array([193, 193, 191, ...,  61,  56,  55], dtype=uint8), array([195, 195, 194, ...,  62,  57,  56], dtype=uint8), array([194, 194, 192, ...,  60,  55,  54], dtype=uint8)), (array([ 36,  38,  42, ..., 148, 148, 148], dtype=uint8), array([ 38,  40,  43, ..., 151, 151, 151], dtype=uint8), array([ 38,  39,  42, ..., 156, 156, 156], dtype=uint8)), (array([ 16,  14,  12, ..., 125, 132, 135], dtype=uint8), array([ 17,  15,  12, ..., 131, 138, 141], dtype=uint8), array([ 13,  11,   8, ..., 136, 143, 146], dtype=uint8))]
#
#
# Image: image_1038_jpg.rf.8ad9161220b0cfb0dbeaceb622ea192b.jpg
# Upper Body Vectors: [(array([206, 197, 208, ..., 226, 157,  49], dtype=uint8), array([212, 203, 214, ..., 228, 157,  49], dtype=uint8), array([217, 208, 219, ..., 222, 152,  43], dtype=uint8))]
# Lower Body Vectors: [(array([  9,  19,  19, ..., 172, 172, 171], dtype=uint8), array([  8,  18,  18, ..., 174, 174, 173], dtype=uint8), array([  4,  14,  14, ..., 174, 174, 173], dtype=uint8))]
# Accessory Vectors: [(array([187, 184, 183, ...,  11,  13,  15], dtype=uint8), array([192, 189, 188, ...,   4,   5,   7], dtype=uint8), array([195, 192, 191, ...,   1,   2,   4], dtype=uint8)), (array([131, 130, 130, ..., 158, 158, 158], dtype=uint8), array([136, 135, 135, ..., 156, 156, 156], dtype=uint8), array([137, 136, 136, ..., 156, 156, 156], dtype=uint8)), (array([149, 151, 150, ..., 172, 173, 183], dtype=uint8), array([154, 156, 155, ..., 166, 167, 177], dtype=uint8), array([153, 155, 154, ..., 161, 162, 172], dtype=uint8))]
#
#
# Image: image_103_jpg.rf.15d574059df69c3a15dd7a7504d80316.jpg
# Upper Body Vectors: [(array([180, 179, 179, ..., 212, 211, 211], dtype=uint8), array([180, 179, 179, ..., 208, 207, 207], dtype=uint8), array([180, 179, 179, ..., 207, 206, 206], dtype=uint8))]
# Lower Body Vectors: [(array([208, 205, 209, ...,  29,  30, 113], dtype=uint8), array([203, 200, 204, ...,  25,  26, 109], dtype=uint8), array([204, 201, 205, ...,  24,  25, 108], dtype=uint8))]
# Accessory Vectors: []
#
#
# Image: image_1048_jpg.rf.333a04a22521cf1d4542eec07e48973e.jpg
# Upper Body Vectors: [(array([ 34,  36,  32, ..., 118, 119, 114], dtype=uint8), array([ 38,  40,  36, ..., 125, 126, 121], dtype=uint8), array([ 43,  45,  41, ..., 134, 135, 130], dtype=uint8))]
# Lower Body Vectors: [(array([84, 69, 71, ..., 81, 80, 83], dtype=uint8), array([68, 52, 54, ..., 69, 68, 71], dtype=uint8), array([57, 38, 40, ..., 51, 50, 53], dtype=uint8))]
# Accessory Vectors: [(array([30, 30, 31, ...,  5,  6,  6], dtype=uint8), array([32, 33, 34, ...,  1,  1,  1], dtype=uint8), array([33, 34, 35, ...,  0,  0,  0], dtype=uint8))]
#
#
# Image: image_1049_jpg.rf.6d5d10443258714c1b2761ac181d33e1.jpg
# Upper Body Vectors: [(array([ 17,  13,  18, ..., 241, 144, 142], dtype=uint8), array([ 15,   9,  13, ..., 240, 146, 146], dtype=uint8), array([ 12,   4,   9, ..., 236, 136, 135], dtype=uint8))]
# Lower Body Vectors: [(array([ 75,  76,  80, ..., 161, 152, 146], dtype=uint8), array([ 72,  73,  77, ..., 161, 152, 146], dtype=uint8), array([ 68,  69,  73, ..., 161, 152, 146], dtype=uint8))]
# Accessory Vectors: [(array([46, 46, 44, ..., 83, 83, 83], dtype=uint8), array([43, 43, 41, ..., 84, 84, 84], dtype=uint8), array([39, 39, 37, ..., 82, 82, 82], dtype=uint8)), (array([ 32,  31,  28, ..., 186, 190, 192], dtype=uint8), array([ 28,  27,  24, ..., 187, 191, 193], dtype=uint8), array([ 23,  22,  19, ..., 185, 189, 191], dtype=uint8)), (array([160, 161, 163, ..., 115, 116, 116], dtype=uint8), array([159, 160, 162, ..., 115, 116, 116], dtype=uint8), array([149, 150, 152, ..., 115, 116, 116], dtype=uint8)), (array([140, 140, 140, ..., 123, 123, 123], dtype=uint8), array([139, 139, 139, ..., 116, 116, 116], dtype=uint8), array([143, 143, 143, ..., 113, 113, 113], dtype=uint8))]
#
#
# Image: image_1057_jpg.rf.0c8fdbac8e8996265b7d03d4128bbb15.jpg
# Upper Body Vectors: [(array([131, 129, 126, ...,  90,  92,  93], dtype=uint8), array([142, 140, 137, ..., 112, 114, 115], dtype=uint8), array([146, 145, 141, ..., 124, 126, 127], dtype=uint8))]
# Lower Body Vectors: [(array([43, 42, 43, ..., 98, 97, 95], dtype=uint8), array([ 55,  54,  55, ..., 104, 103, 101], dtype=uint8), array([ 57,  56,  57, ..., 100,  98,  96], dtype=uint8))]
# Accessory Vectors: [(array([ 85,  62,  54, ..., 137, 134, 120], dtype=uint8), array([ 93,  70,  62, ..., 154, 150, 135], dtype=uint8), array([ 93,  70,  62, ..., 157, 153, 138], dtype=uint8)), (array([ 41,  41,  41, ..., 178, 181, 181], dtype=uint8), array([ 39,  39,  40, ..., 182, 184, 185], dtype=uint8), array([ 38,  38,  38, ..., 176, 179, 179], dtype=uint8)), (array([52, 48, 42, ...,  8,  8,  8], dtype=uint8), array([49, 45, 39, ...,  9,  9,  9], dtype=uint8), array([44, 40, 34, ...,  7,  7,  7], dtype=uint8)), (array([48, 48, 49, ..., 51, 46, 43], dtype=uint8), array([49, 49, 50, ..., 48, 43, 40], dtype=uint8), array([45, 45, 46, ..., 40, 35, 32], dtype=uint8))]
#
#
# Image: image_1066_jpg.rf.48880fa2d4095ac05bafead1aa325be2.jpg
# Upper Body Vectors: [(array([167, 168, 167, ..., 169, 165, 123], dtype=uint8), array([186, 185, 184, ..., 183, 180, 137], dtype=uint8), array([201, 204, 203, ..., 201, 199, 155], dtype=uint8))]
# Lower Body Vectors: [(array([178, 169, 156, ..., 184, 183, 183], dtype=uint8), array([199, 190, 176, ..., 198, 197, 197], dtype=uint8), array([221, 214, 201, ..., 217, 216, 216], dtype=uint8))]
# Accessory Vectors: [(array([157, 157, 160, ..., 186, 182, 187], dtype=uint8), array([168, 168, 171, ..., 201, 197, 202], dtype=uint8), array([176, 176, 176, ..., 218, 213, 218], dtype=uint8)), (array([157, 155, 153, ..., 155, 171, 177], dtype=uint8), array([166, 164, 162, ..., 164, 180, 185], dtype=uint8), array([179, 177, 175, ..., 178, 194, 201], dtype=uint8))]
#
#
# Image: image_106_jpg.rf.3bbb388af3a4bc0cae6ace397da67ef7.jpg
# Upper Body Vectors: [(array([163, 161, 170, ...,  74,  73,  87], dtype=uint8), array([190, 191, 204, ...,  60,  61,  77], dtype=uint8), array([203, 206, 220, ...,  42,  43,  59], dtype=uint8))]
# Lower Body Vectors: [(array([181, 163, 139, ..., 238, 238, 234], dtype=uint8), array([146, 124,  98, ..., 211, 212, 212], dtype=uint8), array([103,  76,  49, ..., 197, 198, 196], dtype=uint8))]
# Accessory Vectors: [(array([85, 86, 87, ..., 70, 69, 69], dtype=uint8), array([ 99,  99, 100, ...,  82,  82,  81], dtype=uint8), array([118, 119, 119, ...,  92,  91,  91], dtype=uint8)), (array([234, 236, 236, ...,  58,  65,  42], dtype=uint8), array([198, 199, 201, ...,  97, 104,  81], dtype=uint8), array([168, 170, 168, ..., 127, 136, 113], dtype=uint8))]
#
#
# Image: image_1070_jpg.rf.ee1c763c746baf81759e50d8923d7fdd.jpg
# Upper Body Vectors: [(array([181, 182, 181, ..., 159, 162, 166], dtype=uint8), array([194, 195, 194, ..., 154, 157, 161], dtype=uint8), array([196, 197, 196, ..., 156, 158, 163], dtype=uint8))]
# Lower Body Vectors: [(array([ 81, 100, 104, ...,  11,  16,  19], dtype=uint8), array([ 89, 109, 113, ...,   4,   9,  12], dtype=uint8), array([121, 148, 158, ...,   3,   6,   9], dtype=uint8))]
# Accessory Vectors: [(array([188, 190, 205, ..., 169, 167, 169], dtype=uint8), array([188, 187, 202, ..., 171, 171, 173], dtype=uint8), array([182, 182, 196, ..., 166, 166, 168], dtype=uint8)), (array([ 26,  26,  29, ..., 205, 206, 206], dtype=uint8), array([ 24,  24,  26, ..., 205, 206, 206], dtype=uint8), array([ 30,  30,  33, ..., 206, 206, 206], dtype=uint8)), (array([139, 138, 137, ..., 136, 138, 140], dtype=uint8), array([149, 148, 146, ..., 137, 139, 141], dtype=uint8), array([149, 148, 146, ..., 135, 137, 139], dtype=uint8)), (array([ 32,  21,  22, ..., 140, 150, 162], dtype=uint8), array([ 34,  23,  22, ..., 136, 146, 158], dtype=uint8), array([ 34,  23,  22, ..., 132, 140, 153], dtype=uint8))]
#
#
# Image: image_1077_jpg.rf.e81c64fe961ea59d65a3a11703fd0517.jpg
# Upper Body Vectors: [(array([241, 223, 191, ..., 189, 197, 199], dtype=uint8), array([241, 223, 191, ..., 195, 198, 200], dtype=uint8), array([247, 229, 200, ..., 214, 219, 221], dtype=uint8))]
# Lower Body Vectors: [(array([11, 12, 11, ..., 32, 31, 32], dtype=uint8), array([ 9, 11, 10, ..., 30, 30, 32], dtype=uint8), array([ 1,  1,  1, ..., 20, 20, 20], dtype=uint8))]
# Accessory Vectors: [(array([148, 150, 148, ..., 188, 188, 186], dtype=uint8), array([149, 148, 149, ..., 185, 185, 182], dtype=uint8), array([147, 148, 147, ..., 180, 180, 177], dtype=uint8)), (array([ 25,  24,  18, ..., 215, 214, 214], dtype=uint8), array([ 21,  20,  14, ..., 207, 206, 206], dtype=uint8), array([ 16,  15,   9, ..., 200, 199, 199], dtype=uint8))]
#
#
# Image: image_1083_jpg.rf.b9baba5eaaee9e93abfb62d212c2287d.jpg
# Upper Body Vectors: [(array([166, 170, 177, ..., 192, 195, 200], dtype=uint8), array([175, 179, 186, ..., 197, 200, 205], dtype=uint8), array([184, 189, 195, ..., 196, 199, 204], dtype=uint8))]
# Lower Body Vectors: [(array([130, 132, 135, ..., 167, 164, 162], dtype=uint8), array([134, 133, 133, ..., 179, 177, 175], dtype=uint8), array([127, 122, 122, ..., 178, 175, 173], dtype=uint8))]
# Accessory Vectors: [(array([133, 132, 132, ..., 174, 174, 174], dtype=uint8), array([140, 139, 137, ..., 187, 187, 187], dtype=uint8), array([143, 142, 139, ..., 189, 189, 189], dtype=uint8)), (array([  0,   0,   1, ..., 176, 175, 174], dtype=uint8), array([  0,   0,   0, ..., 190, 189, 188], dtype=uint8), array([  1,   1,   2, ..., 189, 188, 187], dtype=uint8))]
#
#
# Image: image_1087_jpg.rf.5ab429705537b9e1a912f3e52df19faa.jpg
# Upper Body Vectors: [(array([200, 212, 175, ...,  45,  50,  50], dtype=uint8), array([212, 223, 184, ...,  56,  62,  62], dtype=uint8), array([217, 227, 188, ...,  62,  67,  68], dtype=uint8))]
# Lower Body Vectors: [(array([55, 55, 61, ..., 93, 87, 81], dtype=uint8), array([ 65,  65,  70, ..., 108, 102,  96], dtype=uint8), array([ 90,  91,  99, ..., 117, 111, 105], dtype=uint8))]
# Accessory Vectors: [(array([ 89,  93, 102, ...,  27,  26,  26], dtype=uint8), array([107, 111, 120, ...,  31,  30,  30], dtype=uint8), array([114, 118, 127, ...,  32,  31,  31], dtype=uint8)), (array([19, 21, 24, ..., 72, 72, 73], dtype=uint8), array([21, 23, 26, ..., 90, 89, 89], dtype=uint8), array([22, 24, 27, ..., 97, 96, 96], dtype=uint8))]
#
#
# Image: image_1089_jpg.rf.fabc6bde4c11fcf7b7772009285be837.jpg
# Upper Body Vectors: [(array([185, 188, 195, ...,  72, 118, 131], dtype=uint8), array([201, 199, 206, ...,  88, 131, 144], dtype=uint8), array([210, 207, 213, ...,  94, 139, 152], dtype=uint8))]
# Lower Body Vectors: [(array([116, 125, 128, ..., 105, 146, 154], dtype=uint8), array([103, 112, 113, ..., 108, 149, 159], dtype=uint8), array([105, 113, 112, ..., 113, 157, 168], dtype=uint8))]
# Accessory Vectors: [(array([ 50,  50,  50, ..., 102, 102, 102], dtype=uint8), array([ 55,  55,  55, ..., 120, 120, 120], dtype=uint8), array([ 54,  54,  54, ..., 127, 127, 127], dtype=uint8)), (array([ 8,  8,  7, ..., 69, 71, 72], dtype=uint8), array([ 7,  7,  5, ..., 78, 80, 81], dtype=uint8), array([ 9,  9,  7, ..., 81, 84, 84], dtype=uint8))]
#
#
# Image: image_1091_jpg.rf.7fe18266919f83b12f2da96f3df78429.jpg
# Upper Body Vectors: [(array([ 80,  85, 118, ..., 199, 196, 197], dtype=uint8), array([ 92,  97, 130, ..., 197, 195, 197], dtype=uint8), array([101, 107, 141, ..., 197, 193, 195], dtype=uint8))]
# Lower Body Vectors: [(array([201, 208, 218, ...,  86,  88,  89], dtype=uint8), array([178, 184, 193, ...,  61,  63,  64], dtype=uint8), array([162, 166, 173, ...,  41,  43,  44], dtype=uint8))]
# Accessory Vectors: []
#
#
# Image: image_1096_jpg.rf.fc16e5f5d4899338671a4801f06d0bfb.jpg
# Upper Body Vectors: [(array([179, 164, 165, ..., 220, 222, 225], dtype=uint8), array([181, 167, 168, ..., 245, 243, 242], dtype=uint8), array([169, 155, 156, ..., 251, 244, 237], dtype=uint8))]
# Lower Body Vectors: [(array([20, 22, 26, ..., 25, 25, 26], dtype=uint8), array([12, 14, 18, ..., 26, 27, 27], dtype=uint8), array([ 5,  7, 10, ..., 24, 24, 25], dtype=uint8))]
# Accessory Vectors: [(array([203, 203, 203, ...,  16,  14,  14], dtype=uint8), array([166, 165, 164, ...,  15,  13,  13], dtype=uint8), array([140, 139, 137, ...,  11,   9,   9], dtype=uint8)), (array([205, 205, 208, ..., 150, 141, 139], dtype=uint8), array([195, 195, 199, ..., 164, 155, 154], dtype=uint8), array([195, 195, 199, ..., 172, 164, 163], dtype=uint8))]
#
#
# Image: image_1109_jpg.rf.ac5fe5a213e8b618c4af2045bc9dec6b.jpg
# Upper Body Vectors: [(array([39, 39, 32, ..., 87, 83, 81], dtype=uint8), array([53, 53, 46, ..., 90, 86, 84], dtype=uint8), array([52, 52, 45, ..., 88, 84, 80], dtype=uint8))]
# Lower Body Vectors: [(array([ 55,  57,  55, ..., 107,  91,  90], dtype=uint8), array([ 50,  52,  50, ..., 149, 134, 134], dtype=uint8), array([ 51,  53,  51, ..., 137, 120, 120], dtype=uint8))]
# Accessory Vectors: [(array([175, 175, 169, ...,  24,  16,  16], dtype=uint8), array([181, 181, 174, ...,  21,  13,  13], dtype=uint8), array([188, 188, 181, ...,  17,   9,   9], dtype=uint8)), (array([11,  9,  1, ..., 19, 21, 23], dtype=uint8), array([11,  9,  1, ..., 22, 23, 26], dtype=uint8), array([11,  9,  1, ..., 20, 23, 24], dtype=uint8)), (array([29, 28, 28, ..., 79, 77, 79], dtype=uint8), array([34, 33, 33, ..., 79, 78, 81], dtype=uint8), array([32, 31, 31, ..., 79, 78, 81], dtype=uint8))]
#
#
# Image: image_1116_jpg.rf.0617822c6bcbd82e6fb26cdfe40ecfef.jpg
# Upper Body Vectors: [(array([157, 165, 162, ...,  55, 219, 206], dtype=uint8), array([165, 170, 166, ...,  50, 214, 201], dtype=uint8), array([162, 168, 164, ...,  48, 211, 198], dtype=uint8))]
# Lower Body Vectors: [(array([ 11,  12,  13, ...,  71, 165, 190], dtype=uint8), array([  7,   6,   6, ...,  70, 168, 194], dtype=uint8), array([  3,   3,   3, ...,  70, 170, 198], dtype=uint8))]
# Accessory Vectors: [(array([172, 172, 172, ..., 179, 179, 179], dtype=uint8), array([184, 184, 184, ..., 185, 185, 185], dtype=uint8), array([188, 188, 188, ..., 190, 190, 190], dtype=uint8)), (array([173, 171, 171, ...,  84,  88,  88], dtype=uint8), array([176, 174, 174, ...,  93,  98,  99], dtype=uint8), array([181, 179, 179, ..., 105, 108, 107], dtype=uint8))]
#
#
# Image: image_1124_jpg.rf.bc3a1f6f9fa592f046801a92834ec228.jpg
# Upper Body Vectors: [(array([231, 222, 222, ...,   8,  10,   9], dtype=uint8), array([233, 221, 221, ...,   4,   6,   5], dtype=uint8), array([234, 223, 223, ...,   3,   5,   4], dtype=uint8))]
# Lower Body Vectors: [(array([  5,   9,  11, ..., 216, 216, 221], dtype=uint8), array([  8,  10,  12, ..., 214, 214, 220], dtype=uint8), array([  6,   8,  10, ..., 212, 213, 219], dtype=uint8))]
# Accessory Vectors: [(array([104, 104, 104, ..., 122, 122, 123], dtype=uint8), array([104, 104, 104, ..., 120, 120, 121], dtype=uint8), array([104, 104, 104, ..., 120, 120, 121], dtype=uint8)), (array([ 35,  34,  34, ..., 136, 136, 136], dtype=uint8), array([ 33,  32,  32, ..., 136, 136, 136], dtype=uint8), array([ 33,  32,  32, ..., 136, 136, 136], dtype=uint8))]
#
#
# Image: image_120_jpg.rf.4dba2f58d325fb9680b762acdbbe6b1c.jpg
# Upper Body Vectors: [(array([120, 104, 104, ..., 208, 210, 215], dtype=uint8), array([106,  90,  92, ..., 220, 222, 224], dtype=uint8), array([ 99,  83,  85, ..., 222, 224, 227], dtype=uint8))]
# Lower Body Vectors: [(array([207, 208, 210, ..., 213, 212, 211], dtype=uint8), array([212, 216, 218, ..., 219, 218, 217], dtype=uint8), array([213, 216, 218, ..., 224, 223, 222], dtype=uint8))]
# Accessory Vectors: []
#
#
# Image: image_123_jpg.rf.df1f424a95544ae7e1ec4784e8055fc8.jpg
# Upper Body Vectors: [(array([219, 217, 226, ..., 213, 213, 213], dtype=uint8), array([224, 222, 231, ..., 218, 218, 218], dtype=uint8), array([223, 221, 230, ..., 217, 217, 217], dtype=uint8))]
# Lower Body Vectors: [(array([94, 74, 66, ..., 23, 16, 21], dtype=uint8), array([92, 73, 64, ..., 20, 14, 21], dtype=uint8), array([91, 72, 63, ..., 22, 15, 21], dtype=uint8))]
# Accessory Vectors: [(array([169, 166, 162, ..., 160, 165, 168], dtype=uint8), array([169, 166, 162, ..., 164, 169, 172], dtype=uint8), array([169, 166, 162, ..., 165, 170, 173], dtype=uint8)), (array([151, 148, 154, ..., 180, 180, 179], dtype=uint8), array([156, 153, 159, ..., 180, 180, 179], dtype=uint8), array([155, 152, 158, ..., 178, 180, 179], dtype=uint8))]
#
#
# Image: image_128_jpg.rf.399efdd7d747517f95a07aac042d6039.jpg
# Upper Body Vectors: [(array([229, 223, 224, ..., 223, 226, 231], dtype=uint8), array([227, 221, 222, ..., 219, 222, 228], dtype=uint8), array([226, 220, 221, ..., 218, 221, 226], dtype=uint8))]
# Lower Body Vectors: [(array([188, 228, 221, ..., 109, 109, 110], dtype=uint8), array([187, 224, 219, ..., 117, 118, 119], dtype=uint8), array([184, 217, 208, ..., 126, 128, 129], dtype=uint8))]
# Accessory Vectors: [(array([218, 218, 218, ..., 174, 173, 173], dtype=uint8), array([206, 206, 206, ..., 168, 167, 167], dtype=uint8), array([206, 206, 206, ..., 169, 168, 168], dtype=uint8)), (array([132, 135, 134, ..., 139, 141, 141], dtype=uint8), array([120, 121, 121, ..., 142, 145, 147], dtype=uint8), array([110, 111, 111, ..., 150, 153, 154], dtype=uint8))]
#
#
# Image: image_131_jpg.rf.a9d0f4d8ec1cc3aca2dc02322d6b970c.jpg
# Upper Body Vectors: [(array([184, 184, 185, ..., 216, 215, 215], dtype=uint8), array([190, 189, 190, ..., 217, 216, 217], dtype=uint8), array([189, 189, 189, ..., 213, 212, 211], dtype=uint8))]
# Lower Body Vectors: [(array([ 12,  23,  26, ..., 184, 176, 166], dtype=uint8), array([  3,  16,  18, ..., 182, 175, 167], dtype=uint8), array([  0,   7,   6, ..., 177, 171, 163], dtype=uint8))]
# Accessory Vectors: [(array([131, 130, 129, ..., 172, 170, 168], dtype=uint8), array([137, 136, 134, ..., 169, 167, 165], dtype=uint8), array([136, 135, 134, ..., 165, 164, 161], dtype=uint8)), (array([ 21,  24,  24, ..., 180, 180, 180], dtype=uint8), array([ 12,  12,  12, ..., 181, 181, 181], dtype=uint8), array([  9,  10,  10, ..., 177, 177, 177], dtype=uint8))]
#
#
# Image: image_148_jpg.rf.34996049bd921a1a2f2d250aac91b930.jpg
# Upper Body Vectors: [(array([13, 26, 26, ..., 13, 13, 13], dtype=uint8), array([18, 29, 30, ..., 13, 13, 13], dtype=uint8), array([18, 30, 31, ..., 13, 13, 13], dtype=uint8))]
# Lower Body Vectors: [(array([36, 37, 37, ...,  3,  2,  0], dtype=uint8), array([34, 35, 35, ...,  3,  2,  0], dtype=uint8), array([33, 34, 34, ...,  3,  2,  0], dtype=uint8))]
# Accessory Vectors: [(array([27, 27, 32, ..., 55, 53, 53], dtype=uint8), array([25, 25, 30, ..., 56, 54, 54], dtype=uint8), array([25, 25, 30, ..., 54, 52, 52], dtype=uint8)), (array([103, 101,  97, ..., 106,  88,  81], dtype=uint8), array([101,  99,  95, ..., 113,  95,  89], dtype=uint8), array([100,  98,  94, ..., 119, 102,  96], dtype=uint8)), (array([108, 109, 110, ...,  97, 100, 101], dtype=uint8), array([111, 112, 114, ..., 102, 105, 106], dtype=uint8), array([109, 109, 112, ..., 103, 106, 107], dtype=uint8))]
#
#
# Image: image_152_jpg.rf.878d23ed95047584f35ca84d8075b2cb.jpg
# Upper Body Vectors: [(array([134, 136, 136, ..., 202, 202, 204], dtype=uint8), array([147, 151, 152, ..., 203, 203, 205], dtype=uint8), array([149, 154, 155, ..., 201, 201, 203], dtype=uint8))]
# Lower Body Vectors: [(array([60, 76, 77, ...,  4,  1, 47], dtype=uint8), array([ 77, 101, 101, ...,   9,   6,  57], dtype=uint8), array([ 98, 121, 123, ...,   7,   5,  56], dtype=uint8))]
# Accessory Vectors: [(array([150, 150, 151, ..., 162, 162, 161], dtype=uint8), array([163, 163, 163, ..., 173, 172, 171], dtype=uint8), array([171, 171, 173, ..., 173, 172, 171], dtype=uint8)), (array([ 23,  24,  25, ..., 115, 118, 122], dtype=uint8), array([ 19,  19,  22, ..., 130, 133, 137], dtype=uint8), array([ 18,  18,  20, ..., 133, 136, 140], dtype=uint8))]
#
#
# Image: image_160_jpg.rf.7e92b1133933406495b485f943f5c322.jpg
# Upper Body Vectors: [(array([159, 177, 145, ..., 177, 110,  38], dtype=uint8), array([177, 194, 159, ..., 182, 115,  44], dtype=uint8), array([180, 195, 159, ..., 180, 114,  43], dtype=uint8))]
# Lower Body Vectors: [(array([ 17,  23,  27, ..., 185, 186, 186], dtype=uint8), array([ 18,  23,  28, ..., 185, 186, 186], dtype=uint8), array([ 18,  23,  28, ..., 179, 180, 180], dtype=uint8))]
# Accessory Vectors: [(array([145, 147, 149, ..., 148, 151, 154], dtype=uint8), array([150, 152, 154, ..., 149, 152, 155], dtype=uint8), array([149, 151, 153, ..., 147, 150, 153], dtype=uint8)), (array([229, 227, 225, ..., 200, 222, 234], dtype=uint8), array([230, 228, 226, ..., 201, 223, 235], dtype=uint8), array([226, 225, 222, ..., 205, 227, 239], dtype=uint8))]
#
#
# Image: image_163_jpg.rf.5b59bad0e855f62e6a174aa234d27b02.jpg
# Upper Body Vectors: [(array([207, 228, 228, ..., 170, 170, 189], dtype=uint8), array([190, 206, 204, ..., 150, 153, 174], dtype=uint8), array([175, 186, 179, ..., 141, 146, 171], dtype=uint8))]
# Lower Body Vectors: [(array([212, 205, 205, ...,  53,  53,  50], dtype=uint8), array([188, 183, 185, ...,  56,  56,  53], dtype=uint8), array([160, 153, 154, ...,  60,  61,  59], dtype=uint8))]
# Accessory Vectors: [(array([184, 184, 184, ..., 229, 219, 212], dtype=uint8), array([227, 227, 227, ..., 218, 208, 201], dtype=uint8), array([248, 248, 248, ..., 220, 210, 203], dtype=uint8)), (array([219, 222, 227, ...,  36,  34,  33], dtype=uint8), array([234, 236, 243, ...,  42,  40,  39], dtype=uint8), array([247, 250, 254, ...,  40,  38,  37], dtype=uint8)), (array([ 78,  77,  79, ..., 109, 118, 111], dtype=uint8), array([ 79,  77,  79, ..., 123, 134, 133], dtype=uint8), array([ 75,  71,  73, ..., 142, 153, 151], dtype=uint8)), (array([ 43,  40,  34, ..., 240, 239, 238], dtype=uint8), array([ 33,  30,  24, ..., 214, 214, 213], dtype=uint8), array([ 26,  23,  17, ..., 177, 175, 173], dtype=uint8))]
#
#
# Image: image_171_jpg.rf.6c214620352691ca401345a780e81f27.jpg
# Upper Body Vectors: [(array([144, 147, 141, ...,  29,  31,  62], dtype=uint8), array([142, 145, 139, ...,  29,  31,  62], dtype=uint8), array([141, 144, 138, ...,  29,  31,  62], dtype=uint8))]
# Lower Body Vectors: [(array([152, 169, 192, ..., 112, 111, 106], dtype=uint8), array([149, 166, 189, ..., 110, 109, 106], dtype=uint8), array([145, 162, 185, ..., 109, 108, 106], dtype=uint8))]
# Accessory Vectors: []
#
#
# Image: image_178_jpg.rf.a668f5aeefcc6feaa801cb30abe176e9.jpg
# Upper Body Vectors: [(array([194, 194, 193, ..., 201, 201, 201], dtype=uint8), array([194, 196, 195, ..., 201, 201, 201], dtype=uint8), array([194, 196, 195, ..., 201, 201, 201], dtype=uint8))]
# Lower Body Vectors: [(array([198, 204, 206, ...,  82,  89,  74], dtype=uint8), array([198, 204, 206, ...,  84,  92,  76], dtype=uint8), array([198, 204, 206, ...,  85,  96,  78], dtype=uint8))]
# Accessory Vectors: [(array([153, 152, 150, ..., 126, 127, 127], dtype=uint8), array([143, 142, 142, ..., 119, 120, 120], dtype=uint8), array([143, 142, 142, ..., 122, 123, 123], dtype=uint8)), (array([63, 64, 77, ..., 51, 51, 51], dtype=uint8), array([60, 59, 72, ..., 52, 52, 52], dtype=uint8), array([62, 60, 73, ..., 56, 56, 56], dtype=uint8))]
#
#
# Image: image_181_jpg.rf.e47a6fb9655f6b0242b65a62ebbe0c0e.jpg
# Upper Body Vectors: [(array([ 97,  55,  27, ...,  25,  88, 146], dtype=uint8), array([101,  58,  28, ...,  28,  93, 150], dtype=uint8), array([104,  62,  32, ...,  28,  92, 151], dtype=uint8))]
# Lower Body Vectors: [(array([138,  98, 104, ...,  13,  23,  24], dtype=uint8), array([143, 104, 109, ...,  13,  23,  24], dtype=uint8), array([144, 103, 108, ...,  13,  23,  24], dtype=uint8))]
# Accessory Vectors: [(array([146, 149, 155, ..., 149, 151, 153], dtype=uint8), array([150, 153, 159, ..., 154, 156, 158], dtype=uint8), array([151, 155, 160, ..., 155, 157, 159], dtype=uint8)), (array([ 73,  74,  76, ..., 159, 180, 188], dtype=uint8), array([ 71,  72,  74, ..., 163, 183, 192], dtype=uint8), array([ 71,  72,  74, ..., 164, 184, 193], dtype=uint8))]
#
#
# Image: image_182_jpg.rf.fb3136c34ac7a1254d8e11d097348528.jpg
# Upper Body Vectors: [(array([ 24,  21,  65, ..., 201, 213, 198], dtype=uint8), array([ 16,  18,  64, ..., 205, 216, 199], dtype=uint8), array([ 13,  15,  62, ..., 200, 207, 187], dtype=uint8))]
# Lower Body Vectors: [(array([ 18,  19,  18, ..., 191, 186, 177], dtype=uint8), array([  6,   7,   9, ..., 196, 193, 185], dtype=uint8), array([  4,   5,   6, ..., 211, 208, 199], dtype=uint8))]
# Accessory Vectors: [(array([138, 137, 136, ...,  88,  88,  89], dtype=uint8), array([143, 143, 144, ...,  94,  94,  95], dtype=uint8), array([142, 142, 143, ...,  93,  93,  94], dtype=uint8)), (array([109, 106, 105, ...,  75,  76,  77], dtype=uint8), array([115, 113, 111, ...,  80,  81,  82], dtype=uint8), array([114, 112, 111, ...,  81,  82,  83], dtype=uint8))]
#
#
# Image: image_186_jpg.rf.67314d3299b733c798db240e7db63560.jpg
# Upper Body Vectors: [(array([ 74,  71,  72, ..., 212, 219, 210], dtype=uint8), array([ 35,  30,  31, ..., 182, 191, 182], dtype=uint8), array([ 13,   8,  10, ..., 154, 165, 158], dtype=uint8))]
# Lower Body Vectors: [(array([51, 52, 48, ..., 50, 48, 48], dtype=uint8), array([39, 40, 37, ..., 40, 38, 38], dtype=uint8), array([27, 28, 25, ..., 33, 31, 31], dtype=uint8))]
# Accessory Vectors: [(array([60, 55, 53, ..., 42, 40, 41], dtype=uint8), array([27, 22, 21, ..., 18, 16, 15], dtype=uint8), array([11,  6,  4, ...,  0,  0,  0], dtype=uint8))]
#
#
# Image: image_18_jpg.rf.de3761b2f51c588107f254ed6a0968ec.jpg
# Upper Body Vectors: [(array([154, 131, 101, ...,  95, 156, 172], dtype=uint8), array([157, 133, 103, ..., 101, 162, 177], dtype=uint8), array([156, 133, 103, ...,  99, 161, 176], dtype=uint8))]
# Lower Body Vectors: [(array([187, 174, 145, ...,  80,  72,  58], dtype=uint8), array([182, 169, 137, ...,  77,  70,  58], dtype=uint8), array([179, 166, 135, ...,  73,  69,  58], dtype=uint8))]
# Accessory Vectors: [(array([157, 157, 157, ..., 145, 145, 144], dtype=uint8), array([153, 153, 153, ..., 139, 138, 138], dtype=uint8), array([148, 148, 148, ..., 128, 129, 127], dtype=uint8)), (array([122, 122, 121, ...,  82,  84,  85], dtype=uint8), array([119, 119, 118, ...,  76,  76,  77], dtype=uint8), array([115, 115, 113, ...,  69,  69,  70], dtype=uint8)), (array([100, 101, 100, ...,  67,  65,  64], dtype=uint8), array([94, 95, 94, ..., 64, 62, 61], dtype=uint8), array([95, 96, 95, ..., 60, 58, 57], dtype=uint8))]
#
#
# Image: image_194_jpg.rf.bc7d0852cb6d6c7301c80294d8c90135.jpg
# Upper Body Vectors: [(array([184, 176, 192, ...,  29,  21,  14], dtype=uint8), array([200, 196, 212, ...,  19,  11,   4], dtype=uint8), array([199, 192, 209, ...,  10,   2,   0], dtype=uint8))]
# Lower Body Vectors: [(array([105,  92,  89, ...,  86,  85, 138], dtype=uint8), array([112, 100,  97, ...,  75,  74, 127], dtype=uint8), array([150, 137, 132, ...,  71,  70, 123], dtype=uint8))]
# Accessory Vectors: [(array([126, 125, 125, ...,  53,  54,  55], dtype=uint8), array([128, 127, 126, ...,  60,  61,  62], dtype=uint8), array([129, 128, 127, ...,  63,  64,  65], dtype=uint8)), (array([ 60,  61,  61, ..., 166, 160, 164], dtype=uint8), array([ 51,  52,  52, ..., 154, 148, 152], dtype=uint8), array([ 47,  48,  48, ..., 142, 136, 142], dtype=uint8)), (array([ 36,  36,  36, ..., 137, 137, 137], dtype=uint8), array([ 23,  23,  23, ..., 144, 144, 144], dtype=uint8), array([ 15,  15,  15, ..., 147, 147, 147], dtype=uint8))]
#
#
# Image: image_198_jpg.rf.6c6b82d324fd93661d99d057ef0aa721.jpg
# Upper Body Vectors: [(array([92, 91, 88, ..., 92, 95, 99], dtype=uint8), array([ 99,  97,  94, ..., 101, 104, 108], dtype=uint8), array([ 98,  96,  93, ...,  98, 101, 105], dtype=uint8))]
# Lower Body Vectors: [(array([152, 122,  64, ...,  24,  19,  16], dtype=uint8), array([152, 120,  61, ...,  20,  16,  12], dtype=uint8), array([152, 118,  57, ...,  17,  12,   8], dtype=uint8))]
# Accessory Vectors: [(array([206, 205, 204, ..., 235, 233, 233], dtype=uint8), array([211, 210, 209, ..., 227, 227, 227], dtype=uint8), array([210, 209, 208, ..., 217, 216, 216], dtype=uint8)), (array([218, 218, 219, ...,  84,  79,  77], dtype=uint8), array([220, 220, 221, ...,  79,  74,  72], dtype=uint8), array([221, 221, 222, ...,  78,  73,  71], dtype=uint8)), (array([ 91,  72,  54, ..., 134, 132, 130], dtype=uint8), array([ 88,  69,  51, ..., 136, 134, 132], dtype=uint8), array([ 84,  64,  46, ..., 136, 134, 132], dtype=uint8)), (array([194, 199, 207, ...,  34,  31,  30], dtype=uint8), array([203, 207, 215, ...,  27,  26,  25], dtype=uint8), array([212, 216, 224, ...,  25,  24,  24], dtype=uint8))]
#
#
# Image: image_200_jpg.rf.902dab84bd050b5d107986bd169a34b6.jpg
# Upper Body Vectors: [(array([198, 207, 156, ...,  48,  50,  36], dtype=uint8), array([171, 180, 132, ...,  43,  42,  26], dtype=uint8), array([153, 154, 101, ...,  25,  29,  17], dtype=uint8))]
# Lower Body Vectors: [(array([151, 128,  92, ...,  90,  90,  91], dtype=uint8), array([150, 128,  93, ...,  93,  93,  94], dtype=uint8), array([154, 132,  97, ...,  97,  97,  98], dtype=uint8))]
# Accessory Vectors: [(array([198, 198, 205, ..., 175, 177, 176], dtype=uint8), array([199, 198, 203, ..., 180, 182, 181], dtype=uint8), array([197, 197, 203, ..., 178, 181, 180], dtype=uint8))]
#
#
# Image: image_20_jpg.rf.4bcf40cec2184e238047901fd73acbae.jpg
# Upper Body Vectors: [(array([111,  71,  56, ..., 251, 245, 224], dtype=uint8), array([115,  74,  59, ..., 253, 247, 228], dtype=uint8), array([112,  72,  57, ..., 248, 242, 223], dtype=uint8))]
# Lower Body Vectors: [(array([93,  5, 13, ..., 15, 15, 17], dtype=uint8), array([93,  5, 14, ..., 16, 15, 18], dtype=uint8), array([93,  8, 23, ..., 14, 14, 16], dtype=uint8))]
# Accessory Vectors: []
#
#
# Image: image_212_jpg.rf.073c24fb4b9d94c443bafa6785297b36.jpg
# Upper Body Vectors: [(array([241, 236, 231, ..., 155, 206, 213], dtype=uint8), array([236, 230, 223, ..., 169, 217, 223], dtype=uint8), array([233, 227, 221, ..., 189, 232, 236], dtype=uint8))]
# Lower Body Vectors: [(array([220, 222, 223, ..., 183, 182, 182], dtype=uint8), array([216, 217, 218, ..., 191, 191, 190], dtype=uint8), array([215, 217, 217, ..., 198, 196, 197], dtype=uint8))]
# Accessory Vectors: [(array([220, 220, 220, ..., 200, 206, 210], dtype=uint8), array([225, 225, 225, ..., 205, 211, 215], dtype=uint8), array([226, 226, 226, ..., 206, 212, 216], dtype=uint8)), (array([174, 183, 193, ..., 204, 204, 201], dtype=uint8), array([169, 175, 183, ..., 207, 207, 206], dtype=uint8), array([170, 175, 183, ..., 211, 211, 209], dtype=uint8))]
#
#
# Image: image_218_jpg.rf.67310f621f864dbb8ccdfa098bb90bc7.jpg
# Upper Body Vectors: [(array([ 19,  15,  21, ..., 116, 126, 129], dtype=uint8), array([ 21,  16,  20, ..., 122, 134, 139], dtype=uint8), array([ 21,  16,  21, ..., 121, 133, 137], dtype=uint8))]
# Lower Body Vectors: [(array([73, 73, 72, ..., 63, 60, 59], dtype=uint8), array([78, 78, 77, ..., 79, 76, 75], dtype=uint8), array([77, 76, 75, ..., 91, 88, 87], dtype=uint8))]
# Accessory Vectors: [(array([182, 180, 175, ..., 158, 165, 168], dtype=uint8), array([183, 180, 175, ..., 181, 188, 191], dtype=uint8), array([193, 190, 185, ..., 189, 196, 199], dtype=uint8)), (array([91, 91, 91, ...,  0,  0,  0], dtype=uint8), array([94, 94, 94, ..., 11, 11, 11], dtype=uint8), array([139, 139, 139, ...,  42,  42,  42], dtype=uint8)), (array([244, 176, 109, ...,  30,  30,  56], dtype=uint8), array([250, 177, 106, ...,  34,  35,  60], dtype=uint8), array([243, 171, 102, ...,  23,  25,  57], dtype=uint8))]
#
#
# Image: image_223_jpg.rf.acd7faab7dd42d0874191a03c598308e.jpg
# Upper Body Vectors: [(array([242, 242, 240, ..., 171, 169, 168], dtype=uint8), array([244, 244, 242, ..., 175, 173, 172], dtype=uint8), array([245, 245, 243, ..., 180, 178, 177], dtype=uint8))]
# Lower Body Vectors: [(array([200, 198, 170, ..., 182, 183, 178], dtype=uint8), array([201, 196, 167, ..., 186, 186, 181], dtype=uint8), array([205, 199, 169, ..., 187, 188, 185], dtype=uint8))]
# Accessory Vectors: []
#
#
# Image: image_224_jpg.rf.4711efd9e72ef6656a9c95853b886692.jpg
# Upper Body Vectors: [(array([100,  83,  70, ...,  34,  19,   8], dtype=uint8), array([117,  94,  77, ...,  28,  13,   3], dtype=uint8), array([118,  94,  76, ...,  23,   8,   0], dtype=uint8))]
# Lower Body Vectors: [(array([13, 17, 20, ..., 21, 24, 28], dtype=uint8), array([15, 15, 15, ..., 16, 19, 23], dtype=uint8), array([ 6,  5,  6, ..., 13, 16, 21], dtype=uint8))]
# Accessory Vectors: [(array([189, 188, 187, ..., 152, 150, 149], dtype=uint8), array([185, 184, 183, ..., 158, 157, 156], dtype=uint8), array([174, 173, 172, ..., 161, 160, 159], dtype=uint8)), (array([153, 154, 157, ..., 233, 233, 233], dtype=uint8), array([152, 153, 156, ..., 229, 229, 229], dtype=uint8), array([148, 149, 152, ..., 228, 228, 228], dtype=uint8))]
#
#
# Image: image_226_jpg.rf.1211d5be8f2298894e79002bac4f7226.jpg
# Upper Body Vectors: [(array([203, 202, 202, ..., 175, 188, 201], dtype=uint8), array([212, 211, 211, ..., 196, 206, 216], dtype=uint8), array([209, 208, 208, ..., 214, 219, 224], dtype=uint8))]
# Lower Body Vectors: [(array([102, 101, 101, ..., 197, 198, 197], dtype=uint8), array([115, 114, 113, ..., 200, 202, 202], dtype=uint8), array([119, 117, 117, ..., 202, 203, 203], dtype=uint8))]
# Accessory Vectors: [(array([112, 115, 122, ..., 215, 215, 215], dtype=uint8), array([128, 132, 139, ..., 220, 220, 220], dtype=uint8), array([127, 130, 137, ..., 218, 218, 218], dtype=uint8))]
#
#
# Image: image_227_jpg.rf.5e1895e6230b6fcd292d107c1ba13dcf.jpg
# Upper Body Vectors: [(array([70, 51, 46, ..., 18, 20, 22], dtype=uint8), array([71, 52, 45, ..., 10, 12, 13], dtype=uint8), array([69, 50, 43, ..., 10, 12, 10], dtype=uint8))]
# Lower Body Vectors: [(array([ 50,  51,  56, ..., 210, 204, 204], dtype=uint8), array([ 42,  43,  46, ..., 201, 195, 195], dtype=uint8), array([ 42,  43,  46, ..., 197, 191, 191], dtype=uint8))]
# Accessory Vectors: [(array([225, 225, 225, ..., 122, 128, 132], dtype=uint8), array([216, 216, 216, ..., 112, 118, 123], dtype=uint8), array([213, 213, 213, ..., 112, 117, 120], dtype=uint8)), (array([ 17,  27,  36, ..., 172, 165, 171], dtype=uint8), array([  6,  16,  25, ..., 170, 163, 169], dtype=uint8), array([  2,  12,  21, ..., 164, 155, 161], dtype=uint8))]
#
#
# Image: image_228_jpg.rf.1bcd72cd55b5fe61e29838fd30e5f1ac.jpg
# Upper Body Vectors: [(array([ 97,  79,  73, ..., 251, 243, 253], dtype=uint8), array([ 95,  77,  71, ..., 247, 242, 251], dtype=uint8), array([ 95,  77,  71, ..., 246, 241, 250], dtype=uint8))]
# Lower Body Vectors: [(array([ 39,  47, 127, ...,  84, 162, 204], dtype=uint8), array([ 37,  45, 125, ...,  80, 158, 200], dtype=uint8), array([ 36,  44, 124, ...,  79, 157, 199], dtype=uint8))]
# Accessory Vectors: [(array([205, 200, 194, ...,  21,  17,  13], dtype=uint8), array([203, 198, 191, ...,  20,  15,  11], dtype=uint8), array([203, 198, 191, ...,  20,  15,  11], dtype=uint8)), (array([174, 174, 176, ...,  30,  21,  20], dtype=uint8), array([172, 172, 174, ...,  28,  19,  18], dtype=uint8), array([172, 172, 174, ...,  28,  19,  18], dtype=uint8))]
#
#
# Image: image_22_jpg.rf.34946748f116fa6cbf9cab073687334e.jpg
# Upper Body Vectors: [(array([33, 28, 22, ..., 16, 11,  7], dtype=uint8), array([25, 20, 17, ..., 11,  6,  1], dtype=uint8), array([23, 17, 16, ..., 12,  7,  3], dtype=uint8))]
# Lower Body Vectors: [(array([  7,   6,   5, ..., 128, 126, 125], dtype=uint8), array([  2,   2,   2, ..., 136, 134, 133], dtype=uint8), array([  3,   3,   2, ..., 125, 123, 122], dtype=uint8))]
# Accessory Vectors: [(array([199, 195, 201, ..., 117, 107, 113], dtype=uint8), array([177, 171, 175, ..., 121, 112, 120], dtype=uint8), array([159, 151, 155, ..., 123, 115, 123], dtype=uint8)), (array([179, 179, 159, ..., 146, 143, 143], dtype=uint8), array([170, 170, 150, ..., 149, 147, 147], dtype=uint8), array([157, 157, 137, ..., 143, 141, 141], dtype=uint8)), (array([122, 120, 116, ..., 200, 198, 197], dtype=uint8), array([103, 101,  97, ..., 191, 188, 187], dtype=uint8), array([ 95,  93,  90, ..., 178, 177, 177], dtype=uint8))]
#
#
# Image: image_231_jpg.rf.dcea28457bb0cd937f5a3807a1e0393b.jpg
# Upper Body Vectors: [(array([132, 132, 131, ..., 173, 174, 173], dtype=uint8), array([150, 151, 152, ..., 183, 182, 182], dtype=uint8), array([157, 158, 158, ..., 186, 186, 186], dtype=uint8))]
# Lower Body Vectors: [(array([141, 148, 148, ..., 113,  93,  84], dtype=uint8), array([149, 154, 153, ...,  93,  78,  70], dtype=uint8), array([156, 159, 156, ...,  75,  59,  55], dtype=uint8))]
# Accessory Vectors: [(array([125, 125, 125, ..., 187, 185, 183], dtype=uint8), array([140, 140, 140, ..., 193, 190, 190], dtype=uint8), array([149, 149, 149, ..., 198, 199, 199], dtype=uint8)), (array([ 43,  41,  41, ..., 213, 213, 212], dtype=uint8), array([ 31,  29,  29, ..., 217, 217, 216], dtype=uint8), array([ 19,  17,  17, ..., 222, 222, 221], dtype=uint8))]
#
#
# Image: image_233_jpg.rf.a0a09bac60d37b4119759fb77ea2f4ed.jpg
# Upper Body Vectors: [(array([214, 205, 202, ...,  23,  19,  12], dtype=uint8), array([212, 203, 199, ...,  26,  23,  16], dtype=uint8), array([211, 202, 198, ...,  27,  22,  16], dtype=uint8))]
# Lower Body Vectors: [(array([175, 175, 177, ...,  80,  85,  86], dtype=uint8), array([184, 184, 186, ...,  82,  86,  87], dtype=uint8), array([187, 187, 187, ..., 103, 106, 107], dtype=uint8))]
# Accessory Vectors: [(array([215, 215, 216, ..., 175, 171, 164], dtype=uint8), array([217, 217, 218, ..., 183, 180, 174], dtype=uint8), array([217, 217, 218, ..., 190, 187, 181], dtype=uint8)), (array([173, 174, 177, ..., 244, 234, 231], dtype=uint8), array([170, 171, 174, ..., 239, 229, 226], dtype=uint8), array([172, 173, 176, ..., 241, 231, 228], dtype=uint8)), (array([205, 205, 205, ...,  26,  29,  30], dtype=uint8), array([209, 209, 209, ...,  32,  35,  36], dtype=uint8), array([214, 214, 214, ...,  37,  40,  41], dtype=uint8))]
#
#
# Image: image_237_jpg.rf.62712185217eb8fa7314fe5a31e57980.jpg
# Upper Body Vectors: [(array([240, 242, 250, ..., 174, 155, 173], dtype=uint8), array([240, 242, 250, ..., 172, 152, 171], dtype=uint8), array([240, 242, 250, ..., 173, 153, 171], dtype=uint8))]
# Lower Body Vectors: [(array([17, 19, 14, ..., 16, 14, 12], dtype=uint8), array([15, 17, 12, ..., 11,  9,  8], dtype=uint8), array([15, 17, 12, ..., 12, 10,  9], dtype=uint8))]
# Accessory Vectors: [(array([186, 187, 187, ..., 148, 145, 142], dtype=uint8), array([191, 193, 193, ..., 158, 156, 153], dtype=uint8), array([200, 200, 198, ..., 162, 161, 161], dtype=uint8)), (array([ 14,  14,  15, ..., 189, 184, 182], dtype=uint8), array([ 12,  12,  13, ..., 191, 186, 184], dtype=uint8), array([ 12,  12,  13, ..., 192, 187, 185], dtype=uint8))]
#
#
# Image: image_245_jpg.rf.3e86eeb7cc239db8267caa662f31e3fd.jpg
# Upper Body Vectors: [(array([ 90,  95, 106, ..., 220, 220, 220], dtype=uint8), array([103, 107, 118, ..., 224, 224, 224], dtype=uint8), array([117, 120, 131, ..., 225, 225, 225], dtype=uint8))]
# Lower Body Vectors: [(array([212, 207, 202, ...,  43,  45,  55], dtype=uint8), array([224, 220, 214, ...,  52,  54,  64], dtype=uint8), array([230, 226, 220, ...,  66,  67,  77], dtype=uint8))]
# Accessory Vectors: [(array([113, 112, 112, ..., 106, 108, 110], dtype=uint8), array([123, 123, 123, ..., 115, 117, 119], dtype=uint8), array([130, 127, 127, ..., 125, 127, 129], dtype=uint8)), (array([108, 113, 117, ...,  54,  55,  57], dtype=uint8), array([124, 128, 132, ...,  73,  74,  76], dtype=uint8), array([136, 141, 145, ...,  78,  79,  81], dtype=uint8))]
#
#
# Image: image_248_jpg.rf.039e30ef3586da827cd19bf1443d91a4.jpg
# Upper Body Vectors: [(array([ 83,  95, 104, ..., 140, 173, 225], dtype=uint8), array([ 58,  68,  74, ..., 127, 164, 218], dtype=uint8), array([ 39,  49,  49, ..., 110, 150, 211], dtype=uint8))]
# Lower Body Vectors: [(array([121, 127, 130, ..., 147, 152, 155], dtype=uint8), array([127, 132, 133, ..., 129, 136, 142], dtype=uint8), array([174, 177, 177, ..., 146, 152, 156], dtype=uint8))]
# Accessory Vectors: [(array([107, 111, 112, ...,  67,  67,  70], dtype=uint8), array([77, 75, 71, ..., 37, 40, 47], dtype=uint8), array([59, 56, 51, ..., 10, 13, 20], dtype=uint8)), (array([157, 159, 160, ..., 110, 112, 114], dtype=uint8), array([162, 162, 163, ..., 110, 112, 114], dtype=uint8), array([161, 162, 163, ..., 110, 112, 114], dtype=uint8)), (array([200, 203, 209, ..., 167, 165, 164], dtype=uint8), array([195, 198, 204, ..., 164, 162, 161], dtype=uint8), array([194, 197, 202, ..., 159, 157, 156], dtype=uint8))]
#
#
# Image: image_250_jpg.rf.e3e86189867bb630837ae90f70ada497.jpg
# Upper Body Vectors: [(array([180, 180, 167, ...,  20,  31,  52], dtype=uint8), array([188, 185, 169, ...,  10,  19,  42], dtype=uint8), array([191, 187, 169, ...,   2,  11,  29], dtype=uint8))]
# Lower Body Vectors: [(array([169, 166, 154, ..., 169, 168, 167], dtype=uint8), array([165, 161, 147, ..., 150, 152, 153], dtype=uint8), array([150, 146, 130, ..., 129, 129, 130], dtype=uint8))]
# Accessory Vectors: [(array([158, 157, 157, ..., 174, 177, 179], dtype=uint8), array([155, 154, 154, ..., 169, 172, 174], dtype=uint8), array([150, 149, 149, ..., 166, 169, 171], dtype=uint8)), (array([114, 113, 111, ..., 153, 152, 150], dtype=uint8), array([122, 121, 119, ..., 145, 144, 142], dtype=uint8), array([121, 120, 118, ..., 138, 136, 135], dtype=uint8))]
#
#
# Image: image_254_jpg.rf.65d9097d56f5b9b938feb6fc85ae36d1.jpg
# Upper Body Vectors: [(array([203, 207, 206, ...,  61,  78,  73], dtype=uint8), array([208, 211, 210, ...,  57,  75,  71], dtype=uint8), array([212, 216, 215, ...,  56,  75,  70], dtype=uint8))]
# Lower Body Vectors: [(array([  2,   2,   4, ...,  56,  89, 182], dtype=uint8), array([  3,   2,   4, ...,  54,  87, 180], dtype=uint8), array([  3,   2,   4, ...,  54,  87, 180], dtype=uint8))]
# Accessory Vectors: [(array([138, 141, 146, ..., 188, 188, 188], dtype=uint8), array([142, 145, 151, ..., 185, 185, 185], dtype=uint8), array([143, 146, 152, ..., 187, 187, 187], dtype=uint8)), (array([105, 104, 103, ..., 155, 155, 155], dtype=uint8), array([113, 112, 111, ..., 154, 154, 154], dtype=uint8), array([113, 112, 111, ..., 156, 156, 156], dtype=uint8))]
#
#
# Image: image_25_jpg.rf.524e906edde5c86bc06bd044588023a6.jpg
# Upper Body Vectors: [(array([194, 165, 122, ..., 150, 126,  93], dtype=uint8), array([196, 167, 124, ..., 148, 124,  91], dtype=uint8), array([190, 161, 118, ..., 148, 123,  90], dtype=uint8))]
# Lower Body Vectors: [(array([140, 143, 138, ..., 203, 203, 210], dtype=uint8), array([145, 148, 143, ..., 228, 224, 230], dtype=uint8), array([144, 147, 142, ..., 244, 241, 247], dtype=uint8))]
# Accessory Vectors: []
#
#
# Image: image_267_jpg.rf.875f1280278e552e0ead46435a8eb2c6.jpg
# Upper Body Vectors: [(array([195, 198, 190, ...,  89,  57,  39], dtype=uint8), array([205, 208, 199, ...,  79,  48,  31], dtype=uint8), array([203, 205, 195, ...,  65,  38,  22], dtype=uint8))]
# Lower Body Vectors: [(array([ 41,  33,  22, ..., 226, 228, 233], dtype=uint8), array([ 57,  47,  36, ..., 227, 228, 234], dtype=uint8), array([ 79,  67,  53, ..., 223, 225, 230], dtype=uint8))]
# Accessory Vectors: [(array([114, 113, 111, ...,  96,  85,  71], dtype=uint8), array([122, 121, 119, ..., 100,  90,  75], dtype=uint8), array([121, 119, 118, ..., 101,  91,  76], dtype=uint8)), (array([245, 247, 250, ...,  97, 100, 105], dtype=uint8), array([249, 251, 254, ..., 107, 110, 115], dtype=uint8), array([250, 252, 254, ..., 107, 110, 115], dtype=uint8)), (array([116, 121, 125, ..., 231, 229, 228], dtype=uint8), array([137, 140, 143, ..., 229, 227, 226], dtype=uint8), array([135, 139, 142, ..., 221, 219, 218], dtype=uint8))]
#
#
# Image: image_26_jpg.rf.48b0758ef82e4f48644c27e7e8deec5f.jpg
# Upper Body Vectors: [(array([88, 86, 88, ..., 30, 39, 45], dtype=uint8), array([60, 58, 60, ..., 15, 24, 28], dtype=uint8), array([53, 52, 53, ...,  9, 18, 23], dtype=uint8))]
# Lower Body Vectors: [(array([25, 26, 22, ..., 18,  5, 84], dtype=uint8), array([26, 24, 21, ..., 23, 11, 93], dtype=uint8), array([24, 23, 21, ..., 22, 14, 97], dtype=uint8))]
# Accessory Vectors: [(array([ 61,  64,  67, ..., 150, 141, 145], dtype=uint8), array([ 41,  42,  45, ..., 177, 170, 175], dtype=uint8), array([ 30,  31,  34, ..., 197, 188, 193], dtype=uint8)), (array([40, 38, 35, ..., 32, 33, 34], dtype=uint8), array([32, 31, 29, ..., 20, 21, 22], dtype=uint8), array([25, 24, 23, ..., 11, 12, 12], dtype=uint8))]
#
#
# ...
# Accessory Vectors: [(array([34, 31, 23, ..., 73, 75, 76], dtype=uint8), array([50, 46, 37, ..., 81, 83, 83], dtype=uint8), array([63, 59, 50, ..., 84, 86, 86], dtype=uint8)), (array([194, 202, 199, ...,  26,  23,   7], dtype=uint8), array([195, 202, 200, ...,  31,  27,  10], dtype=uint8), array([191, 199, 196, ...,  40,  37,  20], dtype=uint8))]
#
#
# Image: image_904_jpg.rf.e875478a7ac1a144524f5b3847ad78a8.jpg
# Upper Body Vectors: [(array([151, 152, 150, ..., 203, 203, 202], dtype=uint8), array([149, 150, 146, ..., 203, 203, 202], dtype=uint8), array([ 76,  79,  78, ..., 203, 203, 202], dtype=uint8))]
# Lower Body Vectors: [(array([41,  8,  7, ...,  2, 24, 49], dtype=uint8), array([36,  3,  2, ...,  0, 22, 47], dtype=uint8), array([35,  2,  1, ...,  0, 22, 47], dtype=uint8))]
# Accessory Vectors: [(array([172, 166, 161, ..., 139, 141, 143], dtype=uint8), array([170, 164, 159, ..., 141, 143, 145], dtype=uint8), array([169, 163, 158, ..., 142, 144, 146], dtype=uint8)), (array([ 15,  15,  15, ..., 177, 177, 177], dtype=uint8), array([ 13,  13,  13, ..., 177, 177, 177], dtype=uint8), array([ 12,  12,  12, ..., 177, 177, 177], dtype=uint8))]
#
#
# Image: image_921_jpg.rf.0305b053eeb828ace34d5aea366380e7.jpg
# Upper Body Vectors: [(array([43, 40, 38, ..., 35, 27,  8], dtype=uint8), array([46, 43, 41, ..., 36, 28,  9], dtype=uint8), array([44, 41, 40, ..., 40, 32, 11], dtype=uint8))]
# Lower Body Vectors: [(array([ 0,  0,  1, ..., 14, 10, 10], dtype=uint8), array([ 2,  2,  3, ..., 14, 10, 10], dtype=uint8), array([ 3,  2,  3, ..., 14, 10, 10], dtype=uint8))]
# Accessory Vectors: [(array([ 52,  52,  52, ..., 116, 116, 116], dtype=uint8), array([ 64,  64,  64, ..., 128, 128, 128], dtype=uint8), array([ 66,  66,  66, ..., 132, 132, 132], dtype=uint8)), (array([34, 33, 29, ..., 61, 59, 59], dtype=uint8), array([34, 33, 29, ..., 71, 69, 69], dtype=uint8), array([34, 33, 29, ..., 78, 76, 76], dtype=uint8))]
#
#
# Image: image_925_jpg.rf.eda1b115586b3c41481a7e276f9ce45d.jpg
# Upper Body Vectors: [(array([  7,  27,   5, ..., 178, 185, 183], dtype=uint8), array([  5,  25,   3, ..., 183, 188, 186], dtype=uint8), array([  4,  24,   3, ..., 175, 179, 176], dtype=uint8))]
# Lower Body Vectors: [(array([205, 169,  67, ...,  10, 160, 209], dtype=uint8), array([206, 170,  61, ...,  10, 161, 210], dtype=uint8), array([204, 168,  60, ...,  10, 153, 200], dtype=uint8))]
# Accessory Vectors: [(array([110, 110, 110, ..., 103, 103, 103], dtype=uint8), array([134, 134, 134, ..., 125, 125, 125], dtype=uint8), array([176, 176, 176, ..., 167, 167, 167], dtype=uint8))]
#
#
# Image: image_931_jpg.rf.7c7959c5a1f759390cbe8863ab34bd50.jpg
# Upper Body Vectors: [(array([31, 35, 44, ..., 80, 84, 89], dtype=uint8), array([26, 29, 38, ..., 70, 74, 78], dtype=uint8), array([22, 24, 33, ..., 63, 66, 70], dtype=uint8))]
# Lower Body Vectors: [(array([ 22,  26,  27, ...,  62, 114, 125], dtype=uint8), array([ 10,  14,  15, ...,  55, 109, 121], dtype=uint8), array([  8,  12,  13, ...,  53, 108, 120], dtype=uint8))]
# Accessory Vectors: [(array([116, 116, 116, ..., 119, 120, 121], dtype=uint8), array([111, 111, 111, ..., 116, 117, 118], dtype=uint8), array([108, 108, 108, ..., 108, 109, 110], dtype=uint8)), (array([13, 13, 14, ..., 32, 36, 39], dtype=uint8), array([ 6,  6,  7, ..., 26, 29, 31], dtype=uint8), array([ 3,  3,  4, ..., 19, 22, 24], dtype=uint8))]
#
#
# Image: image_939_jpg.rf.1a45e6e517900e4796c2cc28973c8529.jpg
# Upper Body Vectors: [(array([ 66,  68,  67, ..., 172, 164, 172], dtype=uint8), array([ 80,  81,  80, ..., 213, 208, 216], dtype=uint8), array([  2,   4,   4, ..., 240, 239, 248], dtype=uint8))]
# Lower Body Vectors: [(array([  3,   4,   5, ..., 136, 140, 141], dtype=uint8), array([  4,   5,   5, ..., 160, 166, 167], dtype=uint8), array([  0,   1,   1, ..., 178, 182, 183], dtype=uint8))]
# Accessory Vectors: [(array([  8,   7,   7, ..., 147, 149, 150], dtype=uint8), array([ 13,  13,  12, ..., 167, 169, 170], dtype=uint8), array([ 14,  14,  13, ..., 172, 174, 175], dtype=uint8)), (array([ 49,  51,  59, ..., 150, 140, 137], dtype=uint8), array([ 51,  53,  61, ..., 170, 162, 159], dtype=uint8), array([ 51,  53,  61, ..., 176, 167, 165], dtype=uint8))]
#
#
# Image: image_948_jpg.rf.b8cb6e0e515b70465ddce810eb6787f5.jpg
# Upper Body Vectors: [(array([119, 122, 130, ..., 112, 129, 119], dtype=uint8), array([85, 83, 89, ..., 79, 92, 82], dtype=uint8), array([53, 51, 57, ..., 55, 68, 55], dtype=uint8))]
# Lower Body Vectors: [(array([ 68,  63,  53, ..., 186, 226, 252], dtype=uint8), array([ 55,  50,  40, ..., 177, 218, 246], dtype=uint8), array([ 39,  34,  24, ..., 163, 205, 233], dtype=uint8))]
# Accessory Vectors: [(array([160, 160, 160, ..., 199, 199, 199], dtype=uint8), array([162, 162, 162, ..., 209, 209, 210], dtype=uint8), array([162, 162, 162, ..., 219, 218, 218], dtype=uint8)), (array([ 83,  82,  76, ..., 200, 204, 205], dtype=uint8), array([111, 110, 105, ..., 212, 215, 216], dtype=uint8), array([141, 139, 134, ..., 220, 223, 224], dtype=uint8))]
#
#
# Image: image_954_jpg.rf.e4af5ab52f19aaab0a186f9408f8931c.jpg
# Upper Body Vectors: [(array([66, 58, 51, ..., 68, 81, 95], dtype=uint8), array([68, 60, 53, ..., 70, 80, 95], dtype=uint8), array([ 69,  61,  54, ...,  80,  88, 105], dtype=uint8))]
# Lower Body Vectors: [(array([232, 233, 233, ...,  98,  90, 126], dtype=uint8), array([236, 234, 232, ...,  82,  74, 109], dtype=uint8), array([231, 230, 228, ...,  72,  62,  97], dtype=uint8))]
# Accessory Vectors: [(array([212, 213, 213, ...,  84,  80,  84], dtype=uint8), array([213, 214, 214, ...,  79,  75,  80], dtype=uint8), array([203, 205, 206, ...,  76,  72,  79], dtype=uint8)), (array([116, 116, 117, ..., 127, 129, 127], dtype=uint8), array([107, 107, 108, ..., 127, 127, 127], dtype=uint8), array([103, 103, 104, ..., 127, 127, 127], dtype=uint8))]
#
#
# Image: image_955_jpg.rf.35a8a846985ed277c7b24405e1286269.jpg
# Upper Body Vectors: [(array([100, 114, 127, ...,   0,   0,   0], dtype=uint8), array([114, 127, 142, ...,   1,   1,   0], dtype=uint8), array([113, 128, 145, ...,   1,   1,   0], dtype=uint8))]
# Lower Body Vectors: [(array([55, 49, 47, ..., 83, 69, 54], dtype=uint8), array([49, 43, 41, ..., 84, 71, 55], dtype=uint8), array([44, 38, 36, ..., 81, 66, 53], dtype=uint8))]
# Accessory Vectors: [(array([ 16,  15,  14, ..., 100, 100, 100], dtype=uint8), array([ 12,  11,  10, ..., 104, 104, 104], dtype=uint8), array([11, 10,  9, ..., 92, 92, 92], dtype=uint8)), (array([122, 121, 121, ..., 134, 134, 134], dtype=uint8), array([134, 133, 133, ..., 146, 146, 146], dtype=uint8), array([136, 135, 135, ..., 150, 150, 150], dtype=uint8)), (array([125, 123, 122, ...,  94,  99, 107], dtype=uint8), array([136, 135, 134, ..., 105, 111, 118], dtype=uint8), array([140, 138, 135, ..., 109, 114, 122], dtype=uint8))]
#
#
# Image: image_963_jpg.rf.3ea1568ebb721712513c84533971efb9.jpg
# Upper Body Vectors: [(array([74, 73, 73, ..., 24, 29, 33], dtype=uint8), array([79, 79, 78, ..., 26, 33, 38], dtype=uint8), array([82, 82, 81, ..., 26, 32, 37], dtype=uint8))]
# Lower Body Vectors: [(array([  3,   5,   2, ..., 139, 168, 148], dtype=uint8), array([  3,   5,   3, ..., 141, 170, 150], dtype=uint8), array([  3,   5,   1, ..., 142, 171, 151], dtype=uint8))]
# Accessory Vectors: [(array([ 6,  7,  7, ..., 41, 41, 41], dtype=uint8), array([ 7,  8,  8, ..., 46, 46, 46], dtype=uint8), array([ 5,  6,  6, ..., 47, 47, 47], dtype=uint8)), (array([12, 13, 13, ..., 23, 32, 36], dtype=uint8), array([10, 11, 11, ..., 21, 30, 34], dtype=uint8), array([ 9, 10, 10, ..., 21, 30, 34], dtype=uint8))]
#
#
# Image: image_964_jpg.rf.db80d802bc7e2ade1672638b212be4a3.jpg
# Upper Body Vectors: [(array([132, 116,  92, ..., 187, 205, 218], dtype=uint8), array([137, 121,  97, ..., 183, 201, 214], dtype=uint8), array([136, 120,  96, ..., 182, 200, 213], dtype=uint8))]
# Lower Body Vectors: [(array([43, 44, 46, ..., 94, 95, 89], dtype=uint8), array([29, 28, 30, ..., 84, 86, 82], dtype=uint8), array([16, 15, 17, ..., 64, 66, 62], dtype=uint8))]
# Accessory Vectors: [(array([122, 119, 116, ...,  92,  93,  94], dtype=uint8), array([130, 127, 124, ...,  97,  98,  99], dtype=uint8), array([130, 127, 124, ...,  96,  97,  98], dtype=uint8)), (array([125, 125, 125, ..., 119, 119, 119], dtype=uint8), array([133, 133, 133, ..., 131, 131, 131], dtype=uint8), array([132, 132, 132, ..., 131, 131, 131], dtype=uint8)), (array([138, 117,  61, ..., 114, 107, 119], dtype=uint8), array([144, 123,  67, ..., 127, 120, 132], dtype=uint8), array([140, 118,  62, ..., 129, 122, 134], dtype=uint8))]
#
#
# Image: image_967_jpg.rf.1129b043b3dc9c90e03c89bf95133989.jpg
# Upper Body Vectors: [(array([128, 155, 193, ...,  22,  31,  32], dtype=uint8), array([135, 162, 200, ...,  18,  27,  28], dtype=uint8), array([128, 155, 193, ...,  17,  26,  27], dtype=uint8))]
# Lower Body Vectors: [(array([58, 58, 57, ..., 34, 32, 32], dtype=uint8), array([52, 52, 51, ..., 30, 28, 28], dtype=uint8), array([53, 53, 52, ..., 29, 27, 27], dtype=uint8))]
# Accessory Vectors: [(array([118, 118, 119, ...,  75,  71,  71], dtype=uint8), array([125, 125, 126, ...,  77,  73,  73], dtype=uint8), array([128, 128, 129, ...,  89,  84,  84], dtype=uint8)), (array([190, 190, 190, ..., 202, 202, 202], dtype=uint8), array([197, 197, 197, ..., 201, 201, 201], dtype=uint8), array([212, 212, 212, ..., 240, 240, 240], dtype=uint8)), (array([120, 116,  97, ...,  15,  10,  12], dtype=uint8), array([117, 114,  95, ...,  14,  10,  12], dtype=uint8), array([113, 110,  93, ...,  14,  10,  12], dtype=uint8))]
#
#
# Image: image_96_jpg.rf.042e785a19d0183e5c8140b56684eeb6.jpg
# Upper Body Vectors: [(array([61, 42, 33, ..., 88, 83, 80], dtype=uint8), array([57, 38, 25, ..., 87, 82, 79], dtype=uint8), array([56, 35, 18, ..., 91, 86, 83], dtype=uint8))]
# Lower Body Vectors: [(array([30, 30, 29, ..., 61, 59, 57], dtype=uint8), array([24, 22, 21, ..., 59, 57, 53], dtype=uint8), array([25, 23, 22, ..., 58, 56, 52], dtype=uint8))]
# Accessory Vectors: [(array([ 72,  75,  77, ..., 132, 134, 138], dtype=uint8), array([ 67,  70,  72, ..., 144, 138, 143], dtype=uint8), array([ 69,  72,  74, ..., 146, 143, 146], dtype=uint8))]
#
#
# Image: image_970_jpg.rf.3fb6ed5f90d48588039fbd6c3f98465d.jpg
# Upper Body Vectors: [(array([33, 42, 53, ...,  6,  9,  8], dtype=uint8), array([29, 40, 54, ...,  9,  6,  6], dtype=uint8), array([25, 35, 45, ...,  7,  5,  6], dtype=uint8))]
# Lower Body Vectors: [(array([210, 216, 220, ...,   4,  12,  74], dtype=uint8), array([180, 184, 185, ...,   8,  21,  85], dtype=uint8), array([171, 178, 181, ...,  13,  28,  95], dtype=uint8))]
# Accessory Vectors: [(array([ 10,  10,  10, ..., 140, 141, 141], dtype=uint8), array([  7,   6,   5, ..., 160, 161, 161], dtype=uint8), array([  9,   8,   7, ..., 178, 179, 179], dtype=uint8)), (array([106, 107,  73, ..., 194, 192, 195], dtype=uint8), array([104, 105,  71, ..., 210, 209, 212], dtype=uint8), array([ 94,  95,  61, ..., 223, 222, 225], dtype=uint8))]
#
#
# Image: image_971_jpg.rf.8ac5a3b5cc1da55f1dac250d56b2d41f.jpg
# Upper Body Vectors: [(array([235, 235, 235, ..., 152, 153, 142], dtype=uint8), array([235, 235, 235, ..., 171, 173, 163], dtype=uint8), array([235, 235, 235, ..., 210, 219, 215], dtype=uint8))]
# Lower Body Vectors: [(array([ 35,  36,  37, ..., 157, 157, 157], dtype=uint8), array([ 33,  32,  32, ..., 159, 159, 159], dtype=uint8), array([ 33,  33,  34, ..., 160, 161, 160], dtype=uint8))]
# Accessory Vectors: [(array([ 29,  36,  38, ..., 119,  92,  77], dtype=uint8), array([ 33,  40,  42, ..., 122,  94,  78], dtype=uint8), array([ 56,  60,  60, ..., 169, 142, 128], dtype=uint8)), (array([20, 21, 22, ..., 38, 36, 35], dtype=uint8), array([16, 17, 18, ..., 40, 38, 37], dtype=uint8), array([15, 16, 17, ..., 41, 39, 38], dtype=uint8)), (array([184, 184, 185, ..., 189, 190, 190], dtype=uint8), array([189, 189, 190, ..., 191, 192, 192], dtype=uint8), array([192, 192, 193, ..., 192, 193, 193], dtype=uint8))]
#
#
# Image: image_973_jpg.rf.c6407fcfca036ab654086de33b27b466.jpg
# Upper Body Vectors: [(array([ 19,  22,  27, ..., 204, 202, 214], dtype=uint8), array([ 20,  24,  27, ..., 202, 203, 217], dtype=uint8), array([ 16,  18,  21, ..., 201, 201, 215], dtype=uint8))]
# Lower Body Vectors: [(array([103,  94,  65, ..., 168, 166, 168], dtype=uint8), array([115, 106,  79, ..., 170, 171, 174], dtype=uint8), array([118, 113,  88, ..., 170, 170, 173], dtype=uint8))]
# Accessory Vectors: [(array([101, 102, 103, ...,  92, 103, 107], dtype=uint8), array([ 96,  97,  98, ...,  94, 105, 109], dtype=uint8), array([ 97,  97,  99, ...,  94, 105, 109], dtype=uint8)), (array([ 71,  72,  73, ...,  97,  99, 100], dtype=uint8), array([ 65,  66,  67, ..., 105, 105, 106], dtype=uint8), array([ 66,  67,  68, ..., 104, 104, 105], dtype=uint8))]
#
#
# Image: image_980_jpg.rf.a3dc0df2edba47ad66a547a4e36b5263.jpg
# Upper Body Vectors: [(array([ 21,  27,  34, ..., 109,  94,  74], dtype=uint8), array([  7,  13,  20, ..., 124, 111,  91], dtype=uint8), array([  7,  14,  21, ..., 126, 114,  94], dtype=uint8))]
# Lower Body Vectors: [(array([193, 195, 203, ..., 237, 238, 228], dtype=uint8), array([174, 176, 184, ..., 193, 194, 184], dtype=uint8), array([168, 169, 177, ..., 162, 164, 158], dtype=uint8))]
# Accessory Vectors: [(array([227, 225, 220, ..., 111, 130, 133], dtype=uint8), array([197, 198, 193, ..., 103, 121, 127], dtype=uint8), array([178, 178, 173, ...,  96, 117, 122], dtype=uint8)), (array([142, 142, 142, ..., 135, 134, 131], dtype=uint8), array([146, 146, 146, ..., 133, 131, 129], dtype=uint8), array([147, 147, 147, ..., 132, 130, 128], dtype=uint8))]
#
#
# Image: image_986_jpg.rf.7e7412e9004d94b8c6412ed17b53ccc9.jpg
# Upper Body Vectors: [(array([210, 206, 211, ..., 197, 189, 163], dtype=uint8), array([219, 215, 220, ..., 209, 201, 175], dtype=uint8), array([226, 219, 224, ..., 213, 205, 179], dtype=uint8))]
# Lower Body Vectors: [(array([164, 119, 123, ..., 201, 209, 206], dtype=uint8), array([173, 128, 134, ..., 204, 210, 204], dtype=uint8), array([185, 142, 146, ..., 195, 201, 196], dtype=uint8))]
# Accessory Vectors: []
#
#
# Image: image_990_jpg.rf.c2768dbe5bc9667adf335e6b84e6efa7.jpg
# Upper Body Vectors: [(array([ 20,  20,  16, ..., 125, 180, 196], dtype=uint8), array([ 12,   9,   5, ..., 153, 217, 239], dtype=uint8), array([ 14,  11,   7, ..., 174, 230, 249], dtype=uint8))]
# Lower Body Vectors: [(array([148,  94,  41, ...,  84,  96, 111], dtype=uint8), array([175, 123,  69, ...,  82,  94, 109], dtype=uint8), array([209, 161, 110, ...,  87, 100, 114], dtype=uint8))]
# Accessory Vectors: [(array([133, 133, 133, ...,  73,  73,  72], dtype=uint8), array([133, 133, 133, ...,  69,  69,  68], dtype=uint8), array([133, 133, 133, ...,  74,  73,  73], dtype=uint8)), (array([207, 213, 231, ..., 232, 236, 237], dtype=uint8), array([191, 197, 215, ..., 208, 212, 213], dtype=uint8), array([175, 181, 199, ..., 186, 190, 191], dtype=uint8)), (array([ 68,  68,  71, ..., 181, 187, 187], dtype=uint8), array([ 73,  73,  76, ..., 212, 219, 219], dtype=uint8), array([ 88,  88,  92, ..., 212, 218, 218], dtype=uint8))]
#
#
# Image: image_993_jpg.rf.38e0c8a4169d2c45c8c9b3d8dfdbc7ac.jpg
# Upper Body Vectors: [(array([182, 187, 195, ...,  56, 112, 179], dtype=uint8), array([188, 191, 198, ...,  58, 114, 181], dtype=uint8), array([194, 196, 203, ...,  59, 115, 182], dtype=uint8))]
# Lower Body Vectors: [(array([87, 68, 47, ..., 32, 29, 28], dtype=uint8), array([89, 68, 45, ..., 24, 21, 21], dtype=uint8), array([89, 68, 45, ..., 24, 23, 25], dtype=uint8))]
# Accessory Vectors: [(array([ 66,  67,  68, ..., 169, 175, 179], dtype=uint8), array([ 60,  61,  62, ..., 174, 180, 184], dtype=uint8), array([ 55,  56,  57, ..., 183, 189, 193], dtype=uint8)), (array([191, 190, 189, ..., 195, 196, 197], dtype=uint8), array([201, 200, 199, ..., 201, 202, 203], dtype=uint8), array([211, 211, 209, ..., 208, 209, 210], dtype=uint8)), (array([ 33,  32,  30, ..., 181, 179, 179], dtype=uint8), array([ 35,  34,  33, ..., 195, 194, 194], dtype=uint8), array([ 43,  42,  41, ..., 191, 191, 190], dtype=uint8))]

# %%
# 데이터 준비
upper_body_data_valid = []  # 상의 벡터 (고정 크기 30000)
lower_body_label_valid = []  # 하의 벡터 (고정 크기 30000)
accessory_data_valid = []  # 가변 길이 악세사리 시퀀스
accessory_labels_valid = []  # 가변 길이 악세사리 레이블 시퀀스

for image_name, vectors in valid_image_sets.items():
    # 상의 벡터 처리 (R, G, B 결합)
    if len(vectors['upper_body']) > 0:
        r_vector, g_vector, b_vector = vectors['upper_body'][0]
        upper_body_vector = np.concatenate([r_vector, g_vector, b_vector])  # 크기: 30000
    else:
        upper_body_vector = np.zeros(30000)  # 기본값

    upper_body_data_valid.append(upper_body_vector)

    # 하의 벡터 처리 (R, G, B 결합)
    if len(vectors['lower_body']) > 0:
        r_vector, g_vector, b_vector = vectors['lower_body'][0]
        lower_body_vector = np.concatenate([r_vector, g_vector, b_vector])  # 크기: 30000
    else:
        lower_body_vector = np.zeros(30000)  # 기본값

    lower_body_label_valid.append(lower_body_vector)

    # 악세사리 벡터 처리 (R, G, B 결합 및 시퀀스 형태로 저장)
    accessory_sequence = []
    accessory_label_sequence = []
    for accessory in vectors['accessory']:
        r_vector, g_vector, b_vector = accessory
        accessory_vector = np.concatenate([r_vector, g_vector, b_vector])  # 크기: 30000
        accessory_sequence.append(accessory_vector)
        accessory_label_sequence.append(accessory_vector)  # 동일한 벡터를 레이블로 사용

    accessory_data_valid.append(accessory_sequence)
    accessory_labels_valid.append(accessory_label_sequence)

# numpy 배열로 변환
upper_body_data_valid = np.array(upper_body_data_valid)
lower_body_label_valid = np.array(lower_body_label_valid)
accessory_data_valid = np.array([np.array(seq) for seq in accessory_data_valid], dtype=object)  # 가변 길이 시퀀스
accessory_labels_valid = np.array([np.array(seq) for seq in accessory_labels_valid], dtype=object)  # 가변 길이 시퀀스

# %% [markdown]
# ##### test

# %%
image_dir = "./Crawling2-2/test/images"
label_dir = "./Crawling2-2/test/labels"

# 모든 이미지와 라벨 파일을 처리하여 저장할 딕셔너리
test_image_sets = {}

# 이미지 파일과 라벨 파일 목록 불러오기
image_files = os.listdir(image_dir)
label_files = os.listdir(label_dir)

# 각 이미지와 해당 라벨 파일을 처리
for image_file in image_files:
    # 이미지 경로 및 파일명 설정
    image_path = os.path.join(image_dir, image_file)
    label_file = image_file.replace('.jpg', '.txt')  # 이미지 파일명과 라벨 파일명 맞추기
    label_path = os.path.join(label_dir, label_file)

    # 이미지와 라벨 파일이 모두 존재할 때만 처리
    if os.path.exists(label_path):
        # 이미지 로드 및 크기 확인
        image = cv2.imread(image_path)
        if image is None:
            print(f"Error: Could not load image {image_path}")
            continue
        
        img_height, img_width = image.shape[:2]

        # 라벨 파일에서 바운딩 박스 정보 로드
        detections = load_detections_from_label_file(label_path)

        # 각 이미지의 객체를 벡터화하여 저장
        image_vectors = process_image_sets(image, detections, img_width, img_height)

        # 고유 키를 파일명으로 설정하여 딕셔너리에 저장  => 가독성이 떨어지긴 하는데
        test_image_sets[image_file] = image_vectors

# 전체 결과 확인
for image_name, vectors in test_image_sets.items():
    print(f"Image: {image_name}")
    print("Upper Body Vectors:", vectors['upper_body'])
    print("Lower Body Vectors:", vectors['lower_body'])
    print("Accessory Vectors:", vectors['accessory'])
    print("\n")
# Out:
# Image: image_1000_jpg.rf.335ab735f197afc717f5629c35a6e988.jpg
# Upper Body Vectors: [(array([191, 192, 185, ...,  33,  63, 166], dtype=uint8), array([188, 186, 176, ...,  18,  50, 154], dtype=uint8), array([186, 179, 166, ...,  16,  48, 152], dtype=uint8))]
# Lower Body Vectors: [(array([246, 243, 252, ..., 155, 142, 142], dtype=uint8), array([239, 239, 248, ..., 150, 138, 138], dtype=uint8), array([224, 220, 229, ..., 151, 139, 140], dtype=uint8))]
# Accessory Vectors: [(array([133, 133, 133, ..., 106, 106, 106], dtype=uint8), array([136, 137, 138, ..., 105, 105, 105], dtype=uint8), array([140, 141, 141, ..., 109, 109, 109], dtype=uint8)), (array([120, 116, 114, ..., 100,  96,  98], dtype=uint8), array([118, 114, 110, ...,  91,  86,  88], dtype=uint8), array([118, 114, 110, ...,  95,  92,  94], dtype=uint8))]
#
#
# Image: image_1004_jpg.rf.e164a7f47644a53f2800021b384674eb.jpg
# Upper Body Vectors: [(array([ 52,  61,  66, ..., 113, 113, 111], dtype=uint8), array([ 66,  77,  85, ..., 115, 112, 112], dtype=uint8), array([ 68,  79,  86, ..., 116, 114, 113], dtype=uint8))]
# Lower Body Vectors: [(array([ 62,  46,  50, ...,  72, 134, 167], dtype=uint8), array([ 87,  76,  83, ...,  87, 146, 179], dtype=uint8), array([ 83,  73,  79, ...,  65, 125, 157], dtype=uint8))]
# Accessory Vectors: [(array([116, 115, 114, ..., 156, 154, 154], dtype=uint8), array([120, 119, 118, ..., 141, 139, 139], dtype=uint8), array([115, 114, 113, ..., 138, 136, 136], dtype=uint8)), (array([ 47,  48,  48, ..., 113, 116, 120], dtype=uint8), array([ 64,  64,  64, ...,  98, 101, 105], dtype=uint8), array([55, 56, 57, ..., 89, 93, 96], dtype=uint8))]
#
#
# Image: image_1016_jpg.rf.88cf581bd94e48943a44183b42489598.jpg
# Upper Body Vectors: [(array([236, 235, 221, ...,  79,  66,  58], dtype=uint8), array([241, 240, 226, ..., 103,  87,  75], dtype=uint8), array([240, 239, 225, ..., 144, 122, 105], dtype=uint8))]
# Lower Body Vectors: [(array([ 43,  35,  29, ...,  84, 134, 190], dtype=uint8), array([ 41,  33,  27, ...,  89, 139, 194], dtype=uint8), array([ 41,  33,  27, ...,  87, 137, 192], dtype=uint8))]
# Accessory Vectors: [(array([229, 230, 230, ..., 208, 208, 208], dtype=uint8), array([234, 235, 235, ..., 214, 214, 214], dtype=uint8), array([233, 234, 234, ..., 213, 213, 213], dtype=uint8)), (array([154, 162, 167, ..., 166, 167, 171], dtype=uint8), array([156, 164, 168, ..., 168, 169, 173], dtype=uint8), array([156, 164, 168, ..., 168, 169, 173], dtype=uint8)), (array([  3,   7,   6, ..., 206, 204, 207], dtype=uint8), array([  5,   9,   9, ..., 208, 206, 209], dtype=uint8), array([  5,   9,   9, ..., 208, 206, 209], dtype=uint8))]
#
#
# Image: image_1022_jpg.rf.b5da0d0de9611094a6fad00d4c02357d.jpg
# Upper Body Vectors: [(array([ 87,  94,  86, ..., 155, 153, 155], dtype=uint8), array([147, 151, 141, ..., 148, 146, 148], dtype=uint8), array([132, 136, 127, ..., 131, 129, 131], dtype=uint8))]
# Lower Body Vectors: [(array([144, 142, 140, ...,  87,  86,  85], dtype=uint8), array([137, 135, 135, ...,  80,  78,  77], dtype=uint8), array([118, 116, 114, ...,  65,  65,  64], dtype=uint8))]
# Accessory Vectors: [(array([84, 82, 94, ..., 54, 56, 57], dtype=uint8), array([73, 71, 82, ..., 46, 48, 48], dtype=uint8), array([59, 57, 69, ..., 34, 35, 35], dtype=uint8)), (array([100,  99,  98, ...,  86,  86,  85], dtype=uint8), array([101, 100,  99, ...,  84,  83,  82], dtype=uint8), array([81, 81, 80, ..., 76, 75, 74], dtype=uint8))]
#
#
# Image: image_1023_jpg.rf.898ce370f3297906c2bc19374ae483b2.jpg
# Upper Body Vectors: [(array([209, 207, 208, ..., 161, 146, 123], dtype=uint8), array([207, 206, 206, ..., 164, 153, 133], dtype=uint8), array([206, 204, 205, ..., 172, 163, 148], dtype=uint8))]
# Lower Body Vectors: [(array([85, 85, 85, ..., 35, 34, 35], dtype=uint8), array([90, 90, 90, ..., 30, 29, 30], dtype=uint8), array([93, 93, 93, ..., 29, 28, 29], dtype=uint8))]
# Accessory Vectors: [(array([137, 136, 135, ...,  81,  80,  79], dtype=uint8), array([137, 136, 135, ...,  79,  78,  77], dtype=uint8), array([137, 136, 135, ...,  79,  78,  77], dtype=uint8)), (array([  9,   9,   9, ..., 169, 182, 187], dtype=uint8), array([  9,   9,  10, ..., 165, 178, 183], dtype=uint8), array([  9,   8,   8, ..., 164, 177, 182], dtype=uint8))]
#
#
# Image: image_1026_jpg.rf.6f16d38aba558d7c5729efc6dd9767f0.jpg
# Upper Body Vectors: [(array([180, 167, 163, ..., 127, 124, 119], dtype=uint8), array([177, 159, 151, ..., 126, 125, 122], dtype=uint8), array([162, 145, 134, ..., 123, 124, 122], dtype=uint8))]
# Lower Body Vectors: [(array([197, 207, 213, ..., 159, 149, 146], dtype=uint8), array([200, 208, 211, ..., 160, 152, 149], dtype=uint8), array([201, 204, 206, ..., 158, 150, 147], dtype=uint8))]
# Accessory Vectors: [(array([156, 156, 157, ..., 118, 118, 118], dtype=uint8), array([154, 154, 154, ..., 124, 124, 124], dtype=uint8), array([154, 154, 154, ..., 131, 131, 131], dtype=uint8)), (array([166, 166, 166, ...,  83,  84,  85], dtype=uint8), array([164, 164, 164, ...,  87,  89,  89], dtype=uint8), array([163, 163, 163, ...,  88,  90,  90], dtype=uint8))]
#
#
# Image: image_1027_jpg.rf.b0052a0dbb44861f35a15ada73b90a63.jpg
# Upper Body Vectors: [(array([205, 199, 192, ...,  70,  71,  71], dtype=uint8), array([214, 208, 202, ...,  93,  94,  92], dtype=uint8), array([221, 216, 216, ..., 125, 126, 123], dtype=uint8))]
# Lower Body Vectors: [(array([14, 12, 11, ...,  0,  2, 12], dtype=uint8), array([12, 10,  9, ...,  0,  2, 12], dtype=uint8), array([12, 10,  9, ...,  0,  2, 12], dtype=uint8))]
# Accessory Vectors: [(array([80, 80, 80, ..., 53, 53, 53], dtype=uint8), array([85, 85, 85, ..., 54, 54, 54], dtype=uint8), array([94, 94, 94, ..., 52, 52, 52], dtype=uint8)), (array([152, 152, 152, ...,  75,  78,  82], dtype=uint8), array([163, 163, 163, ...,  87,  90,  94], dtype=uint8), array([167, 167, 167, ...,  87,  90,  94], dtype=uint8)), (array([139, 131, 125, ...,  13,  14,  15], dtype=uint8), array([152, 142, 134, ...,  15,  16,  17], dtype=uint8), array([166, 156, 147, ...,  16,  17,  18], dtype=uint8))]
#
#
# Image: image_1046_jpg.rf.be084044eecdc86fa31d1733ccd52439.jpg
# Upper Body Vectors: [(array([169, 118,  67, ...,  16,  59,  71], dtype=uint8), array([171, 121,  70, ...,  11,  55,  66], dtype=uint8), array([180, 130,  80, ...,  12,  55,  67], dtype=uint8))]
# Lower Body Vectors: [(array([26, 31, 30, ..., 41, 47, 50], dtype=uint8), array([21, 26, 25, ..., 50, 54, 59], dtype=uint8), array([23, 28, 27, ..., 54, 63, 68], dtype=uint8))]
# Accessory Vectors: [(array([139, 144, 120, ...,  23,  22,  19], dtype=uint8), array([145, 150, 126, ...,  21,  20,  19], dtype=uint8), array([144, 149, 124, ...,  21,  20,  19], dtype=uint8)), (array([17, 17, 18, ..., 31, 30, 30], dtype=uint8), array([16, 16, 17, ..., 31, 30, 30], dtype=uint8), array([18, 18, 19, ..., 31, 30, 30], dtype=uint8))]
#
#
# Image: image_1047_jpg.rf.ca493fcfd9deb51c2808dcd31d1ca4cd.jpg
# Upper Body Vectors: [(array([255, 255, 255, ..., 160, 150, 120], dtype=uint8), array([255, 255, 255, ..., 187, 178, 147], dtype=uint8), array([255, 255, 255, ..., 237, 225, 196], dtype=uint8))]
# Lower Body Vectors: [(array([184,  89,  53, ...,  72, 145, 190], dtype=uint8), array([183,  91,  58, ...,  76, 150, 196], dtype=uint8), array([186,  94,  57, ...,  82, 155, 201], dtype=uint8))]
# Accessory Vectors: [(array([ 30,  31,  32, ..., 226, 226, 227], dtype=uint8), array([ 27,  28,  29, ..., 233, 233, 232], dtype=uint8), array([ 29,  30,  31, ..., 236, 236, 235], dtype=uint8)), (array([249, 249, 249, ..., 236, 235, 235], dtype=uint8), array([254, 254, 254, ..., 239, 238, 238], dtype=uint8), array([253, 253, 253, ..., 243, 242, 242], dtype=uint8)), (array([ 72,  77,  67, ..., 235, 233, 233], dtype=uint8), array([ 72,  77,  67, ..., 239, 236, 236], dtype=uint8), array([ 72,  77,  67, ..., 244, 244, 244], dtype=uint8))]
#
#
# Image: image_1050_jpg.rf.56988af4ec925a10b7e5064c449ec4de.jpg
# Upper Body Vectors: [(array([ 74,  70,  66, ..., 127, 129, 128], dtype=uint8), array([ 86,  82,  78, ..., 132, 135, 133], dtype=uint8), array([ 91,  86,  82, ..., 137, 139, 138], dtype=uint8))]
# Lower Body Vectors: [(array([ 12,  10,  13, ..., 144, 143, 143], dtype=uint8), array([  2,   1,   3, ..., 153, 152, 152], dtype=uint8), array([  2,   1,   1, ..., 162, 161, 161], dtype=uint8))]
# Accessory Vectors: []
#
#
# Image: image_1059_jpg.rf.ca3351692b652091498f101e0c26196a.jpg
# Upper Body Vectors: [(array([122, 127, 148, ..., 105, 101, 104], dtype=uint8), array([147, 149, 161, ...,  99,  94,  96], dtype=uint8), array([135, 138, 154, ..., 102,  95,  97], dtype=uint8))]
# Lower Body Vectors: [(array([145, 128,  96, ...,  83,  84,  83], dtype=uint8), array([182, 156, 117, ...,  89,  89,  88], dtype=uint8), array([210, 182, 140, ...,  94,  93,  87], dtype=uint8))]
# Accessory Vectors: [(array([114, 119, 127, ...,  78,  84,  88], dtype=uint8), array([123, 127, 136, ...,  80,  87,  92], dtype=uint8), array([143, 149, 158, ...,  98, 106, 111], dtype=uint8)), (array([235, 234, 234, ..., 149, 128, 112], dtype=uint8), array([227, 226, 226, ..., 145, 124, 109], dtype=uint8), array([234, 233, 232, ..., 149, 128, 111], dtype=uint8)), (array([218, 218, 218, ...,  65,  65,  65], dtype=uint8), array([240, 239, 237, ...,  95,  95,  95], dtype=uint8), array([246, 244, 242, ..., 152, 153, 154], dtype=uint8))]
#
#
# Image: image_1065_jpg.rf.f631be98b804186acbf9401ebc874c1d.jpg
# Upper Body Vectors: [(array([65, 41, 34, ..., 45, 44, 47], dtype=uint8), array([104,  84,  79, ..., 155, 156, 160], dtype=uint8), array([ 88,  67,  62, ..., 133, 134, 138], dtype=uint8))]
# Lower Body Vectors: [(array([115, 167, 181, ...,  96,  96, 162], dtype=uint8), array([167, 204, 207, ...,  94,  99, 173], dtype=uint8), array([158, 199, 204, ...,  95,  98, 170], dtype=uint8))]
# Accessory Vectors: [(array([74, 65, 61, ..., 42, 43, 43], dtype=uint8), array([102,  93,  89, ...,  42,  43,  43], dtype=uint8), array([102,  93,  89, ...,  42,  43,  43], dtype=uint8)), (array([230, 230, 232, ...,  40,  42,  43], dtype=uint8), array([221, 221, 223, ...,  38,  40,  40], dtype=uint8), array([218, 219, 221, ...,  39,  41,  42], dtype=uint8)), (array([213, 176, 172, ...,  13,   1,   2], dtype=uint8), array([215, 180, 178, ...,  27,  18,  19], dtype=uint8), array([209, 175, 173, ...,  33,  21,  22], dtype=uint8))]
#
#
# Image: image_1093_jpg.rf.49e3d0c5afc76586157aaded4e5dd09f.jpg
# Upper Body Vectors: [(array([156, 190, 220, ..., 192, 182, 183], dtype=uint8), array([160, 194, 223, ..., 204, 193, 194], dtype=uint8), array([161, 195, 224, ..., 206, 196, 198], dtype=uint8))]
# Lower Body Vectors: [(array([ 88, 135, 194, ...,  14,  12,   7], dtype=uint8), array([102, 149, 207, ...,   9,   7,   6], dtype=uint8), array([132, 172, 227, ...,   8,   8,   8], dtype=uint8))]
# Accessory Vectors: []
#
#
# Image: image_1112_jpg.rf.916059af9a9b2aade14c577ea4b92e62.jpg
# Upper Body Vectors: [(array([23, 20, 14, ...,  7,  6,  6], dtype=uint8), array([26, 23, 17, ...,  8,  7,  7], dtype=uint8), array([23, 21, 15, ...,  6,  5,  5], dtype=uint8))]
# Lower Body Vectors: [(array([146, 147, 148, ...,  84,  85,  88], dtype=uint8), array([155, 156, 156, ...,  88,  90,  93], dtype=uint8), array([158, 159, 160, ...,  90,  91,  94], dtype=uint8))]
# Accessory Vectors: []
#
#
# Image: image_111_jpg.rf.56e0405e0b9e25505b5ef40a3c2412d4.jpg
# Upper Body Vectors: [(array([175, 178, 182, ..., 152, 124, 108], dtype=uint8), array([182, 184, 185, ..., 160, 141, 132], dtype=uint8), array([186, 187, 188, ..., 162, 158, 162], dtype=uint8))]
# Lower Body Vectors: [(array([158, 176, 160, ..., 229, 222, 223], dtype=uint8), array([157, 173, 155, ..., 228, 222, 223], dtype=uint8), array([152, 166, 146, ..., 223, 216, 217], dtype=uint8))]
# Accessory Vectors: [(array([ 82,  86,  76, ..., 152, 153, 153], dtype=uint8), array([ 74,  78,  67, ..., 157, 158, 158], dtype=uint8), array([ 51,  55,  47, ..., 157, 157, 157], dtype=uint8))]
#
#
# Image: image_122_jpg.rf.302ed16b28b6215cd7d0ad710ae46c35.jpg
# Upper Body Vectors: [(array([15, 27, 30, ..., 45, 56, 52], dtype=uint8), array([17, 28, 29, ..., 33, 46, 42], dtype=uint8), array([12, 24, 25, ..., 31, 43, 42], dtype=uint8))]
# Lower Body Vectors: [(array([ 6,  8, 12, ..., 22, 14, 20], dtype=uint8), array([ 2,  4,  8, ..., 14,  7, 13], dtype=uint8), array([1, 3, 8, ..., 7, 0, 4], dtype=uint8))]
# Accessory Vectors: [(array([ 12,  13,  15, ..., 163, 166, 169], dtype=uint8), array([  6,   6,   6, ..., 153, 156, 159], dtype=uint8), array([  1,   1,   2, ..., 143, 147, 149], dtype=uint8)), (array([ 37,  37,  37, ..., 207, 208, 208], dtype=uint8), array([ 36,  36,  35, ..., 197, 199, 199], dtype=uint8), array([ 32,  32,  31, ..., 187, 189, 189], dtype=uint8)), (array([209, 204, 194, ...,  14,  12,  11], dtype=uint8), array([219, 214, 204, ...,  10,   8,   7], dtype=uint8), array([219, 214, 204, ...,   5,   3,   2], dtype=uint8))]
#
#
# Image: image_124_jpg.rf.d6f9a128179f6c00dc165fdd74e1c5ef.jpg
# Upper Body Vectors: [(array([162, 148, 137, ...,  98,  94,  92], dtype=uint8), array([183, 172, 164, ..., 130, 127, 125], dtype=uint8), array([192, 184, 180, ..., 173, 168, 165], dtype=uint8))]
# Lower Body Vectors: [(array([ 6,  1,  3, ..., 65, 66, 66], dtype=uint8), array([11,  5,  7, ..., 76, 77, 77], dtype=uint8), array([17, 12, 13, ..., 84, 85, 85], dtype=uint8))]
# Accessory Vectors: []
#
#
# Image: image_127_jpg.rf.2fbea83d349c10eaae936c9fb7300277.jpg
# Upper Body Vectors: [(array([ 65,  72,  75, ..., 105, 199, 188], dtype=uint8), array([ 78,  85,  88, ..., 109, 205, 199], dtype=uint8), array([ 89,  96,  99, ...,  98, 199, 198], dtype=uint8))]
# Lower Body Vectors: [(array([ 89,  89,  89, ..., 177, 174, 151], dtype=uint8), array([104, 103, 104, ..., 201, 196, 175], dtype=uint8), array([123, 125, 126, ..., 224, 225, 205], dtype=uint8))]
# Accessory Vectors: [(array([50, 50, 50, ..., 70, 70, 70], dtype=uint8), array([ 71,  71,  71, ..., 103, 103, 103], dtype=uint8), array([102, 102, 102, ..., 148, 148, 148], dtype=uint8)), (array([112, 112, 116, ...,  53,  58,  63], dtype=uint8), array([129, 129, 134, ...,  86,  91,  96], dtype=uint8), array([155, 155, 157, ..., 130, 136, 141], dtype=uint8))]
#
#
# Image: image_12_jpg.rf.1f8b17f698dccbae87dd64b930131321.jpg
# Upper Body Vectors: [(array([178, 180, 177, ...,  11,  13,  11], dtype=uint8), array([180, 182, 179, ...,   0,   2,   2], dtype=uint8), array([180, 182, 179, ...,   0,   0,   0], dtype=uint8))]
# Lower Body Vectors: [(array([44, 45, 43, ..., 33, 32, 41], dtype=uint8), array([39, 40, 38, ..., 26, 26, 34], dtype=uint8), array([40, 40, 37, ..., 23, 23, 31], dtype=uint8))]
# Accessory Vectors: [(array([ 38,  39,  41, ..., 119, 121, 123], dtype=uint8), array([ 34,  35,  37, ..., 119, 121, 123], dtype=uint8), array([ 29,  30,  32, ..., 119, 121, 123], dtype=uint8)), (array([138, 138, 139, ..., 102, 103, 103], dtype=uint8), array([138, 138, 139, ..., 104, 105, 105], dtype=uint8), array([138, 138, 139, ..., 104, 105, 105], dtype=uint8))]
#
#
# Image: image_140_jpg.rf.79e497ae7682b4e10b08f5412a40c831.jpg
# Upper Body Vectors: [(array([115, 114, 115, ..., 183, 184, 182], dtype=uint8), array([133, 132, 133, ..., 186, 187, 185], dtype=uint8), array([150, 149, 150, ..., 191, 192, 190], dtype=uint8))]
# Lower Body Vectors: [(array([ 84,  73,  78, ..., 127, 137, 144], dtype=uint8), array([ 84,  73,  78, ..., 121, 129, 135], dtype=uint8), array([ 90,  79,  84, ..., 116, 125, 131], dtype=uint8))]
# Accessory Vectors: [(array([162, 167, 169, ..., 213, 221, 232], dtype=uint8), array([153, 158, 161, ..., 197, 205, 216], dtype=uint8), array([149, 154, 157, ..., 191, 199, 210], dtype=uint8)), (array([ 93,  94,  97, ..., 199, 198, 190], dtype=uint8), array([ 88,  88,  92, ..., 187, 186, 178], dtype=uint8), array([ 87,  88,  91, ..., 183, 181, 174], dtype=uint8))]
#
#
# Image: image_141_jpg.rf.73d14e0fd74c7bec1880728cb527f38f.jpg
# Upper Body Vectors: [(array([169, 175, 171, ...,  58,  59,  56], dtype=uint8), array([196, 202, 199, ..., 117, 117, 116], dtype=uint8), array([246, 250, 245, ..., 180, 180, 179], dtype=uint8))]
# Lower Body Vectors: [(array([ 81,  65,  58, ..., 107, 106, 105], dtype=uint8), array([ 86,  71,  63, ..., 103, 103, 101], dtype=uint8), array([ 89,  74,  67, ..., 102, 101, 100], dtype=uint8))]
# Accessory Vectors: [(array([117, 117, 128, ..., 215, 215, 215], dtype=uint8), array([118, 118, 128, ..., 204, 205, 205], dtype=uint8), array([116, 116, 127, ..., 204, 205, 205], dtype=uint8)), (array([23, 24, 27, ..., 88, 82, 78], dtype=uint8), array([26, 27, 29, ..., 82, 76, 73], dtype=uint8), array([30, 31, 33, ..., 83, 77, 74], dtype=uint8))]
#
#
# Image: image_147_jpg.rf.ea5a82383d93d019bb0d58c5db49b7bb.jpg
# Upper Body Vectors: [(array([176, 174, 172, ...,  98,  97,  96], dtype=uint8), array([181, 179, 176, ..., 100,  98,  98], dtype=uint8), array([184, 182, 180, ..., 109, 107, 106], dtype=uint8))]
# Lower Body Vectors: [(array([166, 168, 161, ..., 151, 166, 206], dtype=uint8), array([169, 172, 163, ..., 156, 170, 208], dtype=uint8), array([172, 173, 164, ..., 159, 171, 208], dtype=uint8))]
# Accessory Vectors: [(array([81, 79, 77, ..., 89, 89, 90], dtype=uint8), array([ 90,  88,  86, ..., 102, 102, 103], dtype=uint8), array([ 99,  97,  95, ..., 110, 110, 111], dtype=uint8)), (array([ 42,  44,  50, ..., 130, 125, 124], dtype=uint8), array([ 51,  53,  58, ..., 141, 137, 136], dtype=uint8), array([ 61,  63,  68, ..., 153, 149, 148], dtype=uint8)), (array([206, 206, 206, ..., 173, 173, 173], dtype=uint8), array([208, 208, 208, ..., 178, 178, 178], dtype=uint8), array([208, 208, 208, ..., 179, 179, 179], dtype=uint8))]
#
#
# Image: image_157_jpg.rf.d447e12ceb4deaac4851adb12cec957a.jpg
# Upper Body Vectors: [(array([208, 205, 146, ...,  19,  17,  17], dtype=uint8), array([206, 203, 144, ...,  17,  15,  15], dtype=uint8), array([206, 203, 144, ...,  17,  15,  15], dtype=uint8))]
# Lower Body Vectors: [(array([ 45,  89, 126, ...,  25,  26,  28], dtype=uint8), array([ 34,  77, 115, ...,  29,  29,  29], dtype=uint8), array([ 36,  80, 117, ...,  30,  31,  33], dtype=uint8))]
# Accessory Vectors: [(array([96, 98, 95, ..., 60, 56, 52], dtype=uint8), array([131, 134, 133, ...,  72,  67,  62], dtype=uint8), array([174, 177, 175, ...,  82,  77,  72], dtype=uint8)), (array([ 4,  4,  4, ..., 25, 26, 26], dtype=uint8), array([10, 10, 10, ..., 34, 35, 35], dtype=uint8), array([15, 15, 15, ..., 43, 44, 44], dtype=uint8))]
#
#
# Image: image_170_jpg.rf.024d32f2aaeb05ba694dbc868e499526.jpg
# Upper Body Vectors: [(array([70, 52, 48, ..., 19, 19, 19], dtype=uint8), array([66, 48, 44, ..., 15, 15, 15], dtype=uint8), array([65, 48, 43, ..., 14, 14, 14], dtype=uint8))]
# Lower Body Vectors: [(array([174, 172, 169, ..., 161, 161, 162], dtype=uint8), array([179, 177, 174, ..., 158, 158, 159], dtype=uint8), array([178, 176, 172, ..., 154, 154, 155], dtype=uint8))]
# Accessory Vectors: [(array([141, 143, 146, ..., 208, 208, 208], dtype=uint8), array([139, 141, 144, ..., 207, 207, 207], dtype=uint8), array([139, 141, 144, ..., 203, 203, 203], dtype=uint8)), (array([191, 193, 196, ..., 196, 198, 199], dtype=uint8), array([192, 193, 194, ..., 191, 193, 194], dtype=uint8), array([190, 191, 193, ..., 182, 184, 185], dtype=uint8)), (array([68, 68, 70, ..., 91, 93, 93], dtype=uint8), array([72, 72, 74, ..., 96, 97, 97], dtype=uint8), array([ 77,  77,  79, ..., 101, 102, 102], dtype=uint8))]
#
#
# Image: image_175_jpg.rf.fbe04a690183ccf30a151c9756c1e83f.jpg
# Upper Body Vectors: [(array([31, 29, 24, ..., 15, 15, 17], dtype=uint8), array([17, 16, 13, ...,  1,  1,  3], dtype=uint8), array([15, 14,  9, ...,  2,  2,  4], dtype=uint8))]
# Lower Body Vectors: [(array([81, 86, 78, ...,  6,  6, 19], dtype=uint8), array([78, 81, 73, ...,  3,  7, 23], dtype=uint8), array([74, 78, 70, ...,  2,  5, 21], dtype=uint8))]
# Accessory Vectors: [(array([ 44,  44,  43, ..., 119, 119, 119], dtype=uint8), array([ 42,  42,  41, ..., 127, 127, 127], dtype=uint8), array([ 41,  41,  40, ..., 126, 126, 126], dtype=uint8)), (array([165, 165, 159, ...,  37,  39,  39], dtype=uint8), array([165, 165, 159, ...,  35,  37,  37], dtype=uint8), array([165, 165, 159, ...,  34,  36,  36], dtype=uint8))]
#
#
# Image: image_179_jpg.rf.dcf985cdfb1d5737cd48d7727774b57e.jpg
# Upper Body Vectors: [(array([205, 193, 167, ..., 225, 229, 223], dtype=uint8), array([204, 192, 166, ..., 224, 228, 224], dtype=uint8), array([206, 194, 168, ..., 226, 230, 225], dtype=uint8))]
# Lower Body Vectors: [(array([164, 184, 196, ..., 231, 231, 231], dtype=uint8), array([157, 176, 188, ..., 231, 231, 231], dtype=uint8), array([165, 186, 198, ..., 231, 231, 231], dtype=uint8))]
# Accessory Vectors: [(array([185, 186, 186, ..., 178, 178, 178], dtype=uint8), array([183, 184, 184, ..., 177, 177, 177], dtype=uint8), array([183, 184, 184, ..., 181, 181, 181], dtype=uint8)), (array([193, 194, 197, ..., 222, 219, 218], dtype=uint8), array([193, 194, 197, ..., 224, 221, 220], dtype=uint8), array([193, 194, 197, ..., 226, 222, 221], dtype=uint8)), (array([216, 219, 224, ..., 185, 184, 183], dtype=uint8), array([218, 221, 226, ..., 178, 177, 177], dtype=uint8), array([219, 222, 227, ..., 180, 179, 178], dtype=uint8)), (array([106, 106, 104, ..., 182, 182, 182], dtype=uint8), array([105, 105, 102, ..., 174, 174, 174], dtype=uint8), array([107, 107, 104, ..., 175, 175, 175], dtype=uint8))]
#
#
# Image: image_196_jpg.rf.19b71e0f8d4f1373bbe0a304c0f29500.jpg
# Upper Body Vectors: [(array([203, 203, 202, ...,   2,   1,   2], dtype=uint8), array([203, 203, 202, ...,   2,   1,   2], dtype=uint8), array([203, 203, 202, ...,   2,   1,   2], dtype=uint8))]
# Lower Body Vectors: [(array([31, 25, 14, ...,  5, 12, 31], dtype=uint8), array([27, 21, 13, ...,  5, 12, 31], dtype=uint8), array([26, 20, 12, ...,  5, 12, 31], dtype=uint8))]
# Accessory Vectors: [(array([110, 109, 109, ..., 168, 168, 170], dtype=uint8), array([108, 107, 107, ..., 166, 167, 168], dtype=uint8), array([107, 106, 106, ..., 165, 166, 167], dtype=uint8)), (array([105, 104, 100, ...,  45,  57,  73], dtype=uint8), array([100,  99,  95, ...,  45,  57,  73], dtype=uint8), array([99, 98, 94, ..., 45, 57, 73], dtype=uint8))]
#
#
# Image: image_206_jpg.rf.e3f55c1398de88877648426160cbc210.jpg
# Upper Body Vectors: [(array([150, 154, 161, ..., 203, 201, 201], dtype=uint8), array([149, 153, 160, ..., 202, 199, 197], dtype=uint8), array([160, 166, 173, ..., 208, 205, 202], dtype=uint8))]
# Lower Body Vectors: [(array([ 43,  43,  45, ..., 121, 123, 135], dtype=uint8), array([ 45,  45,  47, ..., 121, 122, 134], dtype=uint8), array([ 55,  55,  57, ..., 132, 132, 144], dtype=uint8))]
# Accessory Vectors: [(array([119, 120, 125, ...,  62,  63,  63], dtype=uint8), array([115, 116, 121, ...,  55,  56,  56], dtype=uint8), array([110, 111, 116, ...,  58,  59,  59], dtype=uint8)), (array([ 67,  66,  66, ..., 104,  97,  93], dtype=uint8), array([67, 67, 67, ..., 96, 88, 84], dtype=uint8), array([79, 78, 77, ..., 99, 91, 87], dtype=uint8))]
#
#
# Image: image_210_jpg.rf.92eedd11bbb3fa5aefd785aa2fa9848f.jpg
# Upper Body Vectors: [(array([109, 134, 117, ..., 128,  94,  88], dtype=uint8), array([123, 145, 125, ..., 122,  81,  73], dtype=uint8), array([150, 173, 147, ..., 116,  67,  58], dtype=uint8))]
# Lower Body Vectors: [(array([41, 40, 30, ..., 57, 40, 45], dtype=uint8), array([28, 29, 19, ..., 55, 40, 49], dtype=uint8), array([22, 21, 12, ..., 55, 44, 55], dtype=uint8))]
# Accessory Vectors: []
#
#
# Image: image_213_jpg.rf.33b3735506ff41e508cd8261c3cfedeb.jpg
# Upper Body Vectors: [(array([217, 219, 218, ..., 194, 201, 210], dtype=uint8), array([223, 225, 219, ..., 198, 203, 213], dtype=uint8), array([218, 220, 217, ..., 192, 197, 204], dtype=uint8))]
# Lower Body Vectors: [(array([53, 43, 44, ..., 53, 58, 93], dtype=uint8), array([37, 28, 31, ..., 45, 51, 85], dtype=uint8), array([30, 24, 29, ..., 36, 42, 77], dtype=uint8))]
# Accessory Vectors: [(array([167, 171, 171, ...,  32,  32,  32], dtype=uint8), array([163, 167, 167, ...,  25,  25,  25], dtype=uint8), array([162, 166, 166, ...,  22,  22,  22], dtype=uint8)), (array([31, 33, 34, ..., 51, 58, 65], dtype=uint8), array([15, 17, 18, ..., 46, 53, 60], dtype=uint8), array([ 9, 11, 12, ..., 43, 50, 57], dtype=uint8)), (array([191, 191, 191, ..., 150, 152, 152], dtype=uint8), array([195, 195, 195, ..., 154, 155, 156], dtype=uint8), array([189, 189, 189, ..., 155, 157, 157], dtype=uint8)), (array([ 42,  42,  44, ..., 127, 129, 129], dtype=uint8), array([ 39,  39,  41, ..., 129, 132, 132], dtype=uint8), array([ 31,  31,  33, ..., 127, 130, 130], dtype=uint8))]
#
#
# Image: image_215_jpg.rf.f1aab757f579e8218edca7d06fbadfb9.jpg
# Upper Body Vectors: [(array([116, 118, 118, ...,  22,  68,  65], dtype=uint8), array([93, 88, 89, ..., 38, 83, 77], dtype=uint8), array([ 92,  87,  88, ...,  62, 102,  91], dtype=uint8))]
# Lower Body Vectors: [(array([186, 175, 143, ..., 222, 215, 212], dtype=uint8), array([223, 209, 175, ..., 227, 221, 219], dtype=uint8), array([255, 249, 221, ..., 225, 216, 212], dtype=uint8))]
# Accessory Vectors: [(array([126, 128, 135, ...,  61,  66,  80], dtype=uint8), array([170, 170, 176, ..., 103, 105, 114], dtype=uint8), array([193, 195, 199, ..., 136, 136, 144], dtype=uint8)), (array([113, 114, 117, ..., 107, 104, 102], dtype=uint8), array([167, 168, 171, ..., 151, 149, 148], dtype=uint8), array([192, 193, 196, ..., 170, 167, 166], dtype=uint8)), (array([109, 108, 107, ..., 101, 102, 103], dtype=uint8), array([125, 124, 123, ..., 133, 133, 132], dtype=uint8), array([138, 137, 136, ..., 144, 145, 146], dtype=uint8))]
#
#
# Image: image_238_jpg.rf.7f4160ec87e7004ae3bc9a80b43b418b.jpg
# Upper Body Vectors: [(array([72, 72, 55, ..., 13, 11, 12], dtype=uint8), array([90, 89, 71, ..., 20, 17, 16], dtype=uint8), array([127, 129, 113, ...,  39,  36,  34], dtype=uint8))]
# Lower Body Vectors: [(array([72, 71, 71, ...,  9,  9,  9], dtype=uint8), array([70, 71, 71, ...,  7,  7,  7], dtype=uint8), array([76, 77, 77, ...,  6,  6,  6], dtype=uint8))]
# Accessory Vectors: [(array([131, 131, 131, ...,  25,  25,  25], dtype=uint8), array([129, 129, 129, ...,  21,  20,  20], dtype=uint8), array([129, 129, 129, ...,  21,  21,  21], dtype=uint8)), (array([36, 36, 36, ..., 23, 23, 23], dtype=uint8), array([34, 34, 34, ..., 19, 19, 19], dtype=uint8), array([34, 34, 34, ..., 18, 18, 18], dtype=uint8)), (array([40, 41, 42, ..., 28, 28, 28], dtype=uint8), array([38, 39, 40, ..., 26, 26, 26], dtype=uint8), array([37, 38, 39, ..., 26, 26, 26], dtype=uint8)), (array([29, 29, 29, ..., 57, 57, 57], dtype=uint8), array([36, 36, 36, ..., 52, 52, 52], dtype=uint8), array([51, 51, 51, ..., 53, 53, 53], dtype=uint8))]
#
#
# Image: image_255_jpg.rf.1e0c3cbc71e6af04ff15f05bfca5e8ee.jpg
# Upper Body Vectors: [(array([119, 125, 126, ..., 132, 175, 181], dtype=uint8), array([101, 104, 104, ..., 116, 164, 175], dtype=uint8), array([ 79,  80,  79, ...,  96, 152, 165], dtype=uint8))]
# Lower Body Vectors: [(array([191, 177,  83, ...,  99, 101, 101], dtype=uint8), array([193, 179,  83, ...,  87,  88,  87], dtype=uint8), array([194, 180,  84, ...,  73,  74,  75], dtype=uint8))]
# Accessory Vectors: [(array([44, 44, 45, ..., 41, 40, 40], dtype=uint8), array([70, 70, 71, ..., 50, 49, 49], dtype=uint8), array([86, 86, 87, ..., 55, 53, 53], dtype=uint8)), (array([79, 75, 73, ..., 56, 56, 56], dtype=uint8), array([78, 73, 69, ..., 72, 72, 72], dtype=uint8), array([82, 77, 74, ..., 84, 84, 84], dtype=uint8))]
#
#
# Image: image_263_jpg.rf.89a5090b70b4aab7a9832c0f0928d651.jpg
# Upper Body Vectors: [(array([238, 235, 228, ...,  14,  14,  12], dtype=uint8), array([238, 235, 228, ...,  11,  11,  10], dtype=uint8), array([238, 235, 228, ...,   6,   6,   6], dtype=uint8))]
# Lower Body Vectors: [(array([ 10,   9,   8, ..., 205, 203, 203], dtype=uint8), array([  6,   5,   4, ..., 205, 203, 203], dtype=uint8), array([  5,   4,   3, ..., 205, 203, 203], dtype=uint8))]
# Accessory Vectors: [(array([87, 78, 71, ..., 44, 42, 38], dtype=uint8), array([88, 79, 70, ..., 39, 37, 33], dtype=uint8), array([86, 77, 68, ..., 40, 38, 34], dtype=uint8)), (array([228, 228, 228, ..., 188, 189, 190], dtype=uint8), array([228, 228, 228, ..., 188, 189, 190], dtype=uint8), array([228, 228, 228, ..., 188, 189, 190], dtype=uint8)), (array([ 79,  78,  76, ..., 197, 203, 205], dtype=uint8), array([ 73,  74,  72, ..., 197, 203, 205], dtype=uint8), array([ 74,  73,  71, ..., 197, 203, 205], dtype=uint8))]
#
#
# Image: image_266_jpg.rf.e037f3cc80569ec6f2b0e966fbb3f845.jpg
# Upper Body Vectors: [(array([10,  6,  7, ..., 29, 32, 30], dtype=uint8), array([10,  6,  7, ..., 29, 32, 30], dtype=uint8), array([10,  6,  7, ..., 29, 32, 30], dtype=uint8))]
# Lower Body Vectors: [(array([13, 15, 18, ..., 66, 63, 61], dtype=uint8), array([13, 15, 18, ..., 71, 68, 66], dtype=uint8), array([13, 15, 18, ..., 70, 67, 65], dtype=uint8))]
# Accessory Vectors: [(array([ 22,  21,  23, ..., 133, 129, 129], dtype=uint8), array([ 22,  22,  23, ..., 135, 131, 131], dtype=uint8), array([ 22,  22,  23, ..., 135, 131, 131], dtype=uint8)), (array([31, 31, 29, ..., 27, 28, 28], dtype=uint8), array([37, 37, 36, ..., 32, 33, 33], dtype=uint8), array([36, 36, 34, ..., 31, 32, 32], dtype=uint8)), (array([72, 72, 74, ..., 44, 46, 47], dtype=uint8), array([77, 78, 79, ..., 51, 53, 54], dtype=uint8), array([76, 76, 78, ..., 48, 50, 51], dtype=uint8))]
#
#
# Image: image_270_jpg.rf.de298360d5a101e1a1263c9283f9d20f.jpg
# Upper Body Vectors: [(array([18, 21, 28, ..., 55, 37, 34], dtype=uint8), array([23, 24, 30, ..., 55, 37, 34], dtype=uint8), array([22, 24, 30, ..., 55, 37, 34], dtype=uint8))]
# Lower Body Vectors: [(array([ 39,  29,  23, ..., 114, 115, 116], dtype=uint8), array([ 39,  29,  23, ..., 117, 118, 119], dtype=uint8), array([ 39,  29,  23, ..., 115, 116, 117], dtype=uint8))]
# Accessory Vectors: [(array([148, 146, 149, ..., 104, 104, 104], dtype=uint8), array([163, 164, 164, ..., 110, 110, 110], dtype=uint8), array([165, 165, 166, ..., 109, 109, 109], dtype=uint8)), (array([ 88,  88,  88, ..., 176, 174, 174], dtype=uint8), array([ 89,  89,  89, ..., 183, 182, 181], dtype=uint8), array([ 87,  87,  87, ..., 180, 178, 178], dtype=uint8)), (array([110, 109, 111, ...,  96,  96,  95], dtype=uint8), array([112, 111, 113, ...,  98,  98,  97], dtype=uint8), array([136, 135, 137, ...,  98,  98,  97], dtype=uint8))]
#
#
# Image: image_272_jpg.rf.d64dc50452f7a06ef63c3167752cec21.jpg
# Upper Body Vectors: [(array([ 87,  93,  59, ..., 201, 196, 200], dtype=uint8), array([ 86,  92,  58, ..., 201, 196, 200], dtype=uint8), array([ 88,  94,  60, ..., 201, 196, 200], dtype=uint8))]
# Lower Body Vectors: [(array([  4,  14,  12, ..., 216, 220, 122], dtype=uint8), array([  4,  14,  12, ..., 216, 220, 122], dtype=uint8), array([  4,  14,  12, ..., 216, 220, 122], dtype=uint8))]
# Accessory Vectors: [(array([125, 122, 119, ..., 195, 195, 196], dtype=uint8), array([125, 122, 119, ..., 195, 195, 196], dtype=uint8), array([125, 122, 119, ..., 195, 195, 196], dtype=uint8)), (array([  2,   0,   3, ..., 173, 177, 186], dtype=uint8), array([  2,   0,   3, ..., 173, 177, 186], dtype=uint8), array([  2,   0,   3, ..., 173, 177, 186], dtype=uint8))]
#
#
# Image: image_273_jpg.rf.c69448a3765f5637a0805aa90b46d179.jpg
# Upper Body Vectors: [(array([31, 32, 38, ..., 66, 70, 55], dtype=uint8), array([21, 23, 29, ..., 75, 81, 67], dtype=uint8), array([13, 14, 21, ..., 80, 90, 77], dtype=uint8))]
# Lower Body Vectors: [(array([146, 151, 171, ...,  36,  43,  47], dtype=uint8), array([130, 134, 152, ...,  31,  38,  42], dtype=uint8), array([112, 113, 131, ...,  32,  39,  44], dtype=uint8))]
# Accessory Vectors: [(array([77, 79, 81, ..., 79, 80, 80], dtype=uint8), array([73, 74, 77, ..., 72, 73, 73], dtype=uint8), array([72, 73, 76, ..., 69, 70, 70], dtype=uint8)), (array([21, 19, 23, ..., 49, 55, 58], dtype=uint8), array([ 6,  7,  9, ..., 46, 51, 54], dtype=uint8), array([ 0,  0,  0, ..., 42, 46, 49], dtype=uint8))]
#
#
# Image: image_292_jpg.rf.2bbb52cc56140db8c23274af6be6a08a.jpg
# Upper Body Vectors: [(array([196, 198, 195, ..., 207, 208, 209], dtype=uint8), array([200, 202, 199, ..., 209, 210, 211], dtype=uint8), array([201, 203, 200, ..., 210, 211, 212], dtype=uint8))]
# Lower Body Vectors: [(array([40, 34, 39, ..., 29, 41, 43], dtype=uint8), array([37, 32, 37, ..., 27, 39, 41], dtype=uint8), array([36, 31, 36, ..., 26, 38, 40], dtype=uint8))]
# Accessory Vectors: [(array([151, 151, 151, ..., 131, 130, 131], dtype=uint8), array([149, 149, 149, ..., 137, 136, 137], dtype=uint8), array([141, 141, 141, ..., 142, 141, 142], dtype=uint8)), (array([ 24,  23,  22, ..., 192, 195, 197], dtype=uint8), array([ 29,  28,  27, ..., 193, 194, 195], dtype=uint8), array([ 28,  27,  26, ..., 191, 193, 194], dtype=uint8))]
#
#
# Image: image_306_jpg.rf.c019ba9ffe9519796e320085c01731ed.jpg
# Upper Body Vectors: [(array([42, 32, 49, ..., 26, 18, 13], dtype=uint8), array([35, 24, 39, ..., 26, 21, 16], dtype=uint8), array([27, 15, 30, ..., 48, 45, 42], dtype=uint8))]
# Lower Body Vectors: [(array([49, 51, 49, ..., 88, 86, 79], dtype=uint8), array([29, 29, 28, ..., 86, 84, 77], dtype=uint8), array([23, 23, 20, ..., 85, 83, 76], dtype=uint8))]
# Accessory Vectors: [(array([221, 222, 226, ...,  94,  72,  65], dtype=uint8), array([219, 220, 222, ...,  90,  67,  60], dtype=uint8), array([219, 220, 223, ...,  87,  64,  57], dtype=uint8)), (array([175, 182, 185, ...,  32,  25,  22], dtype=uint8), array([173, 180, 183, ...,  30,  23,  20], dtype=uint8), array([173, 180, 183, ...,  29,  22,  19], dtype=uint8)), (array([90, 91, 95, ..., 67, 80, 97], dtype=uint8), array([117, 118, 122, ...,  81,  93, 110], dtype=uint8), array([144, 146, 149, ..., 130, 143, 162], dtype=uint8))]
#
#
# Image: image_313_jpg.rf.2aa036d66d714c22f7dc9b36e236ef6b.jpg
# Upper Body Vectors: [(array([15, 13, 11, ..., 18, 28, 24], dtype=uint8), array([10,  7,  6, ..., 16, 26, 22], dtype=uint8), array([11,  7,  5, ..., 15, 25, 21], dtype=uint8))]
# Lower Body Vectors: [(array([ 19,  21,  21, ..., 225, 210, 183], dtype=uint8), array([ 17,  19,  19, ..., 217, 196, 168], dtype=uint8), array([ 16,  18,  18, ..., 198, 173, 142], dtype=uint8))]
# Accessory Vectors: [(array([115, 110, 111, ...,  57,  35,  33], dtype=uint8), array([119, 114, 115, ...,  65,  45,  43], dtype=uint8), array([113, 108, 109, ...,  60,  39,  36], dtype=uint8)), (array([66, 64, 63, ..., 65, 69, 74], dtype=uint8), array([67, 65, 64, ..., 66, 70, 75], dtype=uint8), array([63, 61, 60, ..., 57, 61, 66], dtype=uint8)), (array([168, 163, 156, ..., 127, 102,  72], dtype=uint8), array([173, 168, 162, ..., 130, 105,  75], dtype=uint8), array([170, 165, 158, ..., 128, 103,  73], dtype=uint8))]
#
#
# Image: image_327_jpg.rf.8b15344aa0b2a6573e59094eddd39b1b.jpg
# Upper Body Vectors: [(array([187, 187, 187, ..., 121, 115, 122], dtype=uint8), array([205, 205, 205, ..., 130, 124, 129], dtype=uint8), array([212, 212, 212, ..., 133, 127, 132], dtype=uint8))]
# Lower Body Vectors: [(array([167, 175, 179, ...,  24,   0,   0], dtype=uint8), array([195, 203, 204, ...,  27,   2,   1], dtype=uint8), array([219, 227, 227, ...,  26,   0,   0], dtype=uint8))]
# Accessory Vectors: [(array([1, 0, 0, ..., 0, 0, 0], dtype=uint8), array([1, 0, 0, ..., 0, 0, 0], dtype=uint8), array([1, 0, 0, ..., 0, 0, 0], dtype=uint8))]
#
#
# Image: image_329_jpg.rf.322a8995b3cee7a6c12efb3bfaa842e1.jpg
# Upper Body Vectors: [(array([107, 109, 113, ..., 228, 232, 230], dtype=uint8), array([ 93,  92,  92, ..., 226, 231, 229], dtype=uint8), array([ 77,  76,  77, ..., 221, 226, 223], dtype=uint8))]
# Lower Body Vectors: [(array([162, 153, 156, ..., 165, 173, 179], dtype=uint8), array([161, 149, 152, ..., 164, 172, 179], dtype=uint8), array([160, 148, 151, ..., 159, 169, 175], dtype=uint8))]
# Accessory Vectors: [(array([114, 114, 114, ..., 109, 109, 109], dtype=uint8), array([122, 121, 121, ..., 108, 108, 108], dtype=uint8), array([121, 120, 120, ..., 110, 110, 110], dtype=uint8)), (array([ 28,  28,  28, ..., 200, 201, 201], dtype=uint8), array([ 19,  19,  20, ..., 190, 191, 191], dtype=uint8), array([ 16,  16,  16, ..., 183, 184, 184], dtype=uint8))]
#
#
# Image: image_32_jpg.rf.bcc83aad550e8910f04068077af50013.jpg
# Upper Body Vectors: [(array([185, 208, 203, ...,  36,  38,  36], dtype=uint8), array([186, 208, 204, ...,  26,  28,  26], dtype=uint8), array([215, 225, 214, ...,  25,  27,  25], dtype=uint8))]
# Lower Body Vectors: [(array([60, 63, 69, ..., 24, 24, 22], dtype=uint8), array([50, 53, 59, ..., 29, 29, 27], dtype=uint8), array([42, 46, 52, ..., 36, 38, 36], dtype=uint8))]
# Accessory Vectors: []
#
#
# Image: image_336_jpg.rf.9dcbe37c59b7d9a161731ee9dbdbc76b.jpg
# Upper Body Vectors: [(array([46, 27, 54, ..., 65, 70, 72], dtype=uint8), array([46, 26, 52, ..., 47, 53, 58], dtype=uint8), array([46, 26, 52, ..., 57, 62, 67], dtype=uint8))]
# Lower Body Vectors: [(array([112,  53,  68, ...,  77,  87,  89], dtype=uint8), array([104,  47,  63, ...,  86,  95,  90], dtype=uint8), array([104,  45,  60, ...,  60,  72,  86], dtype=uint8))]
# Accessory Vectors: [(array([30, 28, 26, ..., 77, 68, 62], dtype=uint8), array([18, 18, 17, ..., 64, 55, 49], dtype=uint8), array([ 46,  43,  38, ..., 166, 157, 151], dtype=uint8)), (array([18, 16, 18, ..., 88, 83, 80], dtype=uint8), array([13, 11, 13, ..., 69, 65, 65], dtype=uint8), array([ 14,  12,  14, ..., 178, 172, 170], dtype=uint8)), (array([81, 77, 71, ..., 74, 79, 82], dtype=uint8), array([81, 76, 70, ..., 70, 75, 78], dtype=uint8), array([81, 76, 70, ..., 69, 74, 77], dtype=uint8))]
#
#
# Image: image_337_jpg.rf.3de7b116fca1e359ae5e26ed706d7588.jpg
# Upper Body Vectors: [(array([172, 151, 118, ...,   7,   2,   2], dtype=uint8), array([185, 162, 125, ...,   7,   2,   2], dtype=uint8), array([183, 160, 125, ...,   7,   2,   2], dtype=uint8))]
# Lower Body Vectors: [(array([ 34,  33,  35, ..., 195, 194, 192], dtype=uint8), array([ 32,  31,  33, ..., 192, 190, 188], dtype=uint8), array([ 32,  31,  33, ..., 192, 190, 188], dtype=uint8))]
# Accessory Vectors: [(array([151, 152, 154, ...,  90,  91,  92], dtype=uint8), array([156, 157, 159, ...,  92,  93,  94], dtype=uint8), array([159, 160, 162, ...,  92,  93,  94], dtype=uint8)), (array([154, 154, 154, ...,  53,  53,  53], dtype=uint8), array([153, 153, 153, ...,  59,  59,  59], dtype=uint8), array([149, 149, 149, ...,  58,  58,  58], dtype=uint8))]
#
#
# Image: image_339_jpg.rf.2ada7f46ee87846609af091d19f1f8e6.jpg
# Upper Body Vectors: [(array([225, 228, 226, ..., 177, 175, 168], dtype=uint8), array([225, 228, 226, ..., 177, 175, 168], dtype=uint8), array([225, 228, 226, ..., 177, 175, 168], dtype=uint8))]
# Lower Body Vectors: [(array([227, 233, 233, ...,  50,  86, 156], dtype=uint8), array([225, 231, 233, ...,  50,  86, 156], dtype=uint8), array([225, 231, 233, ...,  50,  86, 156], dtype=uint8))]
# Accessory Vectors: [(array([221, 221, 221, ..., 178, 179, 182], dtype=uint8), array([221, 221, 221, ..., 178, 179, 182], dtype=uint8), array([221, 221, 221, ..., 178, 179, 182], dtype=uint8)), (array([ 52,  50,  49, ..., 119, 119, 121], dtype=uint8), array([ 52,  50,  49, ..., 119, 119, 121], dtype=uint8), array([ 52,  50,  49, ..., 119, 119, 121], dtype=uint8))]
#
#
# Image: image_348_jpg.rf.7f6b20997d244b251a33a29eb6ecfd12.jpg
# Upper Body Vectors: [(array([232, 236, 239, ..., 130, 127, 140], dtype=uint8), array([226, 230, 232, ..., 124, 119, 128], dtype=uint8), array([228, 232, 234, ..., 120, 118, 130], dtype=uint8))]
# Lower Body Vectors: [(array([189, 175, 190, ...,  82,  92, 100], dtype=uint8), array([191, 177, 192, ...,  93,  97, 101], dtype=uint8), array([200, 186, 201, ...,  73,  78,  81], dtype=uint8))]
# Accessory Vectors: []
#
#
# Image: image_353_jpg.rf.3bef28d2115d0f6f62ddfb88917f4bd2.jpg
# Upper Body Vectors: [(array([185, 185, 181, ..., 101, 107, 100], dtype=uint8), array([200, 200, 198, ..., 108, 115, 110], dtype=uint8), array([203, 203, 201, ..., 147, 141, 127], dtype=uint8))]
# Lower Body Vectors: [(array([54, 45, 40, ..., 92, 85, 86], dtype=uint8), array([57, 49, 45, ..., 96, 89, 91], dtype=uint8), array([70, 60, 54, ..., 81, 77, 81], dtype=uint8))]
# Accessory Vectors: [(array([208, 208, 208, ..., 162, 166, 169], dtype=uint8), array([217, 217, 217, ..., 172, 176, 179], dtype=uint8), array([221, 221, 221, ..., 179, 183, 186], dtype=uint8)), (array([131, 128, 141, ...,  70,  70,  75], dtype=uint8), array([135, 129, 141, ...,  85,  83,  89], dtype=uint8), array([123, 115, 122, ...,  97,  96, 101], dtype=uint8))]
#
#
# Image: image_371_jpg.rf.196734409238b48540ea3062959eb71d.jpg
# Upper Body Vectors: [(array([177,  88,  64, ..., 102,  85,  82], dtype=uint8), array([183,  93,  69, ..., 107,  90,  87], dtype=uint8), array([181,  92,  68, ..., 108,  89,  86], dtype=uint8))]
# Lower Body Vectors: [(array([39, 39, 42, ..., 45, 57, 61], dtype=uint8), array([52, 54, 56, ..., 55, 72, 77], dtype=uint8), array([56, 57, 60, ..., 69, 84, 89], dtype=uint8))]
# Accessory Vectors: [(array([47, 47, 47, ..., 31, 32, 33], dtype=uint8), array([55, 55, 56, ..., 38, 39, 40], dtype=uint8), array([62, 62, 62, ..., 35, 36, 37], dtype=uint8)), (array([123, 123, 123, ...,  17,  18,  18], dtype=uint8), array([126, 126, 127, ...,  20,  19,  19], dtype=uint8), array([124, 124, 124, ...,  22,  23,  23], dtype=uint8))]
#
#
# Image: image_377_jpg.rf.7de5395f1a36df49e447d2a82e2a4003.jpg
# Upper Body Vectors: [(array([ 17,  19,  23, ..., 136, 117, 108], dtype=uint8), array([ 15,  17,  21, ..., 135, 115, 106], dtype=uint8), array([ 14,  16,  20, ..., 135, 114, 103], dtype=uint8))]
# Lower Body Vectors: [(array([46, 39, 34, ..., 39, 37, 35], dtype=uint8), array([45, 37, 33, ..., 38, 36, 34], dtype=uint8), array([41, 33, 29, ..., 34, 32, 30], dtype=uint8))]
# Accessory Vectors: [(array([ 63,  62,  65, ..., 123, 124, 128], dtype=uint8), array([ 67,  64,  67, ..., 130, 131, 135], dtype=uint8), array([ 62,  63,  67, ..., 127, 128, 132], dtype=uint8)), (array([ 41,  43,  44, ..., 164, 175, 183], dtype=uint8), array([ 45,  46,  47, ..., 170, 181, 189], dtype=uint8), array([ 40,  40,  41, ..., 170, 181, 188], dtype=uint8))]
#
#
# Image: image_383_jpg.rf.7a450add0df474ed0673e1a9d40d84d7.jpg
# Upper Body Vectors: [(array([52, 50, 48, ..., 15, 15, 12], dtype=uint8), array([39, 36, 32, ..., 10, 10,  6], dtype=uint8), array([32, 25, 20, ...,  9,  9,  6], dtype=uint8))]
# Lower Body Vectors: [(array([120, 119, 111, ..., 183, 160, 148], dtype=uint8), array([117, 115, 107, ..., 180, 157, 145], dtype=uint8), array([118, 116, 108, ..., 176, 153, 141], dtype=uint8))]
# Accessory Vectors: [(array([92, 92, 93, ..., 60, 61, 63], dtype=uint8), array([90, 90, 92, ..., 60, 61, 63], dtype=uint8), array([90, 90, 92, ..., 60, 61, 63], dtype=uint8)), (array([105,  97,  95, ...,  94,  98, 101], dtype=uint8), array([100,  92,  91, ...,  94,  98, 101], dtype=uint8), array([101,  97,  96, ...,  94,  98, 101], dtype=uint8))]
#
#
# Image: image_389_jpg.rf.9cabd84052f2bcfd02027b115b042639.jpg
# Upper Body Vectors: [(array([77, 81, 82, ..., 88, 90, 90], dtype=uint8), array([76, 80, 81, ..., 93, 95, 95], dtype=uint8), array([78, 82, 83, ..., 92, 94, 94], dtype=uint8))]
# Lower Body Vectors: [(array([165, 160, 164, ..., 134, 161, 239], dtype=uint8), array([170, 165, 169, ..., 130, 156, 235], dtype=uint8), array([169, 164, 168, ..., 130, 157, 236], dtype=uint8))]
# Accessory Vectors: [(array([131, 131, 131, ..., 159, 158, 158], dtype=uint8), array([131, 131, 131, ..., 159, 158, 158], dtype=uint8), array([131, 131, 131, ..., 159, 158, 158], dtype=uint8)), (array([ 19,  20,  19, ..., 153, 156, 153], dtype=uint8), array([ 19,  20,  19, ..., 153, 156, 153], dtype=uint8), array([ 19,  20,  19, ..., 153, 156, 153], dtype=uint8))]
#
#
# Image: image_392_jpg.rf.cce85158047fb2e119f44863c227c470.jpg
# Upper Body Vectors: [(array([201, 195, 191, ..., 195, 198, 198], dtype=uint8), array([204, 200, 195, ..., 200, 202, 201], dtype=uint8), array([205, 200, 195, ..., 203, 205, 205], dtype=uint8))]
# Lower Body Vectors: [(array([28, 36, 36, ..., 20, 20, 20], dtype=uint8), array([28, 36, 36, ..., 22, 22, 22], dtype=uint8), array([28, 36, 36, ..., 22, 22, 22], dtype=uint8))]
# Accessory Vectors: [(array([203, 204, 205, ...,  48,  49,  50], dtype=uint8), array([211, 212, 213, ...,  50,  51,  52], dtype=uint8), array([210, 210, 212, ...,  61,  63,  63], dtype=uint8)), (array([197, 196, 193, ..., 170, 165, 160], dtype=uint8), array([200, 199, 197, ..., 174, 169, 164], dtype=uint8), array([204, 203, 200, ..., 179, 174, 169], dtype=uint8)), (array([87, 84, 84, ..., 31, 29, 29], dtype=uint8), array([99, 96, 95, ..., 56, 57, 57], dtype=uint8), array([126, 124, 123, ...,  85,  86,  87], dtype=uint8))]
#
#
# Image: image_403_jpg.rf.19f10e6cec696929d6a4a4057fde7196.jpg
# Upper Body Vectors: [(array([131, 102,  96, ..., 114,  70,  71], dtype=uint8), array([115,  87,  80, ..., 101,  66,  68], dtype=uint8), array([109,  82,  76, ...,  99,  62,  63], dtype=uint8))]
# Lower Body Vectors: [(array([157, 153, 151, ..., 104, 126, 166], dtype=uint8), array([146, 138, 130, ...,  88, 112, 156], dtype=uint8), array([138, 125, 115, ...,  82, 106, 149], dtype=uint8))]
# Accessory Vectors: []
#
#
# Image: image_40_jpg.rf.c9c1f1b14bb41c1ffc3ced155f1602aa.jpg
# Upper Body Vectors: [(array([47, 49, 48, ..., 82,  9,  6], dtype=uint8), array([42, 44, 43, ..., 83,  9,  5], dtype=uint8), array([44, 46, 44, ..., 87, 12,  9], dtype=uint8))]
# Lower Body Vectors: [(array([ 37,  39,  39, ...,  49,  96, 118], dtype=uint8), array([ 37,  39,  39, ...,  54, 101, 123], dtype=uint8), array([ 37,  39,  39, ...,  55, 102, 128], dtype=uint8))]
# Accessory Vectors: [(array([ 54,  54,  54, ..., 246, 244, 244], dtype=uint8), array([ 52,  52,  52, ..., 251, 249, 249], dtype=uint8), array([ 52,  52,  52, ..., 252, 250, 250], dtype=uint8)), (array([103,  98,  86, ..., 121, 118, 117], dtype=uint8), array([101,  97,  85, ..., 113, 110, 109], dtype=uint8), array([101,  97,  85, ..., 113, 111, 110], dtype=uint8))]
#
#
# Image: image_418_jpg.rf.1b7d740452ddba1284e4863414da51db.jpg
# Upper Body Vectors: [(array([ 79,  78,  80, ..., 104, 111, 108], dtype=uint8), array([ 72,  69,  71, ...,  97, 101,  99], dtype=uint8), array([63, 60, 61, ..., 94, 98, 96], dtype=uint8))]
# Lower Body Vectors: [(array([126, 126, 122, ..., 174, 157, 152], dtype=uint8), array([111, 112, 107, ..., 178, 162, 160], dtype=uint8), array([108, 108, 104, ..., 191, 175, 171], dtype=uint8))]
# Accessory Vectors: [(array([154, 154, 153, ..., 153, 153, 161], dtype=uint8), array([167, 167, 166, ..., 160, 158, 166], dtype=uint8), array([175, 175, 174, ..., 163, 161, 169], dtype=uint8)), (array([148, 136, 123, ..., 221, 222, 224], dtype=uint8), array([127, 114,  99, ..., 212, 216, 218], dtype=uint8), array([125, 110,  92, ..., 213, 217, 219], dtype=uint8)), (array([ 44,  43,  38, ...,  95, 117, 120], dtype=uint8), array([ 50,  49,  43, ...,  81, 102, 105], dtype=uint8), array([ 57,  56,  51, ...,  79, 101, 103], dtype=uint8))]
#
#
# Image: image_425_jpg.rf.543b1bfc4597abe3c02fa40b97ba3f88.jpg
# Upper Body Vectors: [(array([182, 121,  54, ...,  47,  49,  49], dtype=uint8), array([180, 119,  52, ...,  42,  44,  45], dtype=uint8), array([179, 118,  51, ...,  41,  43,  43], dtype=uint8))]
# Lower Body Vectors: [(array([ 8, 10, 12, ..., 41, 36, 30], dtype=uint8), array([ 2,  2,  4, ..., 36, 31, 25], dtype=uint8), array([ 3,  4,  5, ..., 35, 30, 24], dtype=uint8))]
# Accessory Vectors: [(array([71, 74, 73, ..., 47, 43, 41], dtype=uint8), array([66, 69, 68, ..., 42, 39, 37], dtype=uint8), array([65, 68, 67, ..., 41, 38, 36], dtype=uint8))]
#
#
# Image: image_42_jpg.rf.13e164b2928891e127bcd61446a08240.jpg
# Upper Body Vectors: [(array([ 86,  73,  63, ..., 215, 163,  99], dtype=uint8), array([ 92,  78,  67, ..., 216, 167, 106], dtype=uint8), array([118, 101,  86, ..., 225, 179, 124], dtype=uint8))]
# Lower Body Vectors: [(array([ 51,  48,  33, ..., 155, 148, 136], dtype=uint8), array([ 55,  55,  40, ..., 153, 146, 134], dtype=uint8), array([ 74,  72,  56, ..., 145, 138, 126], dtype=uint8))]
# Accessory Vectors: [(array([108, 108, 112, ...,  63,  50,  50], dtype=uint8), array([108, 108, 112, ...,  62,  48,  48], dtype=uint8), array([108, 108, 112, ...,  62,  48,  48], dtype=uint8)), (array([143, 147, 164, ..., 115, 111, 110], dtype=uint8), array([145, 149, 166, ..., 110, 106, 105], dtype=uint8), array([145, 149, 166, ..., 112, 108, 107], dtype=uint8))]
#
#
# Image: image_439_jpg.rf.bba79756e90f3c850bee4bf5a05d0d47.jpg
# ...
#
#
# Image: image_845_jpg.rf.2e658eb1f49ff3f0a903cff874dfaa97.jpg
# Upper Body Vectors: [(array([187, 183, 189, ...,  22,  24,  24], dtype=uint8), array([189, 185, 191, ...,  16,  19,  21], dtype=uint8), array([190, 186, 192, ...,  19,  21,  23], dtype=uint8))]
# Lower Body Vectors: [(array([43, 43, 37, ..., 31, 31, 31], dtype=uint8), array([41, 38, 33, ..., 29, 29, 29], dtype=uint8), array([40, 40, 34, ..., 29, 29, 29], dtype=uint8))]
# Accessory Vectors: [(array([215, 215, 211, ..., 176, 176, 176], dtype=uint8), array([215, 215, 211, ..., 178, 178, 178], dtype=uint8), array([215, 215, 211, ..., 178, 178, 178], dtype=uint8)), (array([ 99,  98,  94, ..., 195, 195, 195], dtype=uint8), array([ 97,  96,  92, ..., 196, 196, 196], dtype=uint8), array([ 97,  96,  92, ..., 200, 200, 200], dtype=uint8)), (array([197, 198, 201, ..., 201, 199, 199], dtype=uint8), array([199, 200, 203, ..., 203, 201, 201], dtype=uint8), array([200, 201, 204, ..., 204, 202, 202], dtype=uint8))]
#
#
# Image: image_854_jpg.rf.0af171550f8b5e0c9d0eb4d54f222718.jpg
# Upper Body Vectors: [(array([36, 46, 41, ...,  2,  5,  5], dtype=uint8), array([37, 44, 32, ...,  1,  7,  7], dtype=uint8), array([115, 137, 135, ...,  46,  37,  35], dtype=uint8))]
# Lower Body Vectors: [(array([208, 231, 236, ...,  97,  93,  94], dtype=uint8), array([212, 237, 244, ..., 114, 110, 111], dtype=uint8), array([227, 237, 234, ..., 117, 113, 114], dtype=uint8))]
# Accessory Vectors: [(array([164, 179, 171, ...,  47,  44,  32], dtype=uint8), array([174, 189, 183, ...,  63,  56,  45], dtype=uint8), array([191, 206, 201, ...,  80,  74,  59], dtype=uint8)), (array([60, 56, 50, ..., 12, 13, 13], dtype=uint8), array([65, 61, 55, ..., 25, 24, 24], dtype=uint8), array([96, 92, 86, ..., 33, 32, 32], dtype=uint8))]
#
#
# Image: image_855_jpg.rf.79bf0e92c53c98d1c01d3131bc166311.jpg
# Upper Body Vectors: [(array([ 36,  39,  48, ..., 128, 130, 135], dtype=uint8), array([ 50,  55,  66, ..., 137, 139, 145], dtype=uint8), array([ 75,  83,  97, ..., 147, 149, 155], dtype=uint8))]
# Lower Body Vectors: [(array([46, 56, 61, ..., 32, 31, 30], dtype=uint8), array([66, 77, 81, ..., 31, 31, 30], dtype=uint8), array([ 98, 115, 121, ...,  31,  31,  30], dtype=uint8))]
# Accessory Vectors: [(array([148, 151, 155, ..., 131, 130, 128], dtype=uint8), array([151, 155, 158, ..., 136, 135, 133], dtype=uint8), array([155, 159, 162, ..., 135, 134, 132], dtype=uint8)), (array([ 26,  27,  28, ..., 204, 202, 202], dtype=uint8), array([ 28,  28,  29, ..., 206, 204, 204], dtype=uint8), array([ 29,  32,  33, ..., 206, 204, 204], dtype=uint8))]
#
#
# Image: image_856_jpg.rf.3f90c02ae0a9a3ec652fb9beb51f8fd4.jpg
# Upper Body Vectors: [(array([ 15,   4,   5, ...,  85, 201, 229], dtype=uint8), array([ 16,   6,   5, ...,  85, 201, 231], dtype=uint8), array([ 16,   6,   5, ...,  85, 201, 231], dtype=uint8))]
# Lower Body Vectors: [(array([160, 153, 143, ..., 207, 202, 221], dtype=uint8), array([148, 141, 134, ..., 196, 193, 214], dtype=uint8), array([137, 130, 123, ..., 182, 181, 207], dtype=uint8))]
# Accessory Vectors: [(array([95, 96, 96, ..., 50, 53, 56], dtype=uint8), array([100, 101, 101, ...,  50,  53,  56], dtype=uint8), array([101, 102, 102, ...,  50,  53,  56], dtype=uint8))]
#
#
# Image: image_858_jpg.rf.49ec4dfea81d16e42f6cc7d0bc3ff3ab.jpg
# Upper Body Vectors: [(array([188, 117,  61, ...,  42,  50,  43], dtype=uint8), array([192, 119,  61, ...,  39,  47,  40], dtype=uint8), array([194, 119,  61, ...,  34,  41,  35], dtype=uint8))]
# Lower Body Vectors: [(array([ 9, 11, 14, ..., 31, 29, 24], dtype=uint8), array([ 7,  6, 10, ..., 32, 29, 28], dtype=uint8), array([ 7,  7,  8, ..., 28, 25, 23], dtype=uint8))]
# Accessory Vectors: [(array([ 49,  49,  51, ..., 121, 121, 121], dtype=uint8), array([ 49,  49,  48, ..., 133, 132, 132], dtype=uint8), array([ 43,  43,  43, ..., 161, 160, 160], dtype=uint8)), (array([222, 205, 183, ...,  69,  72,  84], dtype=uint8), array([217, 199, 177, ...,  82,  86,  98], dtype=uint8), array([202, 182, 159, ...,  94,  98, 110], dtype=uint8))]
#
#
# Image: image_865_jpg.rf.d6eed90bfe135fd47472bef72d8cc41a.jpg
# Upper Body Vectors: [(array([183, 183, 183, ..., 188, 183, 173], dtype=uint8), array([188, 188, 188, ..., 190, 184, 174], dtype=uint8), array([187, 187, 187, ..., 171, 167, 158], dtype=uint8))]
# Lower Body Vectors: [(array([106,  99,  62, ...,  69,  68,  67], dtype=uint8), array([106,  96,  55, ...,  59,  60,  59], dtype=uint8), array([92, 81, 39, ..., 42, 43, 42], dtype=uint8))]
# Accessory Vectors: [(array([ 65,  62,  61, ..., 167, 166, 165], dtype=uint8), array([ 59,  55,  52, ..., 166, 165, 165], dtype=uint8), array([ 48,  44,  42, ..., 162, 161, 159], dtype=uint8)), (array([165, 162, 160, ...,  77,  78,  77], dtype=uint8), array([164, 161, 159, ...,  64,  65,  64], dtype=uint8), array([160, 157, 155, ...,  48,  49,  48], dtype=uint8)), (array([195, 163, 108, ..., 105, 105, 104], dtype=uint8), array([192, 160, 105, ..., 107, 107, 106], dtype=uint8), array([188, 156, 101, ..., 101, 101, 100], dtype=uint8))]
#
#
# Image: image_876_jpg.rf.efc127e147a0d67cbfce42d13400f84d.jpg
# Upper Body Vectors: [(array([ 48,   5,  32, ..., 105, 119, 124], dtype=uint8), array([ 62,  19,  47, ..., 125, 137, 142], dtype=uint8), array([ 85,  42,  71, ..., 139, 151, 155], dtype=uint8))]
# Lower Body Vectors: [(array([102, 107,  48, ...,  87, 102, 109], dtype=uint8), array([111, 117,  59, ..., 125, 143, 154], dtype=uint8), array([120, 122,  61, ..., 160, 178, 191], dtype=uint8))]
# Accessory Vectors: [(array([63, 53, 43, ..., 24, 26, 35], dtype=uint8), array([101,  89,  78, ...,  48,  49,  57], dtype=uint8), array([95, 84, 74, ..., 90, 92, 99], dtype=uint8))]
#
#
# Image: image_88_jpg.rf.a11f4480e79141a482e560f264f59750.jpg
# Upper Body Vectors: [(array([179, 182, 177, ..., 179, 182, 181], dtype=uint8), array([183, 186, 183, ..., 184, 187, 186], dtype=uint8), array([185, 187, 183, ..., 183, 186, 185], dtype=uint8))]
# Lower Body Vectors: [(array([ 8,  8,  8, ..., 31, 31, 31], dtype=uint8), array([ 0,  0,  0, ..., 43, 43, 43], dtype=uint8), array([10, 10, 10, ..., 61, 61, 61], dtype=uint8))]
# Accessory Vectors: [(array([125, 125, 125, ..., 185, 187, 188], dtype=uint8), array([137, 137, 136, ..., 197, 198, 199], dtype=uint8), array([141, 141, 140, ..., 194, 196, 197], dtype=uint8)), (array([ 90,  91,  89, ..., 140, 139, 140], dtype=uint8), array([102, 103, 101, ..., 153, 153, 152], dtype=uint8), array([104, 105, 103, ..., 155, 152, 154], dtype=uint8)), (array([ 66,  88, 109, ..., 197, 209, 222], dtype=uint8), array([ 68,  90, 110, ..., 185, 199, 213], dtype=uint8), array([ 68,  90, 110, ..., 180, 195, 209], dtype=uint8))]
#
#
# Image: image_896_jpg.rf.60cdf91c49188c0947fd9730f964d146.jpg
# Upper Body Vectors: [(array([ 78,  60,  51, ..., 218, 216, 220], dtype=uint8), array([ 33,  23,  28, ..., 221, 221, 225], dtype=uint8), array([ 32,  25,  31, ..., 222, 222, 226], dtype=uint8))]
# Lower Body Vectors: [(array([174, 172, 172, ..., 131, 146, 144], dtype=uint8), array([182, 183, 182, ..., 139, 153, 152], dtype=uint8), array([181, 181, 181, ..., 145, 157, 155], dtype=uint8))]
# Accessory Vectors: [(array([172, 171, 171, ..., 206, 206, 207], dtype=uint8), array([171, 170, 170, ..., 208, 208, 209], dtype=uint8), array([167, 166, 166, ..., 202, 202, 203], dtype=uint8)), (array([25, 21, 14, ..., 32, 33, 34], dtype=uint8), array([23, 19, 12, ..., 27, 30, 32], dtype=uint8), array([22, 18, 11, ..., 28, 31, 32], dtype=uint8))]
#
#
# Image: image_906_jpg.rf.a6120b6f6140de32377b5abba2d08a17.jpg
# Upper Body Vectors: [(array([193, 154, 124, ...,  65,  66,  67], dtype=uint8), array([184, 143, 110, ...,  47,  49,  51], dtype=uint8), array([178, 136, 103, ...,  39,  39,  39], dtype=uint8))]
# Lower Body Vectors: [(array([ 23,  26,  31, ..., 155, 154, 156], dtype=uint8), array([ 24,  24,  29, ..., 175, 176, 173], dtype=uint8), array([ 45,  30,  25, ..., 180, 180, 182], dtype=uint8))]
# Accessory Vectors: []
#
#
# Image: image_907_jpg.rf.46c4382837f43318aef36ddf0591d6bf.jpg
# Upper Body Vectors: [(array([ 70,  63,  64, ...,  52, 109, 157], dtype=uint8), array([ 52,  44,  45, ...,  48, 105, 153], dtype=uint8), array([ 49,  40,  40, ...,  47, 104, 152], dtype=uint8))]
# Lower Body Vectors: [(array([124, 111, 103, ...,  50,  51,  52], dtype=uint8), array([87, 75, 70, ..., 44, 45, 46], dtype=uint8), array([71, 59, 53, ..., 37, 38, 39], dtype=uint8))]
# Accessory Vectors: [(array([92, 93, 76, ..., 77, 69, 54], dtype=uint8), array([82, 84, 67, ..., 57, 49, 34], dtype=uint8), array([82, 82, 64, ..., 50, 43, 29], dtype=uint8)), (array([141, 139, 136, ...,  42,  41,  40], dtype=uint8), array([106, 104, 101, ...,  51,  50,  49], dtype=uint8), array([102, 100,  97, ...,  62,  60,  59], dtype=uint8)), (array([66, 66, 65, ..., 21, 21, 21], dtype=uint8), array([49, 49, 49, ..., 25, 25, 25], dtype=uint8), array([46, 46, 46, ..., 30, 30, 30], dtype=uint8))]
#
#
# Image: image_911_jpg.rf.9dbaee104d9046c78e24521da3a62658.jpg
# Upper Body Vectors: [(array([46, 45, 43, ..., 14, 14, 16], dtype=uint8), array([27, 25, 24, ...,  3,  2,  3], dtype=uint8), array([26, 24, 23, ...,  1,  0,  1], dtype=uint8))]
# Lower Body Vectors: [(array([102, 204, 227, ...,  30,  32,  37], dtype=uint8), array([ 95, 199, 223, ...,  25,  27,  32], dtype=uint8), array([ 92, 196, 221, ...,  22,  25,  31], dtype=uint8))]
# Accessory Vectors: [(array([37, 37, 37, ..., 37, 38, 38], dtype=uint8), array([23, 23, 23, ..., 35, 36, 36], dtype=uint8), array([27, 27, 28, ..., 47, 48, 48], dtype=uint8)), (array([168, 168, 168, ..., 114, 114, 114], dtype=uint8), array([168, 168, 168, ..., 116, 116, 116], dtype=uint8), array([168, 168, 168, ..., 116, 116, 116], dtype=uint8)), (array([198, 196, 193, ...,  92,  93,  95], dtype=uint8), array([201, 198, 194, ...,  94,  94,  95], dtype=uint8), array([206, 203, 198, ...,  95,  95,  95], dtype=uint8)), (array([196, 181, 144, ...,  55,  78,  82], dtype=uint8), array([191, 173, 137, ...,  52,  75,  79], dtype=uint8), array([190, 173, 135, ...,  50,  71,  75], dtype=uint8))]
#
#
# Image: image_938_jpg.rf.4cfc505516f666f78e6b8af05370686f.jpg
# Upper Body Vectors: [(array([57, 59, 58, ..., 51, 55, 56], dtype=uint8), array([81, 80, 79, ..., 61, 66, 68], dtype=uint8), array([101, 101, 100, ...,  74,  79,  80], dtype=uint8))]
# Lower Body Vectors: [(array([ 10,  12,   8, ...,  98, 101,  93], dtype=uint8), array([13, 14,  6, ..., 70, 71, 63], dtype=uint8), array([ 19,  24,  23, ..., 116, 121, 112], dtype=uint8))]
# Accessory Vectors: [(array([  9,   9,   9, ..., 193, 192, 192], dtype=uint8), array([  3,   3,   3, ..., 191, 190, 190], dtype=uint8), array([ 20,  20,  20, ..., 180, 179, 179], dtype=uint8)), (array([108, 110, 112, ...,  95,  97,  98], dtype=uint8), array([111, 112, 115, ...,  97,  99, 100], dtype=uint8), array([115, 117, 119, ...,  98, 100, 101], dtype=uint8))]
#
#
# Image: image_946_jpg.rf.cb54e30dce85e36e7acd71ec1d69f457.jpg
# Upper Body Vectors: [(array([44, 17, 27, ...,  8, 22,  9], dtype=uint8), array([52, 24, 33, ...,  6, 24, 10], dtype=uint8), array([51, 24, 32, ...,  4, 21,  8], dtype=uint8))]
# Lower Body Vectors: [(array([13, 12, 13, ..., 88, 83, 78], dtype=uint8), array([ 20,  19,  17, ..., 110, 109, 110], dtype=uint8), array([ 23,  22,  22, ..., 143, 149, 154], dtype=uint8))]
# Accessory Vectors: []
#
#
# Image: image_951_jpg.rf.b22452ec66e73f3c3e66a07366da7fc3.jpg
# Upper Body Vectors: [(array([146, 153, 146, ..., 118, 139, 137], dtype=uint8), array([121, 126, 112, ...,  90, 111, 109], dtype=uint8), array([ 95, 100,  90, ...,  71,  94,  92], dtype=uint8))]
# Lower Body Vectors: [(array([175, 172, 176, ..., 210, 211, 201], dtype=uint8), array([179, 175, 178, ..., 210, 209, 199], dtype=uint8), array([177, 173, 176, ..., 210, 209, 199], dtype=uint8))]
# Accessory Vectors: [(array([120, 119, 118, ..., 102, 103, 104], dtype=uint8), array([127, 126, 124, ..., 107, 108, 109], dtype=uint8), array([130, 129, 128, ..., 106, 107, 108], dtype=uint8)), (array([157, 157, 158, ...,  74,  83,  89], dtype=uint8), array([155, 155, 156, ...,  76,  85,  91], dtype=uint8), array([155, 155, 156, ...,  76,  85,  91], dtype=uint8))]
#
#
# Image: image_959_jpg.rf.2b1f877bc506da6612faaa4dd1bfe613.jpg
# Upper Body Vectors: [(array([175, 174, 122, ...,  83,  71,  63], dtype=uint8), array([178, 177, 123, ...,  89,  74,  66], dtype=uint8), array([179, 178, 124, ...,  96,  82,  75], dtype=uint8))]
# Lower Body Vectors: [(array([46, 62, 63, ..., 28, 28, 26], dtype=uint8), array([38, 51, 51, ..., 19, 18, 17], dtype=uint8), array([37, 47, 47, ..., 12, 12, 13], dtype=uint8))]
# Accessory Vectors: [(array([187, 187, 186, ...,  55,  57,  58], dtype=uint8), array([176, 175, 175, ...,  50,  52,  53], dtype=uint8), array([172, 172, 171, ...,  49,  51,  52], dtype=uint8)), (array([ 24,  23,  21, ..., 230, 230, 230], dtype=uint8), array([ 15,  14,  14, ..., 225, 225, 225], dtype=uint8), array([ 12,  11,  10, ..., 224, 224, 224], dtype=uint8))]
#
#
# Image: image_965_jpg.rf.96ae2b7b9a6e1c3f69dfe1776e107496.jpg
# Upper Body Vectors: [(array([ 56,  70,  61, ...,  29,  44, 103], dtype=uint8), array([ 70,  88,  79, ...,  38,  50, 107], dtype=uint8), array([ 68,  85,  76, ...,  38,  51, 108], dtype=uint8))]
# Lower Body Vectors: [(array([ 94, 165, 185, ..., 155, 154, 150], dtype=uint8), array([ 96, 166, 186, ..., 159, 159, 155], dtype=uint8), array([ 97, 168, 187, ..., 160, 160, 156], dtype=uint8))]
# Accessory Vectors: [(array([196, 197, 198, ...,  81,  91,  97], dtype=uint8), array([196, 197, 198, ...,  79,  89,  95], dtype=uint8), array([196, 197, 198, ...,  79,  89,  95], dtype=uint8)), (array([159, 159, 158, ..., 137, 153, 157], dtype=uint8), array([161, 161, 160, ..., 137, 153, 157], dtype=uint8), array([162, 162, 161, ..., 137, 153, 157], dtype=uint8))]
#
#
# Image: image_97_jpg.rf.9c5add556d26e2a8d0cfac3a74f11165.jpg
# Upper Body Vectors: [(array([ 16,  16,  17, ..., 139, 146, 141], dtype=uint8), array([  4,   5,   6, ..., 122, 128, 126], dtype=uint8), array([ 2,  1,  2, ..., 84, 90, 86], dtype=uint8))]
# Lower Body Vectors: [(array([63, 34, 11, ...,  8,  5,  3], dtype=uint8), array([54, 25,  4, ...,  6,  3,  1], dtype=uint8), array([38, 15,  0, ...,  6,  3,  1], dtype=uint8))]
# Accessory Vectors: [(array([136, 136, 134, ...,  92,  85,  85], dtype=uint8), array([144, 144, 141, ...,  93,  87,  87], dtype=uint8), array([151, 151, 148, ..., 103,  97,  97], dtype=uint8)), (array([ 67,  75,  75, ...,  94, 114, 105], dtype=uint8), array([ 64,  69,  68, ..., 108, 129, 122], dtype=uint8), array([ 66,  74,  73, ..., 126, 148, 140], dtype=uint8))]
#
#
# Image: image_985_jpg.rf.e518c5b2392416fa3958277a634843d4.jpg
# Upper Body Vectors: [(array([171, 165, 162, ...,  95,  67,  49], dtype=uint8), array([171, 164, 162, ..., 112,  81,  66], dtype=uint8), array([171, 166, 163, ..., 143, 109,  98], dtype=uint8))]
# Lower Body Vectors: [(array([11, 20, 44, ..., 48, 52, 52], dtype=uint8), array([10, 16, 42, ..., 48, 53, 52], dtype=uint8), array([14, 20, 44, ..., 48, 53, 52], dtype=uint8))]
# Accessory Vectors: [(array([119, 119, 120, ...,  98, 102, 102], dtype=uint8), array([133, 133, 134, ..., 110, 114, 114], dtype=uint8), array([145, 145, 146, ..., 116, 120, 120], dtype=uint8)), (array([130, 129, 125, ...,  63,  68,  69], dtype=uint8), array([153, 152, 148, ...,  79,  85,  86], dtype=uint8), array([169, 168, 164, ...,  94,  98,  99], dtype=uint8)), (array([113, 121, 120, ...,  32,  34,  43], dtype=uint8), array([102, 113, 114, ...,  27,  28,  34], dtype=uint8), array([ 98, 113, 115, ...,  28,  27,  30], dtype=uint8)), (array([ 72,  73,  75, ..., 113, 116, 117], dtype=uint8), array([71, 72, 74, ..., 95, 97, 99], dtype=uint8), array([75, 76, 78, ..., 79, 81, 82], dtype=uint8))]

# %%
# 데이터 준비
upper_body_data = []  # 상의 벡터 (고정 크기 30000)
lower_body_labels = []  # 하의 벡터 (고정 크기 30000)
accessory_data = []  # 가변 길이 악세사리 시퀀스
accessory_labels = []  # 가변 길이 악세사리 레이블 시퀀스

for image_name, vectors in valid_image_sets.items():
    # 상의 벡터 처리 (R, G, B 결합)
    if len(vectors['upper_body']) > 0:
        r_vector, g_vector, b_vector = vectors['upper_body'][0]
        upper_body_vector = np.concatenate([r_vector, g_vector, b_vector])  # 크기: 30000
    else:
        upper_body_vector = np.zeros(30000)  # 기본값

    upper_body_data.append(upper_body_vector)

    # 하의 벡터 처리 (R, G, B 결합)
    if len(vectors['lower_body']) > 0:
        r_vector, g_vector, b_vector = vectors['lower_body'][0]
        lower_body_vector = np.concatenate([r_vector, g_vector, b_vector])  # 크기: 30000
    else:
        lower_body_vector = np.zeros(30000)  # 기본값

    lower_body_labels.append(lower_body_vector)

    # 악세사리 벡터 처리 (R, G, B 결합 및 시퀀스 형태로 저장)
    accessory_sequence = []
    accessory_label_sequence = []
    for accessory in vectors['accessory']:
        r_vector, g_vector, b_vector = accessory
        accessory_vector = np.concatenate([r_vector, g_vector, b_vector])  # 크기: 30000
        accessory_sequence.append(accessory_vector)
        accessory_label_sequence.append(accessory_vector)  # 동일한 벡터를 레이블로 사용

    accessory_data.append(accessory_sequence)
    accessory_labels.append(accessory_label_sequence)

# numpy 배열로 변환
upper_body_data = np.array(upper_body_data)
lower_body_labels = np.array(lower_body_labels)
accessory_data = np.array([np.array(seq) for seq in accessory_data], dtype=object)  # 가변 길이 시퀀스
accessory_labels = np.array([np.array(seq) for seq in accessory_labels], dtype=object)  # 가변 길이 시퀀스

# %% [markdown]
# #### model

# %% [markdown]
# ##### Fully Connected Neural Network

# %%
# from tensorflow.keras import layers, models

# # 딥러닝 모델 정의
# model = models.Sequential([
#     layers.Dense(512, activation='relu', input_shape=(30000,)),  # 상의의 1차원 벡터 입력 (100x100x3)
#     layers.Dense(256, activation='relu'),
#     layers.Dense(128, activation='relu'),
#     layers.Dense(30000, activation='sigmoid')  # 하의의 1차원 벡터를 출력 (100x100x3)
# ])

# # 모델 컴파일
# model.compile(optimizer='adam',
#               loss='mean_squared_error',  # 이미지 복원과 비슷하게 MSE 사용
#               metrics=['accuracy'])

# # train_data와 train_labels 준비
# train_data = []
# train_labels = []

# for vectors in image_sets.values():
#     # 상의 벡터 가져오기
#     if len(vectors) > 0:
#         r_vector, g_vector, b_vector = vectors[0]  # 상의 벡터: 첫 번째 요소
#         upper_body_vector = np.concatenate([r_vector, g_vector, b_vector])
#     else:
#         upper_body_vector = np.zeros(30000)

#     # 하의 벡터 가져오기
#     if len(vectors) > 1:
#         r_vector, g_vector, b_vector = vectors[1]  # 하의 벡터: 두 번째 요소
#         lower_body_vector = np.concatenate([r_vector, g_vector, b_vector])
#     else:
#         lower_body_vector = np.zeros(30000)

#     # 악세사리 벡터 가져오기
#     if len(vectors) > 2:
#         r_vector, g_vector, b_vector = vectors[2]  # 악세사리 벡터: 세 번째 요소
#         accessory_vector = np.concatenate([r_vector, g_vector, b_vector])
#     else:
#         accessory_vector = np.zeros(30000)

#     # 상의 벡터를 train_data에 추가
#     train_data.append(upper_body_vector)
#     # 하의와 악세사리 벡터를 합산하여 train_labels에 추가
#     train_labels.append(lower_body_vector + accessory_vector)

# # numpy 배열로 변환
# train_data = np.array(train_data)
# train_labels = np.array(train_labels)

# # 모델 학습
# model.fit(train_data, train_labels, epochs=10, batch_size=32)

# # 학습 후 모델 저장
# model.save('pattern_color_model.h5')

# %%
# from tensorflow.keras.models import load_model

# # 학습된 모델 로드
# model = load_model('pattern_color_model.h5')

# # valid_image_sets에서 상의 벡터를 가져와 numpy 배열로 변환
# # 각 upper_body 벡터를 R, G, B로 분리한 후 결합
# valid_data = []
# for vectors in valid_image_sets.values():
#     if len(vectors['upper_body']) > 0:
#         r_vector, g_vector, b_vector = vectors['upper_body'][0]
#         upper_body_vector = np.concatenate([r_vector, g_vector, b_vector])
#         valid_data.append(upper_body_vector)

# # numpy 배열로 변환
# valid_data = np.array(valid_data)

# # 모델 예측
# predicted_vectors = model.predict(valid_data)

# # 예측 결과 처리 및 이미지 저장
# output_dir = "predictions"
# os.makedirs(output_dir, exist_ok=True)  # 폴더가 없으면 생성

# for idx, (image_name, vectors) in enumerate(valid_image_sets.items()):
#     # 예측된 벡터 분리
#     predicted_combined_vector = predicted_vectors[idx]
#     predicted_lower_body_vector = predicted_combined_vector[:30000]  # 첫 30000은 하의 벡터
#     predicted_accessory_vector = predicted_combined_vector[30000:]   # 나머지 30000은 악세사리 벡터

#     # 예외 처리: 벡터가 비어 있는 경우 기본값으로 채우기
#     if predicted_lower_body_vector.size == 0:
#         predicted_lower_body_vector = np.zeros(30000)
#     if predicted_accessory_vector.size == 0:
#         predicted_accessory_vector = np.zeros(30000)

#     # 예측된 벡터를 이미지로 변환
#     predicted_lower_body_image = predicted_lower_body_vector.reshape(100, 100, 3)
#     predicted_lower_body_image = np.clip(predicted_lower_body_image, 0, 255).astype('uint8')

#     predicted_accessory_image = predicted_accessory_vector.reshape(100, 100, 3)
#     predicted_accessory_image = np.clip(predicted_accessory_image, 0, 255).astype('uint8')

#     # 예측된 이미지 저장
#     lower_body_image_path = os.path.join(output_dir, f"predicted_lower_body_{image_name}.jpg")
#     accessory_image_path = os.path.join(output_dir, f"predicted_accessory_{image_name}.jpg")

#     # 이미지 저장
#     cv2.imwrite(lower_body_image_path, predicted_lower_body_image)
#     cv2.imwrite(accessory_image_path, predicted_accessory_image)

#     print(f"Predicted images saved: '{lower_body_image_path}' and '{accessory_image_path}'")

# %% [markdown]
# ##### CNN+LSTM

# %% [markdown]
# 상의 -> 하의
# 악세사리 -> 악세사리

# %%
from tensorflow.keras import layers, models, Input
import numpy as np

# 최대 시퀀스 길이를 5로 설정
MAX_SEQUENCE_LENGTH = 5

# 패딩 함수 => 만약 우리가 3개의 output을 냈다면 뒤의 2개는 0 벡터로 표현함
def pad_sequence(sequence, max_length, vector_size):
    # 현재 시퀀스 길이가 max_length보다 작으면 0 벡터를 추가
    while len(sequence) < max_length:
        sequence.append(np.zeros(vector_size))
    return np.array(sequence)

# 모델 구성
# 상의 벡터 입력 (고정 크기: 30000)
upper_body_input = Input(shape=(30000,))
x = layers.Dense(512, activation='relu')(upper_body_input)
x = layers.Dense(256, activation='relu')(x)
x = layers.Dense(128, activation='relu')(x)

# 하의 벡터 출력 (고정 크기: 30000)
lower_body_output = layers.Dense(30000, activation='sigmoid', name='lower_body_output')(x)

# 악세사리 벡터 입력 (고정된 최대 길이: MAX_SEQUENCE_LENGTH, 각 벡터 크기 30000)
accessory_input = Input(shape=(MAX_SEQUENCE_LENGTH, 30000))
accessory_rnn = layers.LSTM(128, activation='relu', return_sequences=True)(accessory_input)

# 상의 벡터를 악세사리 시퀀스 길이에 맞게 확장
x_repeated = layers.RepeatVector(MAX_SEQUENCE_LENGTH)(x)

# 상의 벡터와 악세사리 RNN 출력 결합
combined = layers.Concatenate(axis=-1)([x_repeated, accessory_rnn])
accessory_output = layers.TimeDistributed(layers.Dense(30000, activation='sigmoid'))(combined)

# 모델 정의 (입력: 상의 + 악세사리, 출력: 하의 + 악세사리)
model = models.Model(inputs=[upper_body_input, accessory_input], outputs=[lower_body_output, accessory_output])

# 모델 컴파일
model.compile(
    optimizer='adam',
    loss=['mean_squared_error', 'mean_squared_error'],
    metrics=[['accuracy'], ['accuracy']]  # 각 출력에 대해 메트릭을 지정
)

# 모델 요약 출력
model.summary()
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 30000)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 512)       │ 15,360,512 │ input_layer_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 256)       │    131,328 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 128)       │     32,896 │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_3       │ (None, 5, 30000)  │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ repeat_vector_1     │ (None, 5, 128)    │          0 │ dense_6[0][0]     │
# │ (RepeatVector)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_1 (LSTM)       │ (None, 5, 128)    │ 15,426,048 │ input_layer_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 5, 256)    │          0 │ repeat_vector_1[… │
# │ (Concatenate)       │                   │            │ lstm_1[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lower_body_output   │ (None, 30000)     │  3,870,000 │ dense_6[0][0]     │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ time_distributed_1  │ (None, 5, 30000)  │  7,710,000 │ concatenate_1[0]… │
# │ (TimeDistributed)   │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 42,530,784 (162.24 MB)
#  Trainable params: 42,530,784 (162.24 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
import numpy as np

# 벡터 크기와 시퀀스 길이 설정
VECTOR_SIZE = 30000
MAX_SEQUENCE_LENGTH = 5

# 패딩 함수
def pad_sequence(sequence, max_length, vector_size):
    padded_sequence = list(sequence)[:max_length]  # 최대 길이까지 잘라내기
    while len(padded_sequence) < max_length:
        padded_sequence.append(np.zeros(vector_size))  # 0 벡터로 패딩
    return np.array(padded_sequence)

# 악세사리 데이터를 패딩하여 3D 형태로 변환
accessory_data_train_padded = np.array(
    [pad_sequence(seq, MAX_SEQUENCE_LENGTH, VECTOR_SIZE) for seq in accessory_data_train]
)
accessory_labels_train_padded = np.array(
    [pad_sequence(seq, MAX_SEQUENCE_LENGTH, VECTOR_SIZE) for seq in accessory_labels_train]
)

# 데이터 준비 확인
print("Shape of accessory_data_train_padded:", accessory_data_train_padded.shape)
print("Shape of accessory_labels_train_padded:", accessory_labels_train_padded.shape)

# 모델 학습
history = model.fit(
    [upper_body_data_train, accessory_data_train_padded],  # 입력 데이터
    [lower_body_label_train, accessory_labels_train_padded],  # 출력 데이터 (레이블)
    epochs=5,
    batch_size=32
)
# Out:
# Shape of accessory_data_train_padded: (755, 5, 30000)
# Shape of accessory_labels_train_padded: (755, 5, 30000)
# Epoch 1/5
# c:\Users\wjdrl\anaconda3\envs\jsy\Lib\site-packages\keras\src\models\functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor_20', 'keras_tensor_25']. Received: the structure of inputs=('*', '*')
#   warnings.warn(
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 170ms/step - loss: 19154.7227 - lower_body_output_accuracy: 0.0069 - lower_body_output_loss: 10899.7822 - time_distributed_1_accuracy: 0.5352 - time_distributed_1_loss: 8255.0293
# Epoch 2/5
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - loss: 19802.2324 - lower_body_output_accuracy: 0.0049 - lower_body_output_loss: 11415.8652 - time_distributed_1_accuracy: 0.5804 - time_distributed_1_loss: 8384.2646
# Epoch 3/5
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - loss: 19790.0000 - lower_body_output_accuracy: 0.0065 - lower_body_output_loss: 11820.3125 - time_distributed_1_accuracy: 0.5930 - time_distributed_1_loss: 7977.4170
# Epoch 4/5
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - loss: 19484.9277 - lower_body_output_accuracy: 0.0092 - lower_body_output_loss: 11562.0566 - time_distributed_1_accuracy: 0.5842 - time_distributed_1_loss: 7913.8560
# Epoch 5/5
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - loss: 19999.0820 - lower_body_output_accuracy: 0.0101 - lower_body_output_loss: 11642.1445 - time_distributed_1_accuracy: 0.5892 - time_distributed_1_loss: 8354.7295

# %%
# # 악세사리 데이터를 패딩하여 3D 형태로 변환
# accessory_data_valid_padded = np.array(
#     [pad_sequence(seq, MAX_SEQUENCE_LENGTH, VECTOR_SIZE) for seq in accessory_data_valid]
# )
# accessory_labels_train_padded = np.array(
#     [pad_sequence(seq, MAX_SEQUENCE_LENGTH, VECTOR_SIZE) for seq in accessory_labels_valid]
# )

# # 모델 예측
# predictions = model.predict([upper_body_data_valid, accessory_data_valid_padded])

# # 반환된 값의 형태와 개수 확인
# print("Type of predictions:", type(predictions))
# if isinstance(predictions, (list, tuple)):
#     print("Number of predictions:", len(predictions))
#     for idx, pred in enumerate(predictions):
#         print(f"Shape of predictions[{idx}]:", pred.shape)
# else:
#     print("Shape of predictions:", predictions.shape)

# %%
# import os
# import numpy as np
# import cv2
# from tensorflow.keras.models import load_model

# # 학습된 모델 로드
# model = load_model('pattern_color_model.h5')

# # 저장할 폴더 경로 설정
# output_folder = 'predicted_images'
# if not os.path.exists(output_folder):
#     os.makedirs(output_folder)  # 폴더가 없으면 생성

# # 유효성 검사용 데이터 준비
# upper_body_data_valid = np.array(upper_body_data_valid)
# accessory_data_valid_padded = np.array(
#     [pad_sequence(seq, MAX_SEQUENCE_LENGTH, 30000) for seq in accessory_data_valid], dtype=np.float32
# )

# # 모델 예측
# predictions = model.predict([upper_body_data_valid, accessory_data_valid_padded])

# # 예측값을 확인하여 처리
# if isinstance(predictions, list) and len(predictions) == 2:
#     lower_body_pred = predictions[0]
#     accessory_pred = predictions[1]
# else:
#     print("Error: 예측 결과가 예상한 형태가 아닙니다.")
#     lower_body_pred = np.array([])
#     accessory_pred = np.array([])

# # 예측 벡터 크기 확인
# print("Shape of lower_body_pred:", lower_body_pred.shape)
# print("Shape of accessory_pred:", accessory_pred.shape)

# # 예측 결과 처리 및 이미지 저장
# if lower_body_pred.size > 0 and accessory_pred.size > 0:
#     for i in range(min(5, len(lower_body_pred))):  # 처음 5개만 저장
#         # 하의 예측 벡터 처리
#         if lower_body_pred[i].size == 30000:  # 벡터 크기가 30000인지 확인
#             predicted_lower_body_image = lower_body_pred[i].reshape(100, 100, 3)
#             predicted_lower_body_image = np.clip(predicted_lower_body_image, 0, 255).astype('uint8')
#             cv2.imwrite(os.path.join(output_folder, f"predicted_lower_body_image_{i}.jpg"), predicted_lower_body_image)
#             print(f"Saved: predicted_lower_body_image_{i}.jpg")
#         else:
#             print(f"Warning: lower_body_pred[{i}] 크기 {lower_body_pred[i].size}가 예상과 다릅니다. 스킵합니다.")

#         # 악세사리 예측이 있는 경우 처리
#         if accessory_pred is not None and len(accessory_pred) > i and accessory_pred[i].shape[0] > 0:
#             for j in range(min(accessory_pred.shape[1], 5)):  # 최대 5개의 악세사리 처리
#                 if accessory_pred[i][j].size == 30000:  # 벡터 크기 확인
#                     predicted_accessory_image = accessory_pred[i][j].reshape(100, 100, 3)
#                     predicted_accessory_image = np.clip(predicted_accessory_image, 0, 255).astype('uint8')
#                     cv2.imwrite(os.path.join(output_folder, f"predicted_accessory_image_{i}_{j}.jpg"), predicted_accessory_image)
#                     print(f"Saved: predicted_accessory_image_{i}_{j}.jpg")
#                 else:
#                     print(f"Warning: accessory_pred[{i}, {j}] 크기 {accessory_pred[i][j].size}가 예상과 다릅니다. 스킵합니다.")
# else:
#     print("Error: 예측된 벡터가 비어 있습니다.")

# print(f"예측된 이미지들이 폴더에 저장되었습니다: {output_folder}")

# %%
import os
import numpy as np
import cv2
from tensorflow.keras.models import load_model

# 학습된 모델 로드
model = load_model('pattern_color_model.h5')

# 저장할 폴더 경로 설정
output_folder = 'predicted_images'
if not os.path.exists(output_folder):
    os.makedirs(output_folder)  # 폴더가 없으면 생성

# 유효성 검사용 데이터 준비
upper_body_data_valid = np.array(upper_body_data_valid)
accessory_data_valid_padded = np.array(
    [pad_sequence(seq, MAX_SEQUENCE_LENGTH, 30000) for seq in accessory_data_valid], dtype=np.float32
)

# 모델 예측
predictions = model.predict([upper_body_data_valid, accessory_data_valid_padded])

# 예측값을 확인하여 처리
if isinstance(predictions, list) and len(predictions) == 2:
    lower_body_pred = predictions[0]
    accessory_pred = predictions[1]
else:
    print("Error: 예측 결과가 예상한 형태가 아닙니다.")
    lower_body_pred = np.array([])
    accessory_pred = np.array([])

# 예측 벡터 크기 확인
print("Shape of lower_body_pred:", lower_body_pred.shape)
print("Shape of accessory_pred:", accessory_pred.shape)

# 예측 결과 처리 및 이미지 저장
if lower_body_pred.size > 0 and accessory_pred.size > 0:
    for i in range(min(5, len(lower_body_pred))):  # 처음 5개만 저장
        # 하의 예측 벡터 처리
        if lower_body_pred[i].size == 30000:  # 벡터 크기가 30000인지 확인
            try:
                predicted_lower_body_image = lower_body_pred[i].reshape(100, 100, 3)
                predicted_lower_body_image = np.clip(predicted_lower_body_image, 0, 255).astype('uint8')
                cv2.imwrite(os.path.join(output_folder, f"predicted_lower_body_image_{i}.jpg"), predicted_lower_body_image)
                print(f"Saved: predicted_lower_body_image_{i}.jpg")
            except Exception as e:
                print(f"Error saving lower body image {i}: {e}")
        else:
            print(f"Warning: lower_body_pred[{i}] 크기 {lower_body_pred[i].size}가 예상과 다릅니다. 스킵합니다.")

        # 악세사리 예측이 있는 경우 처리
        if accessory_pred is not None and len(accessory_pred) > i and accessory_pred[i].shape[0] > 0:
            for j in range(min(accessory_pred.shape[1], 5)):  # 최대 5개의 악세사리 처리
                if accessory_pred[i][j].size == 30000:  # 벡터 크기 확인
                    try:
                        predicted_accessory_image = accessory_pred[i][j].reshape(100, 100, 3)
                        predicted_accessory_image = np.clip(predicted_accessory_image, 0, 255).astype('uint8')
                        cv2.imwrite(os.path.join(output_folder, f"predicted_accessory_image_{i}_{j}.jpg"), predicted_accessory_image)
                        print(f"Saved: predicted_accessory_image_{i}_{j}.jpg")
                    except Exception as e:
                        print(f"Error saving accessory image {i}_{j}: {e}")
                else:
                    print(f"Warning: accessory_pred[{i}, {j}] 크기 {accessory_pred[i][j].size}가 예상과 다릅니다. 스킵합니다.")
else:
    print("Error: 예측된 벡터가 비어 있습니다.")

print(f"예측된 이미지들이 폴더에 저장되었습니다: {output_folder}")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Error: 예측 결과가 예상한 형태가 아닙니다.
# Shape of lower_body_pred: (0,)
# Shape of accessory_pred: (0,)
# Error: 예측된 벡터가 비어 있습니다.
# 예측된 이미지들이 폴더에 저장되었습니다: predicted_images

# %% [markdown]
# GG
