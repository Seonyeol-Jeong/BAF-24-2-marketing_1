# %% [markdown]
# source /home/hemoa001/anaconda3/etc/profile.d/conda.sh

# %% [markdown]
# # 1. 상의 하의 검출

# %% [markdown]
# **roboflow**에서 라벨링 한 data: objection_detection

# %% [markdown]
# 바운딩 박스 좌표가 담겨져있는 txt 파일 내의 라벨링을 실행.
# 두번째 줄의 0을 1로 변경. (0: 상의, 1: 하의)

# %%
import os

# train set에 대한 하의 1 변경
dataset_train = '/data1/project/seoeun/BAF/object_detection/train/labels'  # 텍스트 파일이 있는 폴더 경로

# 폴더 내의 모든 텍스트 파일에 대해 작업
for filename in os.listdir(dataset_train):
    if filename.endswith(".txt"):
        file_path = os.path.join(dataset_train, filename)

        # 텍스트 파일 읽기
        with open(file_path, 'r') as file:
            lines = file.readlines()

        # 두 번째 줄이 존재하고, 맨 앞의 숫자가 0일 경우에만 작업 수행
        if len(lines) > 1 and lines[1][0] == '0':
            # 두 번째 줄의 맨 앞의 0을 1로 변경
            lines[1] = '1' + lines[1][1:]

            # 변경된 텍스트 파일 저장 (기존 파일 덮어쓰기)
            with open(file_path, 'w') as file:
                file.writelines(lines)

# %%
# valid set에 대한 하의 1 변경
dataset_valid = '/data1/project/seoeun/BAF/object_detection/valid/labels'  # 텍스트 파일이 있는 폴더 경로

# 폴더 내의 모든 텍스트 파일에 대해 작업
for filename in os.listdir(dataset_valid):
    if filename.endswith(".txt"):
        file_path = os.path.join(dataset_valid, filename)

        # 텍스트 파일 읽기
        with open(file_path, 'r') as file:
            lines = file.readlines()

        # 두 번째 줄이 존재하고, 맨 앞의 숫자가 0일 경우에만 작업 수행
        if len(lines) > 1 and lines[1][0] == '0':
            # 두 번째 줄의 맨 앞의 0을 1로 변경
            lines[1] = '1' + lines[1][1:]

            # 변경된 텍스트 파일 저장 (기존 파일 덮어쓰기)
            with open(file_path, 'w') as file:
                file.writelines(lines)

# %%
# test set에 대한 하의 1 변경
dataset_test = '/data1/project/seoeun/BAF/object_detection/test/labels'  # 텍스트 파일이 있는 폴더 경로

# 폴더 내의 모든 텍스트 파일에 대해 작업
for filename in os.listdir(dataset_test):
    if filename.endswith(".txt"):
        file_path = os.path.join(dataset_test, filename)

        # 텍스트 파일 읽기
        with open(file_path, 'r') as file:
            lines = file.readlines()

        # 두 번째 줄이 존재하고, 맨 앞의 숫자가 0일 경우에만 작업 수행
        if len(lines) > 1 and lines[1][0] == '0':
            # 두 번째 줄의 맨 앞의 0을 1로 변경
            lines[1] = '1' + lines[1][1:]

            # 변경된 텍스트 파일 저장 (기존 파일 덮어쓰기)
            with open(file_path, 'w') as file:
                file.writelines(lines)

# %% [markdown]
# ## **YOLOv5**

# %% [markdown]
# YOLOv5 설치

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16965, done.
# remote: Counting objects: 100% (160/160), done.64% (103/160)
# remote: Compressing objects: 100% (111/111), done.
# remote: Total 16965 (delta 81), reused 102 (delta 49), pack-reused 16805 (from 1)
# Receiving objects: 100% (16965/16965), 15.71 MiB | 10.79 MiB/s, done.
# Resolving deltas: 100% (11619/11619), done.

# %%
# %cd /data1/project/seoeun/BAF/yolov5/
# !pip install -r requirements.txt
# Out:
# /data1/project/seoeun/BAF/yolov5
# Collecting gitpython>=3.1.30 (from -r requirements.txt (line 5))
#   Downloading GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: matplotlib>=3.3 in /home/hemoa001/anaconda3/envs/cv/lib/python3.9/site-packages (from -r requirements.txt (line 6)) (3.9.2)
# Requirement already satisfied: numpy>=1.23.5 in /home/hemoa001/anaconda3/envs/cv/lib/python3.9/site-packages (from -r requirements.txt (line 7)) (1.26.4)
# Requirement already satisfied: opencv-python>=4.1.1 in /home/hemoa001/anaconda3/envs/cv/lib/python3.9/site-packages (from -r requirements.txt (line 8)) (4.10.0.84)
# Requirement already satisfied: pillow>=10.3.0 in /home/hemoa001/anaconda3/envs/cv/lib/python3.9/site-packages (from -r requirements.txt (line 9)) (10.4.0)
# Requirement already satisfied: psutil in /home/hemoa001/anaconda3/envs/cv/lib/python3.9/site-packages (from -r requirements.txt (line 10)) (6.0.0)
# Requirement already satisfied: PyYAML>=5.3.1 in /home/hemoa001/anaconda3/envs/cv/lib/python3.9/site-packages (from -r requirements.txt (line 11)) (6.0.2)
# Requirement already satisfied: requests>=2.32.2 in /home/hemoa001/anaconda3/envs/cv/lib/python3.9/site-packages (from -r requirements.txt (line 12)) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /home/hemoa001/anaconda3/envs/cv/lib/python3.9/site-packages (from -r requirements.txt (line 13)) (1.13.1)
# Collecting thop>=0.1.1 (from -r requirements.txt (line 14))
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: torch>=1.8.0 in /home/hemoa001/anaconda3/envs/cv/lib/python3.9/site-packages (from -r requirements.txt (line 15)) (2.4.1)
# Collecting torchvision>=0.9.0 (from -r requirements.txt (line 16))
#   Downloading torchvision-0.19.1-cp39-cp39-manylinux1_x86_64.whl.metadata (6.0 kB)
# Requirement already satisfied: tqdm>=4.66.3 in /home/hemoa001/anaconda3/envs/cv/lib/python3.9/site-packages (from -r requirements.txt (line 17)) (4.66.5)
# Collecting ultralytics>=8.2.34 (from -r requirements.txt (line 18))
#   Downloading ultralytics-8.2.101-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: pandas>=1.1.4 in /home/hemoa001/anaconda3/envs/cv/lib/python3.9/site-packages (from -r requirements.txt (line 27)) (2.2.3)
# Collecting seaborn>=0.11.0 (from -r requirements.txt (line 28))
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: setuptools>=70.0.0 in /home/hemoa001/anaconda3/envs/cv/lib/python3.9/site-packages (from -r requirements.txt (line 42)) (75.1.0)
# Collecting gitdb<5,>=4.0.1 (from gitpython>=3.1.30->-r requirements.txt (line 5))
#   Downloading gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /home/hemoa001/anaconda3/envs/cv/lib/python3.9/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/hemoa001/anaconda3/envs/cv/lib/python3.9/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/hemoa001/anaconda3/envs/cv/lib/python3.9/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/hemoa001/anaconda3/envs/cv/lib/python3.9/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/hemoa001/anaconda3/envs/cv/lib/python3.9/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/hemoa001/anaconda3/envs/cv/lib/python3.9/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/hemoa001/anaconda3/envs/cv/lib/python3.9/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (2.9.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/hemoa001/anaconda3/envs/cv/lib/python3.9/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (6.4.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/hemoa001/anaconda3/envs/cv/lib/python3.9/site-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/hemoa001/anaconda3/envs/cv/lib/python3.9/site-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/hemoa001/anaconda3/envs/cv/lib/python3.9/site-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/hemoa001/anaconda3/envs/cv/lib/python3.9/site-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (2024.8.30)
# Requirement already satisfied: filelock in /home/hemoa001/anaconda3/envs/cv/lib/python3.9/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/hemoa001/anaconda3/envs/cv/lib/python3.9/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (4.12.2)
# Requirement already satisfied: sympy in /home/hemoa001/anaconda3/envs/cv/lib/python3.9/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (1.13.3)
# Requirement already satisfied: networkx in /home/hemoa001/anaconda3/envs/cv/lib/python3.9/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.2.1)
# Requirement already satisfied: jinja2 in /home/hemoa001/anaconda3/envs/cv/lib/python3.9/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.1.4)
# Requirement already satisfied: fsspec in /home/hemoa001/anaconda3/envs/cv/lib/python3.9/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (2024.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/hemoa001/anaconda3/envs/cv/lib/python3.9/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/hemoa001/anaconda3/envs/cv/lib/python3.9/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/hemoa001/anaconda3/envs/cv/lib/python3.9/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/hemoa001/anaconda3/envs/cv/lib/python3.9/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/hemoa001/anaconda3/envs/cv/lib/python3.9/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/hemoa001/anaconda3/envs/cv/lib/python3.9/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/hemoa001/anaconda3/envs/cv/lib/python3.9/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/hemoa001/anaconda3/envs/cv/lib/python3.9/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/hemoa001/anaconda3/envs/cv/lib/python3.9/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/hemoa001/anaconda3/envs/cv/lib/python3.9/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/hemoa001/anaconda3/envs/cv/lib/python3.9/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /home/hemoa001/anaconda3/envs/cv/lib/python3.9/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/hemoa001/anaconda3/envs/cv/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8.0->-r requirements.txt (line 15)) (12.6.68)
# Collecting py-cpuinfo (from ultralytics>=8.2.34->-r requirements.txt (line 18))
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl.metadata (794 bytes)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics>=8.2.34->-r requirements.txt (line 18))
#   Downloading ultralytics_thop-2.0.8-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: pytz>=2020.1 in /home/hemoa001/anaconda3/envs/cv/lib/python3.9/site-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/hemoa001/anaconda3/envs/cv/lib/python3.9/site-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2024.2)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython>=3.1.30->-r requirements.txt (line 5))
#   Downloading smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: zipp>=3.1.0 in /home/hemoa001/anaconda3/envs/cv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.3->-r requirements.txt (line 6)) (3.20.2)
# Requirement already satisfied: six>=1.5 in /home/hemoa001/anaconda3/envs/cv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.3->-r requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/hemoa001/anaconda3/envs/cv/lib/python3.9/site-packages (from jinja2->torch>=1.8.0->-r requirements.txt (line 15)) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/hemoa001/anaconda3/envs/cv/lib/python3.9/site-packages (from sympy->torch>=1.8.0->-r requirements.txt (line 15)) (1.3.0)
# Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
# Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Downloading torchvision-0.19.1-cp39-cp39-manylinux1_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 11.0 MB/s eta 0:00:00a 0:00:01
# Downloading ultralytics-8.2.101-py3-none-any.whl (874 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 874.1/874.1 kB 8.9 MB/s eta 0:00:00
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
# Downloading ultralytics_thop-2.0.8-py3-none-any.whl (26 kB)
# Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: py-cpuinfo, smmap, gitdb, seaborn, gitpython, ultralytics-thop, torchvision, thop, ultralytics
# Successfully installed gitdb-4.0.11 gitpython-3.1.43 py-cpuinfo-9.0.0 seaborn-0.13.2 smmap-5.0.1 thop-0.1.1.post2209072238 torchvision-0.19.1 ultralytics-8.2.101 ultralytics-thop-2.0.8

# %% [markdown]
# data.yaml 파일 수정 필요.
# name:
# - Top
# - Bottom
#
# nc: 2
#
# train: /경로 정확히 /images까지 지정

# %%
# !python  train.py --img 416 --batch 16 --epochs 100 --data /data1/project/seoeun/BAF/object_detection/data.yaml --cfg ./models/yolov5s.yaml --weights yolov5s.pt --name best_yolov5s_result
# 15m 33.8s 걸림.
# Out:
# 2024-09-26 14:46:46.709243: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-26 14:46:46.724751: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-26 14:46:46.729423: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# train: weights=yolov5s.pt, cfg=./models/yolov5s.yaml, data=/data1/project/seoeun/BAF/object_detection/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data/hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=best_yolov5s_result, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-368-gb163ff8d Python-3.9.20 torch-2.4.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24217MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=2
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     18879  models.yolo.Detect                      [2, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# YOLOv5s summary: 214 layers, 7025023 parameters, 7025023 gradients, 16.0 GFLOPs
#
# Transferred 342/349 items from yolov5s.pt
# /data1/project/seoeun/BAF/yolov5/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /data1/project/seoeun/BAF/yolov5/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# WARNING ⚠️ DP not recommended, use torch.distributed.run for best DDP Multi-GPU results.
# See Multi-GPU Tutorial at https://docs.ultralytics.com/yolov5/tutorials/multi_gpu_training to get started.
# train: Scanning /data1/project/seoeun/BAF/object_detection/train/labels.cache...
# val: Scanning /data1/project/seoeun/BAF/object_detection/valid/labels.cache... 2
#
# AutoAnchor: 5.52 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/best_yolov5s_result3/labels.jpg...
# /data1/project/seoeun/BAF/yolov5/train.py:355: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=amp)
# Image sizes 416 train, 416 val
# Using 8 dataloader workers
# Logging results to runs/train/best_yolov5s_result3
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/45 [00:00<?, ?it/s]/data1/project/seoeun/BAF/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/99     0.768G     0.1211    0.02451    0.03107         59        416:  /data1/project/seoeun/BAF/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/99     0.807G     0.1211    0.02393     0.0308         54        416:  /data1/project/seoeun/BAF/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/99     0.845G     0.1213    0.02236    0.03111         39        416:  /data1/project/seoeun/BAF/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/99     0.845G     0.1211    0.02212    0.03116         49        416:  /data1/project/seoeun/BAF/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/99     0.845G    0.09467    0.03077    0.02532          2        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        201        402       0.43      0.622      0.451      0.119
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        1/99      1.13G    0.06685    0.02918    0.01036          2        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        201        402      0.339      0.595      0.333     0.0942
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        2/99      1.13G    0.06619    0.02524   0.005005          8        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        201        402      0.489       0.73      0.583       0.17
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        3/99      1.13G    0.06058    0.02198   0.004259          1        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        201        402      0.584      0.779      0.716      0.341
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        4/99      1.13G    0.05255    0.01925   0.003657          2        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        201        402      0.768      0.843       0.85      0.313
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        5/99      1.13G    0.04797    0.01989   0.002995          5        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        201        402      0.871       0.92      0.936      0.463
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        6/99      1.13G    0.04313    0.01813   0.002475          3        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        201        402      0.934      0.909      0.936       0.42
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        7/99      1.13G    0.04078    0.01773   0.002385          3        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        201        402      0.951      0.949      0.962       0.57
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        8/99      1.13G    0.03932    0.01774   0.002004          4        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        201        402      0.947       0.93      0.949      0.493
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        9/99      1.13G    0.03767    0.01674   0.001883          2        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        201        402      0.922      0.953      0.957      0.532
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       10/99      1.13G    0.03415    0.01677   0.001719          0        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        201        402      0.943       0.95      0.962      0.572
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       11/99      1.13G    0.03426    0.01612   0.001998          1        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        201        402      0.964      0.953      0.969      0.592
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       12/99      1.13G    0.03411    0.01719   0.001826          3        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        201        402      0.967      0.943      0.961      0.565
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       13/99      1.13G    0.03432    0.01669   0.001191          2        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        201        402      0.952      0.945      0.962      0.573
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       14/99      1.13G     0.0316    0.01682    0.00133          8        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        201        402      0.941      0.947      0.962      0.577
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       15/99      1.13G    0.03312    0.01621   0.001034          5        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        201        402      0.957      0.957      0.965      0.612
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       16/99      1.13G    0.03072    0.01554   0.001144          2        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        201        402      0
416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        201        402      0.954      0.956      0.961      0.619
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       81/99      1.13G    0.01833    0.01148  0.0002468          2        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        201        402      0.959       0.96      0.961      0.625
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       82/99      1.13G    0.01813    0.01136  0.0002798          3        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        201        402      0.958      0.963      0.961      0.627
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       83/99      1.13G    0.01829    0.01175  0.0002236          3        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        201        402      0.961       0.96       0.96      0.623
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       84/99      1.13G    0.01803    0.01124  0.0002003          2        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        201        402      0.961       0.96      0.959      0.623
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       85/99      1.13G    0.01781    0.01198  0.0001833          5        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        201        402      0.961      0.959       0.96      0.623
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       86/99      1.13G     0.0177     0.0116  0.0002713          2        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        201        402      0.962      0.962      0.957      0.626
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       87/99      1.13G    0.01786    0.01164  0.0002263          2        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        201        402      0.957       0.96      0.959      0.621
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       88/99      1.13G    0.01789    0.01154  0.0001944          8        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        201        402      0.958      0.964       0.96       0.62
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       89/99      1.13G    0.01772    0.01147  0.0001886          2        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        201        402      0.956      0.952      0.957      0.615
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       90/99      1.13G    0.01737    0.01124  0.0001624          4        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        201        402      0.962      0.955      0.958      0.616
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       91/99      1.13G     0.0172    0.01174  0.0002288          7        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        201        402      0.956      0.964      0.963      0.626
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       92/99      1.13G    0.01732    0.01153  0.0001813          3        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        201        402      0.959      0.955      0.962      0.631
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       93/99      1.13G    0.01723     0.0113   0.000189          6        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        201        402      0.964      0.968      0.964       0.63
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       94/99      1.13G    0.01732    0.01158  0.0002057          5        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        201        402      0.958      0.961      0.965      0.627
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       95/99      1.13G    0.01746    0.01155  0.0001558          2        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        201        402      0.955      0.959      0.965      0.624
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       96/99      1.13G    0.01689    0.01123  0.0001641          2        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        201        402      0.964      0.949      0.962      0.624
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       97/99      1.13G    0.01676    0.01129  0.0001702          2        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        201        402      0.955      0.958      0.961      0.628
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       98/99      1.13G    0.01661    0.01131  0.0001714          4        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        201        402      0.955      0.959      0.961       0.62
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       99/99      1.13G    0.01693    0.01106  0.0001551          3        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        201        402      0.958      0.963      0.963      0.625
#
# 100 epochs completed in 0.251 hours.
# Optimizer stripped from runs/train/best_yolov5s_result3/weights/last.pt, 14.3MB
# Optimizer stripped from runs/train/best_yolov5s_result3/weights/best.pt, 14.3MB
#
# Validating runs/train/best_yolov5s_result3/weights/best.pt...
# Fusing layers...
# YOLOv5s summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
#                  Class     Images  Instances          P          R      mAP50
#                    all        201        402      0.947       0.96      0.964      0.639
#                    Top        201        201      0.953      0.955      0.958      0.638
#                 Bottom        201        201      0.941      0.965       0.97      0.641
# Results saved to runs/train/best_yolov5s_result3

# %%
import torch

if torch.cuda.is_available():
    print(f"Current CUDA Device ID: {torch.cuda.current_device()}")
    print(f"Device Name: {torch.cuda.get_device_name(torch.cuda.current_device())}")
else:
    print("No GPU available")
# Out:
# Current CUDA Device ID: 0
# Device Name: NVIDIA GeForce RTX 4090

# %%
pwd
# Out:
# '/data1/project/seoeun/BAF/yolov5'

# %%
# %load_ext tensorboard
# %tensorboard --logdir /data1/project/seoeun/BAF/yolov5/runs
# Out:
#       <iframe id="tensorboard-frame-6f791f83dbf188d7" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-6f791f83dbf188d7");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ## 상의, 하의 검출 확인하기

# %%
# !python detect.py --weights runs/train/best_yolov5s_result3/weights/best.pt --source "/data1/project/seoeun/BAF/test1.jpg"
# Out:
# detect: weights=['runs/train/best_yolov5s_result3/weights/best.pt'], source=/data1/project/seoeun/BAF/test1.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-368-gb163ff8d Python-3.9.20 torch-2.4.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24217MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /data1/project/seoeun/BAF/test1.jpg: 640x448 1 Top, 1 Bottom, 31.5ms
# Speed: 0.5ms pre-process, 31.5ms inference, 369.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp3

# %%
# !python detect.py --weights runs/train/best_yolov5s_result3/weights/best.pt --source "/data1/project/seoeun/BAF/test2.jpg"
# Out:
# detect: weights=['runs/train/best_yolov5s_result3/weights/best.pt'], source=/data1/project/seoeun/BAF/test2.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-368-gb163ff8d Python-3.9.20 torch-2.4.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24217MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /data1/project/seoeun/BAF/test2.jpg: 640x448 1 Top, 1 Bottom, 30.5ms
# Speed: 0.4ms pre-process, 30.5ms inference, 360.8ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp4

# %%
# !python detect.py --weights runs/train/best_yolov5s_result3/weights/best.pt --source "/data1/project/seoeun/BAF/test3.jpg"
# Out:
# detect: weights=['runs/train/best_yolov5s_result3/weights/best.pt'], source=/data1/project/seoeun/BAF/test3.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-368-gb163ff8d Python-3.9.20 torch-2.4.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24217MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /data1/project/seoeun/BAF/test3.jpg: 640x448 1 Top, 1 Bottom, 30.6ms
# Speed: 0.4ms pre-process, 30.6ms inference, 354.2ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp5

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt  # 일반 Python 환경에서 이미지 출력용

# 이미지 경로 설정
img_path1 = '/data1/project/seoeun/BAF/yolov5/runs/detect/exp3/test1.jpg'
img_path2 = '/data1/project/seoeun/BAF/yolov5/runs/detect/exp4/test2.jpg'
img_path3 = '/data1/project/seoeun/BAF/yolov5/runs/detect/exp5/test3.jpg'

# 이미지 읽기
img1 = cv2.imread(img_path1)
img2 = cv2.imread(img_path2)
img3 = cv2.imread(img_path3)

# 이미지가 잘 로드되었는지 확인
if img1 is None or img2 is None or img3 is None:
    print("Error: One or more images could not be loaded.")
else:
    # 이미지 크기 조정
    new_size1 = (400, 500)
    new_size2 = (300, 500)
    new_size3 = (300, 500)
    
    img1 = cv2.resize(img1, new_size1)
    img2 = cv2.resize(img2, new_size2)
    img3 = cv2.resize(img3, new_size3)

    # 이미지 가로로 연결
    concatenated_img = np.concatenate((img1, img2, img3), axis=1)

    # 이미지 출력 (Matplotlib 사용)
    plt.imshow(cv2.cvtColor(concatenated_img, cv2.COLOR_BGR2RGB))
    plt.axis('off')  # 축 제거
    plt.show()
